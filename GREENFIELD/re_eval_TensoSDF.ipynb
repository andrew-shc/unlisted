# %%
# !pip install "numpy==1.26.4"

# reconstruct the geometry
# !cd TensoSDF; python run_training.py --cfg configs/shape/orb_subset/teapot.yaml

# extract mesh from the model
# !python extract_mesh.py --cfg configs/shape/orb_subset/teapot.yaml

# evaluate the geometry reconstruction results via the CD metric
# !python eval_orb_shape.py --out_mesh_path data/meshes/teapot_scene006_shape-180000.ply --target_mesh_path your_ORB_GT_mesh_path
# Out:
# train set len 99999999
# val val set len 1
# aabb tensor([-1., -1., -1.,  1.,  1.,  1.], device='cuda:0')
# grid size tensor([128, 128, 128])
# /home/ahc/Documents/metrology_ir/TensoSDF/network/shapeRenderer.py:227: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.gridSize = torch.tensor(gridSize.cpu(), dtype=torch.int32).to(self.device)
# sampling step size:  tensor(0.0394, device='cuda:0')
# Gaussian settings: 5, 0.5
# /home/ahc/miniconda3/envs/TensoSDF/lib/python3.10/site-packages/torch/functional.py:534: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3595.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# current levels : 1, current units : tensor([0.0157, 0.0157, 0.0157], device='cuda:0')
# /home/ahc/miniconda3/envs/TensoSDF/lib/python3.10/site-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# training size 2048 2048 ...
# Acutal splits num: train -> 59, val -> 1
# ========> filtering rays ...
# Ray filtering done! takes 1.4321315288543701 s. ray mask ratio: 1.0
# lr_decay_target_ratio : 0.05, lr_decay_iters : 180000,                 upsample list : [20000, 40000], occ_loss_step : 10000, radiance_field_step: 20000
# | 0/180000 [00:00<?, ?it/s]/home/ahc/miniconda3/envs/TensoSDF/lib/python3.10/site-packages/torch/__init__.py:1144: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:432.)
#   _C._set_default_tensor_type(t)
# | 2499/180000 [06:39<7:40:42,  6.42it/s, loss=0.0856, loss_color=0.0499, loss_eikonal=0.00724, loss_gau=0, loss_hessian=0, loss_mask=0.0217, loss_rad=0, loss_sparse=0.00501, loss_tv_sdf=0.00173, lr_net=0.001, lr_xyz=0.01]
# 0it [00:00, ?it/s]
# 1it [00:20, 20.69s/it]
# eval cost 21.55345892906189 s
# New best model psnr: 26.13941 previous 0.00000
# | 4999/180000 [13:28<7:28:14,  6.51it/s, loss=0.0829, loss_color=0.0491, loss_eikonal=0.00784, loss_gau=0, loss_hessian=0, loss_mask=0.0197, loss_rad=0, loss_sparse=0.00471, loss_tv_sdf=0.00164, lr_net=0.000998, lr_xyz=0.00998]
# 0it [00:00, ?it/s]
# 1it [00:20, 20.68s/it]
# eval cost 21.536725759506226 s
# New best model psnr: 26.40325 previous 26.13941
# | 7499/180000 [20:17<7:22:27,  6.50it/s, loss=0.0938, loss_color=0.0547, loss_eikonal=0.00808, loss_gau=0, loss_hessian=0, loss_mask=0.0245, loss_rad=0, loss_sparse=0.00503, loss_tv_sdf=0.00148, lr_net=0.000996, lr_xyz=0.00996]
# 0it [00:00, ?it/s]
# 1it [00:20, 20.70s/it]
# eval cost 21.561810970306396 s
# New best model psnr: 26.66994 previous 26.40325
# | 9999/180000 [27:06<7:15:18,  6.51it/s, loss=0.0569, loss_color=0.0426, loss_eikonal=0.000627, loss_gau=0, loss_hessian=0, loss_mask=0.00494, loss_rad=0, loss_sparse=0.00699, loss_tv_sdf=0.00176, lr_net=0.000993, lr_xyz=0.00993]
# 0it [00:00, ?it/s]
# 1it [00:20, 20.79s/it]
# eval cost 21.652073860168457 s
# New best model psnr: 30.51278 previous 26.66994
# | 12499/180000 [34:20<7:42:50,  6.03it/s, loss=0.0988, loss_color=0.0396, loss_eikonal=0.000525, loss_gau=0, loss_hessian=0, loss_mask=0.00397, loss_rad=0, loss_sparse=0.00507, loss_tv_sdf=0.00176, lr_net=0.000989, lr_xyz=0.00989]
# 0it [00:00, ?it/s]
# 1it [00:21, 21.24s/it]
# eval cost 22.103938579559326 s
# | 14999/180000 [41:34<7:35:59,  6.03it/s, loss=0.0845, loss_color=0.0377, loss_eikonal=0.000561, loss_gau=0, loss_hessian=0, loss_mask=0.00146, loss_rad=0, loss_sparse=0.00584, loss_tv_sdf=0.00175, lr_net=0.000984, lr_xyz=0.00984]
# 0it [00:00, ?it/s]
# 1it [00:21, 21.23s/it]
# eval cost 22.090148448944092 s
# New best model psnr: 30.75106 previous 30.51278
# | 17499/180000 [48:49<7:25:20,  6.08it/s, loss=0.0944, loss_color=0.0399, loss_eikonal=0.00055, loss_gau=0, loss_hessian=0, loss_mask=0.00183, loss_rad=0, loss_sparse=0.00598, loss_tv_sdf=0.00177, lr_net=0.000978, lr_xyz=0.00978]
# 0it [00:00, ?it/s]
# 1it [00:21, 21.25s/it]
# eval cost 22.112488985061646 s
# New best model psnr: 31.24518 previous 30.75106
# | 19999/180000 [56:04<7:17:30,  6.10it/s, loss=0.0847, loss_color=0.0387, loss_eikonal=0.00052, loss_gau=0, loss_hessian=0, loss_mask=0.00149, loss_rad=0, loss_sparse=0.00594, loss_tv_sdf=0.00172, lr_net=0.000971, lr_xyz=0.00971]
# 0it [00:00, ?it/s]
# 1it [00:21, 21.26s/it]
# eval cost 22.123932123184204 s
# New best model psnr: 31.35207 previous 31.24518
# | 20001/180000 [56:27<215:52:18,  4.86s/it, loss=0.0815, loss_color=0.0392, loss_eikonal=0.00048, loss_gau=0, loss_hessian=0, loss_mask=0.00286, loss_rad=0, loss_sparse=0.00587, loss_tv_sdf=0.00172, lr_net=0.000971, lr_xyz=0.00971]bbox: (tensor([-0.4803, -0.4331, -0.4173]), tensor([0.6063, 0.4488, 0.5276])) alpha rest %5.963326
# current levels : 2, current units : tensor([0.0078, 0.0078, 0.0078], device='cuda:0')
# upsamping to tensor([256, 256, 256], device='cuda:0', dtype=torch.int32), remember to update renderer
# aabb tensor([-1., -1., -1.,  1.,  1.,  1.], device='cuda:0')
# grid size tensor([256, 256, 256], device='cuda:0', dtype=torch.int32)
# /home/ahc/Documents/metrology_ir/TensoSDF/network/shapeRenderer.py:227: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.gridSize = torch.tensor(gridSize.cpu(), dtype=torch.int32).to(self.device)
# sampling step size:  tensor(0.0196, device='cuda:0')
# | 22498/180000 [59:18<2:59:50, 14.60it/s, loss=0.0834, loss_color=0.0356, loss_eikonal=0.00198, loss_gau=0.000863, loss_hessian=0, loss_mask=0.00342, loss_rad=0.00561, loss_sparse=0.00655, loss_tv_sdf=0.000785, lr_net=0.000992, lr_xyz=0.00496]
# 0it [00:00, ?it/s]
# 1it [00:07,  7.06s/it]
# eval cost 7.9151036739349365 s
# New best model psnr: 31.43119 previous 31.35207
# | 24998/180000 [1:02:17<2:56:23, 14.65it/s, loss=0.0742, loss_color=0.0334, loss_eikonal=0.000858, loss_gau=0.000813, loss_hessian=0, loss_mask=0.00481, loss_rad=0.00513, loss_sparse=0.00747, loss_tv_sdf=0.000798, lr_net=0.000984, lr_xyz=0.00492]
# 0it [00:00, ?it/s]
# 1it [00:06,  7.00s/it]
# eval cost 7.8515708446502686 s
# New best model psnr: 31.46298 previous 31.43119
# | 27498/180000 [1:05:16<2:53:51, 14.62it/s, loss=0.0572, loss_color=0.0325, loss_eikonal=0.000768, loss_gau=0.000814, loss_hessian=0, loss_mask=0.00106, loss_rad=0.00399, loss_sparse=0.00601, loss_tv_sdf=0.000826, lr_net=0.000974, lr_xyz=0.00487]
# 0it [00:00, ?it/s]
# 1it [00:07,  7.06s/it]
# eval cost 7.917787551879883 s
# New best model psnr: 31.81247 previous 31.46298
# | 29998/180000 [1:08:16<2:51:22, 14.59it/s, loss=0.0771, loss_color=0.0328, loss_eikonal=0.00088, loss_gau=0.000805, loss_hessian=0, loss_mask=0.00158, loss_rad=0.00522, loss_sparse=0.00712, loss_tv_sdf=0.00085, lr_net=0.000964, lr_xyz=0.00482]
# 0it [00:00, ?it/s]
# 1it [00:07,  7.06s/it]
# eval cost 7.930215358734131 s
# New best model psnr: 32.02333 previous 31.81247
# | 32498/180000 [1:11:15<2:48:08, 14.62it/s, loss=0.0719, loss_color=0.0334, loss_eikonal=0.00072, loss_gau=0.000766, loss_hessian=0, loss_mask=0.00342, loss_rad=0.00422, loss_sparse=0.00663, loss_tv_sdf=0.000856, lr_net=0.000953, lr_xyz=0.00476]
# 0it [00:00, ?it/s]
# 1it [00:07,  7.07s/it]
# eval cost 7.927986145019531 s
# New best model psnr: 32.49091 previous 32.02333
# | 34998/180000 [1:14:15<2:46:08, 14.55it/s, loss=0.0682, loss_color=0.0339, loss_eikonal=0.000713, loss_gau=0.000776, loss_hessian=0, loss_mask=0.00245, loss_rad=0.00474, loss_sparse=0.00618, loss_tv_sdf=0.00089, lr_net=0.000941, lr_xyz=0.00471]
# 0it [00:00, ?it/s]
# 1it [00:07,  7.08s/it]
# eval cost 7.941312074661255 s
# | 37498/180000 [1:17:14<2:42:54, 14.58it/s, loss=0.0621, loss_color=0.0336, loss_eikonal=0.00115, loss_gau=0.00076, loss_hessian=0, loss_mask=0.00229, loss_rad=0.00424, loss_sparse=0.00566, loss_tv_sdf=0.000904, lr_net=0.000928, lr_xyz=0.00464]
# 0it [00:00, ?it/s]
# 1it [00:07,  7.03s/it]
# eval cost 7.8945863246917725 s
# | 39998/180000 [1:20:14<2:39:30, 14.63it/s, loss=0.0613, loss_color=0.0336, loss_eikonal=0.000727, loss_gau=0.000769, loss_hessian=0, loss_mask=0.00327, loss_rad=0.00437, loss_sparse=0.00679, loss_tv_sdf=0.000912, lr_net=0.000915, lr_xyz=0.00458]
# 0it [00:00, ?it/s]
# 1it [00:07,  7.05s/it]
# eval cost 7.909682989120483 s
# | 40000/180000 [1:20:22<49:29:26,  1.27s/it, loss=0.0649, loss_color=0.0341, loss_eikonal=0.00059, loss_gau=0.000772, loss_hessian=0, loss_mask=0.00583, loss_rad=0.00456, loss_sparse=0.00124, loss_tv_sdf=0.000914, lr_net=0.000915, lr_xyz=0.00458]current levels : 3, current units : tensor([0.0039, 0.0039, 0.0039], device='cuda:0')
# upsamping to tensor([508, 508, 508], device='cuda:0', dtype=torch.int32), remember to update renderer
# aabb tensor([-1., -1., -1.,  1.,  1.,  1.], device='cuda:0')
# grid size tensor([508, 508, 508], device='cuda:0', dtype=torch.int32)
# /home/ahc/Documents/metrology_ir/TensoSDF/network/shapeRenderer.py:227: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.gridSize = torch.tensor(gridSize.cpu(), dtype=torch.int32).to(self.device)
# sampling step size:  tensor(0.0099, device='cuda:0')
# | 42499/180000 [1:25:15<4:27:34,  8.56it/s, loss=0.062, loss_color=0.0333, loss_eikonal=0.001, loss_gau=0.00139, loss_hessian=0, loss_mask=0.00212, loss_rad=0.00439, loss_sparse=0.00129, loss_tv_sdf=0.000549, lr_net=0.000985, lr_xyz=0.00492]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.90s/it]
# eval cost 10.767165184020996 s
# New best model psnr: 32.58303 previous 32.49091
# | 44999/180000 [1:30:19<4:23:11,  8.55it/s, loss=0.0656, loss_color=0.0329, loss_eikonal=0.00137, loss_gau=0.00141, loss_hessian=0, loss_mask=0.00117, loss_rad=0.00478, loss_sparse=0.00138, loss_tv_sdf=0.000584, lr_net=0.000969, lr_xyz=0.00484]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.85s/it]
# eval cost 10.705435752868652 s
# New best model psnr: 32.85542 previous 32.58303
# | 47499/180000 [1:35:24<4:21:15,  8.45it/s, loss=0.0683, loss_color=0.0335, loss_eikonal=0.00155, loss_gau=0.00153, loss_hessian=0, loss_mask=0.00314, loss_rad=0.00448, loss_sparse=0.00134, loss_tv_sdf=0.000666, lr_net=0.000952, lr_xyz=0.00476]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.92s/it]
# eval cost 10.78503131866455 s
# | 49999/180000 [1:40:29<4:12:45,  8.57it/s, loss=0.0596, loss_color=0.0337, loss_eikonal=0.00136, loss_gau=0.00152, loss_hessian=0, loss_mask=0.00175, loss_rad=0.00374, loss_sparse=0.00132, loss_tv_sdf=0.000698, lr_net=0.000934, lr_xyz=0.00467]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.87s/it]
# eval cost 10.73561978340149 s
# | 52499/180000 [1:45:34<4:09:21,  8.52it/s, loss=0.0527, loss_color=0.0327, loss_eikonal=0.000928, loss_gau=0.00145, loss_hessian=0, loss_mask=0.00166, loss_rad=0.00345, loss_sparse=0.00128, loss_tv_sdf=0.000723, lr_net=0.000916, lr_xyz=0.00458]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.88s/it]
# eval cost 10.736101865768433 s
# | 54999/180000 [1:50:38<4:03:39,  8.55it/s, loss=0.0649, loss_color=0.0334, loss_eikonal=0.00082, loss_gau=0.00137, loss_hessian=0, loss_mask=0.00136, loss_rad=0.00375, loss_sparse=0.00138, loss_tv_sdf=0.000688, lr_net=0.000897, lr_xyz=0.00449]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.87s/it]
# eval cost 10.727936506271362 s
# | 57499/180000 [1:55:43<3:59:19,  8.53it/s, loss=0.0603, loss_color=0.0334, loss_eikonal=0.00078, loss_gau=0.00138, loss_hessian=0, loss_mask=0.00226, loss_rad=0.0039, loss_sparse=0.00132, loss_tv_sdf=0.000712, lr_net=0.000878, lr_xyz=0.00439]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.88s/it]
# eval cost 10.741074562072754 s
# | 59999/180000 [2:00:48<3:54:36,  8.53it/s, loss=0.0588, loss_color=0.0329, loss_eikonal=0.000788, loss_gau=0.00133, loss_hessian=0, loss_mask=0.00216, loss_rad=0.0046, loss_sparse=0.00145, loss_tv_sdf=0.000712, lr_net=0.000858, lr_xyz=0.00429]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.88s/it]
# eval cost 10.742436408996582 s
# New best model psnr: 33.18873 previous 32.85542
# | 62499/180000 [2:05:52<3:51:18,  8.47it/s, loss=0.064, loss_color=0.0335, loss_eikonal=0.000819, loss_gau=0.00133, loss_hessian=0, loss_mask=0.00391, loss_rad=0.00466, loss_sparse=0.00145, loss_tv_sdf=0.000747, lr_net=0.000837, lr_xyz=0.00419]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.83s/it]
# eval cost 10.683481693267822 s
# | 64999/180000 [2:10:57<3:44:13,  8.55it/s, loss=0.0515, loss_color=0.0319, loss_eikonal=0.000715, loss_gau=0.00126, loss_hessian=0, loss_mask=0.00102, loss_rad=0.00286, loss_sparse=0.00124, loss_tv_sdf=0.000691, lr_net=0.000816, lr_xyz=0.00408]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.86s/it]
# eval cost 10.719793558120728 s
# | 67499/180000 [2:16:02<3:40:14,  8.51it/s, loss=0.0506, loss_color=0.0328, loss_eikonal=0.000689, loss_gau=0.00117, loss_hessian=0, loss_mask=0.00128, loss_rad=0.00374, loss_sparse=0.00145, loss_tv_sdf=0.000677, lr_net=0.000795, lr_xyz=0.00398]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.84s/it]
# eval cost 10.699793100357056 s
# | 69999/180000 [2:21:07<3:35:50,  8.49it/s, loss=0.0555, loss_color=0.033, loss_eikonal=0.000874, loss_gau=0.00115, loss_hessian=0, loss_mask=0.00134, loss_rad=0.0047, loss_sparse=0.0016, loss_tv_sdf=0.000688, lr_net=0.000773, lr_xyz=0.00387]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.88s/it]
# eval cost 10.74043893814087 s
# | 72499/180000 [2:26:11<3:30:05,  8.53it/s, loss=0.0461, loss_color=0.0323, loss_eikonal=0.000656, loss_gau=0.00116, loss_hessian=0, loss_mask=0.000704, loss_rad=0.00314, loss_sparse=0.00123, loss_tv_sdf=0.000684, lr_net=0.000751, lr_xyz=0.00376]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.86s/it]
# eval cost 10.720069885253906 s
# | 74999/180000 [2:31:16<3:26:06,  8.49it/s, loss=0.059, loss_color=0.0328, loss_eikonal=0.000771, loss_gau=0.00108, loss_hessian=0, loss_mask=0.00172, loss_rad=0.00353, loss_sparse=0.00141, loss_tv_sdf=0.000673, lr_net=0.000729, lr_xyz=0.00364]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.88s/it]
# eval cost 10.736103057861328 s
# | 77499/180000 [2:36:21<3:19:45,  8.55it/s, loss=0.0578, loss_color=0.0327, loss_eikonal=0.000649, loss_gau=0.00109, loss_hessian=0, loss_mask=0.00158, loss_rad=0.00231, loss_sparse=0.0012, loss_tv_sdf=0.000691, lr_net=0.000706, lr_xyz=0.00353]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.82s/it]
# eval cost 10.67701506614685 s
# | 79999/180000 [2:41:25<3:15:04,  8.54it/s, loss=0.0495, loss_color=0.0334, loss_eikonal=0.000636, loss_gau=0.00109, loss_hessian=0, loss_mask=0.0016, loss_rad=0.00357, loss_sparse=0.00136, loss_tv_sdf=0.00068, lr_net=0.000683, lr_xyz=0.00342]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.87s/it]
# eval cost 10.730619192123413 s
# | 82499/180000 [2:46:30<3:11:11,  8.50it/s, loss=0.0558, loss_color=0.0329, loss_eikonal=0.000574, loss_gau=0.00101, loss_hessian=0, loss_mask=0.00189, loss_rad=0.00318, loss_sparse=0.00142, loss_tv_sdf=0.000661, lr_net=0.00066, lr_xyz=0.0033]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.82s/it]
# eval cost 10.67344880104065 s
# | 84999/180000 [2:51:34<3:06:02,  8.51it/s, loss=0.0499, loss_color=0.0325, loss_eikonal=0.000573, loss_gau=0.00102, loss_hessian=0, loss_mask=0.00121, loss_rad=0.00334, loss_sparse=0.00136, loss_tv_sdf=0.000673, lr_net=0.000637, lr_xyz=0.00319]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.82s/it]
# eval cost 10.682565689086914 s
# | 87499/180000 [2:56:39<3:01:03,  8.51it/s, loss=0.0553, loss_color=0.0328, loss_eikonal=0.000673, loss_gau=0.000966, loss_hessian=0, loss_mask=0.00177, loss_rad=0.00311, loss_sparse=0.00141, loss_tv_sdf=0.000658, lr_net=0.000614, lr_xyz=0.00307]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.82s/it]
# eval cost 10.68443751335144 s
# | 89999/180000 [3:01:44<2:56:36,  8.49it/s, loss=0.0473, loss_color=0.033, loss_eikonal=0.000565, loss_gau=0.000924, loss_hessian=0, loss_mask=0.00188, loss_rad=0.00275, loss_sparse=0.00135, loss_tv_sdf=0.00064, lr_net=0.000591, lr_xyz=0.00295]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.83s/it]
# eval cost 10.684146165847778 s
# | 92499/180000 [3:06:48<2:51:13,  8.52it/s, loss=0.0559, loss_color=0.0338, loss_eikonal=0.000566, loss_gau=0.000907, loss_hessian=0, loss_mask=0.00208, loss_rad=0.00296, loss_sparse=0.0015, loss_tv_sdf=0.000655, lr_net=0.000567, lr_xyz=0.00284]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.85s/it]
# eval cost 10.71146535873413 s
# | 94999/180000 [3:11:53<2:45:47,  8.55it/s, loss=0.0493, loss_color=0.0335, loss_eikonal=0.000576, loss_gau=0.000883, loss_hessian=0, loss_mask=0.00132, loss_rad=0.00249, loss_sparse=0.00128, loss_tv_sdf=0.000641, lr_net=0.000544, lr_xyz=0.00272]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.82s/it]
# eval cost 10.687402963638306 s
# | 97499/180000 [3:16:58<2:39:56,  8.60it/s, loss=0.0507, loss_color=0.0326, loss_eikonal=0.000525, loss_gau=0.000888, loss_hessian=0, loss_mask=0.00117, loss_rad=0.0025, loss_sparse=0.00126, loss_tv_sdf=0.000637, lr_net=0.000521, lr_xyz=0.0026]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.85s/it]
# eval cost 10.707045793533325 s
# | 99999/180000 [3:22:02<2:36:18,  8.53it/s, loss=0.0489, loss_color=0.033, loss_eikonal=0.000426, loss_gau=0.000777, loss_hessian=0, loss_mask=0.000673, loss_rad=0.00227, loss_sparse=0.00129, loss_tv_sdf=0.000604, lr_net=0.000498, lr_xyz=0.00249]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.85s/it]
# eval cost 10.709136009216309 s
# | 102499/180000 [3:27:07<2:30:29,  8.58it/s, loss=0.0482, loss_color=0.0329, loss_eikonal=0.000477, loss_gau=0.000785, loss_hessian=0, loss_mask=0.00255, loss_rad=0.00296, loss_sparse=0.0014, loss_tv_sdf=0.000616, lr_net=0.000475, lr_xyz=0.00237]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.82s/it]
# eval cost 10.676626443862915 s
# | 104999/180000 [3:32:11<2:26:07,  8.55it/s, loss=0.0501, loss_color=0.0341, loss_eikonal=0.000419, loss_gau=0.000774, loss_hessian=0, loss_mask=0.00328, loss_rad=0.00375, loss_sparse=0.0014, loss_tv_sdf=0.000611, lr_net=0.000452, lr_xyz=0.00226]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.83s/it]
# eval cost 10.684238195419312 s
# | 107499/180000 [3:37:16<2:23:05,  8.44it/s, loss=0.0467, loss_color=0.0324, loss_eikonal=0.00042, loss_gau=0.000735, loss_hessian=0, loss_mask=0.00127, loss_rad=0.00243, loss_sparse=0.00152, loss_tv_sdf=0.000588, lr_net=0.00043, lr_xyz=0.00215]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.86s/it]
# eval cost 10.722161293029785 s
# | 109999/180000 [3:42:21<2:17:14,  8.50it/s, loss=0.0562, loss_color=0.0338, loss_eikonal=0.000429, loss_gau=0.000736, loss_hessian=0, loss_mask=0.00285, loss_rad=0.00247, loss_sparse=0.00126, loss_tv_sdf=0.000596, lr_net=0.000408, lr_xyz=0.00204]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.86s/it]
# eval cost 10.721216440200806 s
# | 112499/180000 [3:47:25<2:11:24,  8.56it/s, loss=0.0495, loss_color=0.0335, loss_eikonal=0.000391, loss_gau=0.000683, loss_hessian=0, loss_mask=0.00261, loss_rad=0.00261, loss_sparse=0.00128, loss_tv_sdf=0.000577, lr_net=0.000386, lr_xyz=0.00193]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.80s/it]
# eval cost 10.66530156135559 s
# | 114999/180000 [3:52:29<2:07:05,  8.52it/s, loss=0.0451, loss_color=0.0331, loss_eikonal=0.000353, loss_gau=0.000644, loss_hessian=0, loss_mask=0.00149, loss_rad=0.00273, loss_sparse=0.00131, loss_tv_sdf=0.000574, lr_net=0.000365, lr_xyz=0.00182]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.84s/it]
# eval cost 10.698805093765259 s
# | 117499/180000 [3:57:34<2:01:18,  8.59it/s, loss=0.0479, loss_color=0.0333, loss_eikonal=0.000301, loss_gau=0.000618, loss_hessian=0, loss_mask=0.00078, loss_rad=0.00259, loss_sparse=0.00131, loss_tv_sdf=0.000565, lr_net=0.000344, lr_xyz=0.00172]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.85s/it]
# eval cost 10.70660924911499 s
# | 119999/180000 [4:02:39<1:56:48,  8.56it/s, loss=0.051, loss_color=0.0334, loss_eikonal=0.000377, loss_gau=0.000613, loss_hessian=0, loss_mask=0.00203, loss_rad=0.00244, loss_sparse=0.00144, loss_tv_sdf=0.000562, lr_net=0.000323, lr_xyz=0.00162]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.83s/it]
# eval cost 10.684115886688232 s
# | 122499/180000 [4:07:43<1:52:09,  8.54it/s, loss=0.0396, loss_color=0.0317, loss_eikonal=0.000255, loss_gau=0.000557, loss_hessian=0, loss_mask=0.000635, loss_rad=0.00146, loss_sparse=0.00114, loss_tv_sdf=0.000538, lr_net=0.000304, lr_xyz=0.00152]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.84s/it]
# eval cost 10.705009937286377 s
# | 124999/180000 [4:12:48<1:48:16,  8.47it/s, loss=0.0478, loss_color=0.033, loss_eikonal=0.000317, loss_gau=0.000552, loss_hessian=0, loss_mask=0.00167, loss_rad=0.00231, loss_sparse=0.00136, loss_tv_sdf=0.000535, lr_net=0.000284, lr_xyz=0.00142]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.85s/it]
# eval cost 10.710005521774292 s
# | 127499/180000 [4:17:52<1:42:46,  8.51it/s, loss=0.0488, loss_color=0.0331, loss_eikonal=0.000303, loss_gau=0.000535, loss_hessian=0, loss_mask=0.00114, loss_rad=0.00171, loss_sparse=0.00125, loss_tv_sdf=0.00053, lr_net=0.000265, lr_xyz=0.00133]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.84s/it]
# eval cost 10.69870114326477 s
# | 129999/180000 [4:22:57<1:37:21,  8.56it/s, loss=0.0525, loss_color=0.0326, loss_eikonal=0.000267, loss_gau=0.000499, loss_hessian=0, loss_mask=0.00427, loss_rad=0.00132, loss_sparse=0.0012, loss_tv_sdf=0.000519, lr_net=0.000247, lr_xyz=0.00124]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.87s/it]
# eval cost 10.733896255493164 s
# | 132499/180000 [4:28:02<1:32:53,  8.52it/s, loss=0.0436, loss_color=0.0324, loss_eikonal=0.000247, loss_gau=0.000482, loss_hessian=0, loss_mask=0.000656, loss_rad=0.00209, loss_sparse=0.0012, loss_tv_sdf=0.000518, lr_net=0.00023, lr_xyz=0.00115]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.86s/it]
# eval cost 10.725264072418213 s
# | 134999/180000 [4:33:06<1:28:53,  8.44it/s, loss=0.0468, loss_color=0.0329, loss_eikonal=0.000227, loss_gau=0.000455, loss_hessian=0, loss_mask=0.0017, loss_rad=0.00199, loss_sparse=0.00142, loss_tv_sdf=0.000505, lr_net=0.000213, lr_xyz=0.00106]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.85s/it]
# eval cost 10.70694351196289 s
# | 137499/180000 [4:38:11<1:23:23,  8.49it/s, loss=0.0512, loss_color=0.0335, loss_eikonal=0.000258, loss_gau=0.00044, loss_hessian=0, loss_mask=0.00155, loss_rad=0.00245, loss_sparse=0.00145, loss_tv_sdf=0.0005, lr_net=0.000197, lr_xyz=0.000983]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.83s/it]
# eval cost 10.689317226409912 s
# | 139999/180000 [4:43:15<1:18:02,  8.54it/s, loss=0.0455, loss_color=0.033, loss_eikonal=0.000255, loss_gau=0.000416, loss_hessian=0, loss_mask=0.00172, loss_rad=0.00139, loss_sparse=0.00127, loss_tv_sdf=0.000494, lr_net=0.000181, lr_xyz=0.000906]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.89s/it]
# eval cost 10.748689413070679 s
# | 142499/180000 [4:48:20<1:13:03,  8.55it/s, loss=0.0471, loss_color=0.0328, loss_eikonal=0.000201, loss_gau=0.000394, loss_hessian=0, loss_mask=0.00413, loss_rad=0.00243, loss_sparse=0.00132, loss_tv_sdf=0.000483, lr_net=0.000167, lr_xyz=0.000833]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.85s/it]
# eval cost 10.701634407043457 s
# | 144999/180000 [4:53:25<1:08:16,  8.54it/s, loss=0.051, loss_color=0.0334, loss_eikonal=0.000213, loss_gau=0.000377, loss_hessian=0, loss_mask=0.00565, loss_rad=0.00223, loss_sparse=0.00136, loss_tv_sdf=0.00048, lr_net=0.000153, lr_xyz=0.000765]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.75s/it]
# eval cost 10.608899593353271 s
# | 147499/180000 [4:58:30<1:03:57,  8.47it/s, loss=0.0463, loss_color=0.0327, loss_eikonal=0.000187, loss_gau=0.000358, loss_hessian=0, loss_mask=0.0015, loss_rad=0.00198, loss_sparse=0.00141, loss_tv_sdf=0.000476, lr_net=0.00014, lr_xyz=0.0007]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.85s/it]
# eval cost 10.705352067947388 s
# | 149999/180000 [5:03:34<58:39,  8.52it/s, loss=0.0424, loss_color=0.0332, loss_eikonal=0.00021, loss_gau=0.000341, loss_hessian=0, loss_mask=0.000756, loss_rad=0.00192, loss_sparse=0.00139, loss_tv_sdf=0.000467, lr_net=0.000128, lr_xyz=0.000639]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.85s/it]
# eval cost 10.713085651397705 s
# | 152499/180000 [5:08:39<53:55,  8.50it/s, loss=0.0473, loss_color=0.0342, loss_eikonal=0.000174, loss_gau=0.000327, loss_hessian=0, loss_mask=0.00183, loss_rad=0.00203, loss_sparse=0.00147, loss_tv_sdf=0.000464, lr_net=0.000117, lr_xyz=0.000583]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.82s/it]
# eval cost 10.670604705810547 s
# | 154999/180000 [5:13:43<48:49,  8.53it/s, loss=0.0448, loss_color=0.0325, loss_eikonal=0.000181, loss_gau=0.000314, loss_hessian=0, loss_mask=0.00072, loss_rad=0.00113, loss_sparse=0.00121, loss_tv_sdf=0.00046, lr_net=0.000106, lr_xyz=0.000532]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.80s/it]
# eval cost 10.654364824295044 s
# | 157499/180000 [5:18:47<43:42,  8.58it/s, loss=0.0439, loss_color=0.0332, loss_eikonal=0.000161, loss_gau=0.000304, loss_hessian=0, loss_mask=0.00326, loss_rad=0.00152, loss_sparse=0.00123, loss_tv_sdf=0.000457, lr_net=9.69e-5, lr_xyz=0.000485]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.84s/it]
# eval cost 10.698322772979736 s
# | 159999/180000 [5:23:52<38:55,  8.57it/s, loss=0.0443, loss_color=0.0327, loss_eikonal=0.000147, loss_gau=0.000291, loss_hessian=0, loss_mask=0.00172, loss_rad=0.00138, loss_sparse=0.00128, loss_tv_sdf=0.000454, lr_net=8.85e-5, lr_xyz=0.000442]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.83s/it]
# eval cost 10.68964409828186 s
# | 162499/180000 [5:28:56<34:23,  8.48it/s, loss=0.0527, loss_color=0.0331, loss_eikonal=0.000158, loss_gau=0.000282, loss_hessian=0, loss_mask=0.00165, loss_rad=0.00195, loss_sparse=0.00125, loss_tv_sdf=0.00045, lr_net=8.1e-5, lr_xyz=0.000405]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.86s/it]
# eval cost 10.718225717544556 s
# | 164999/180000 [5:34:01<29:22,  8.51it/s, loss=0.0455, loss_color=0.033, loss_eikonal=0.000156, loss_gau=0.000271, loss_hessian=0, loss_mask=0.00213, loss_rad=0.00169, loss_sparse=0.00136, loss_tv_sdf=0.000445, lr_net=7.45e-5, lr_xyz=0.000372]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.77s/it]
# eval cost 10.629789113998413 s
# | 167499/180000 [5:39:05<24:27,  8.52it/s, loss=0.048, loss_color=0.033, loss_eikonal=0.00015, loss_gau=0.000262, loss_hessian=0, loss_mask=0.00121, loss_rad=0.00159, loss_sparse=0.0014, loss_tv_sdf=0.000443, lr_net=6.89e-5, lr_xyz=0.000345]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.87s/it]
# eval cost 10.729980945587158 s
# | 169999/180000 [5:44:10<19:30,  8.54it/s, loss=0.0483, loss_color=0.0343, loss_eikonal=0.000145, loss_gau=0.000255, loss_hessian=0, loss_mask=0.00242, loss_rad=0.00161, loss_sparse=0.00136, loss_tv_sdf=0.00044, lr_net=6.44e-5, lr_xyz=0.000322]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.84s/it]
# eval cost 10.693308353424072 s
# | 172499/180000 [5:49:15<14:40,  8.52it/s, loss=0.048, loss_color=0.0331, loss_eikonal=0.00015, loss_gau=0.00025, loss_hessian=0, loss_mask=0.000878, loss_rad=0.00164, loss_sparse=0.00139, loss_tv_sdf=0.000439, lr_net=6.08e-5, lr_xyz=0.000304]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.84s/it]
# eval cost 10.69688105583191 s
# | 174999/180000 [5:54:19<09:48,  8.49it/s, loss=0.0442, loss_color=0.0327, loss_eikonal=0.000132, loss_gau=0.000246, loss_hessian=0, loss_mask=0.00235, loss_rad=0.00172, loss_sparse=0.00148, loss_tv_sdf=0.000437, lr_net=5.83e-5, lr_xyz=0.000291]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.84s/it]
# eval cost 10.702118158340454 s
# | 177499/180000 [5:59:24<04:54,  8.50it/s, loss=0.0432, loss_color=0.0335, loss_eikonal=0.000138, loss_gau=0.000242, loss_hessian=0, loss_mask=0.00407, loss_rad=0.00138, loss_sparse=0.00143, loss_tv_sdf=0.000435, lr_net=5.68e-5, lr_xyz=0.000284]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.83s/it]
# eval cost 10.688953161239624 s
# | 179999/180000 [6:04:29<00:00,  8.57it/s, loss=0.0421, loss_color=0.0326, loss_eikonal=0.000159, loss_gau=0.000241, loss_hessian=0, loss_mask=0.00114, loss_rad=0.00117, loss_sparse=0.0012, loss_tv_sdf=0.000436, lr_net=5.63e-5, lr_xyz=0.000281]
# 0it [00:00, ?it/s]
# 1it [00:09,  9.84s/it]
# eval cost 10.703763008117676 s
# | 180000/180000 [6:04:40<00:00,  8.23it/s, loss=0.049, loss_color=0.0339, loss_eikonal=0.000173, loss_gau=0.000241, loss_hessian=0, loss_mask=0.00257, loss_rad=0.0019, loss_sparse=0.00145, loss_tv_sdf=0.000436, lr_net=5.63e-5, lr_xyz=0.000281]
# Training done, costs 6 hours, 5 minutes and 13.5 seconds.
