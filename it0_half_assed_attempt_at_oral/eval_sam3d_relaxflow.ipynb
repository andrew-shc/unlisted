# %%
# from pathlib import Path
# import sys
# sys.path.append(str(Path("~/Documents/vggt2/digitizing_reality/relaxflow").expanduser()))

# %% [markdown]
# ```sh
# FOLDER="test_data/bike_three_wheels"
# OUTNAME=$(basename $FOLDER)
# IMG=${FOLDER}/input.png
# MSK=${FOLDER}/mask.png
# # PRI="${FOLDER}/prior1.png ${FOLDER}/prior2.png ${FOLDER}/prior3.png ${FOLDER}/prior4.png"
# PRI=${FOLDER}/prior.jpg
# python demo_relaxflow.py --image $IMG --mask $MSK --prior-images $PRI --output-name $OUTNAME --render-backend gsplat
# ```

# %%
from pathlib import Path
import subprocess

prior1A = "/home/ahc/Documents/vggt2/digitizing_reality/eval_data/DUCK/pred0/A yellow rubber duck with a pirate eye patch on its left, white background, centered, 3D render.png"
prior1B = "/home/ahc/Documents/vggt2/digitizing_reality/eval_data/DUCK/pred1/A yellow rubber duck with left eye blue right eye white, white background, centered, 3D render.png"
prior1C = "/home/ahc/Documents/vggt2/digitizing_reality/eval_data/DUCK/pred2/A yellow rubber duck with the left eye replaced by a googlie eye, white background, centered, 3D render.png"
prior2A = "/home/ahc/Documents/vggt2/digitizing_reality/eval_data/FLIP_CALENDAR_RED/pred0/Red flip paper calendar with many binder rings showing month of March, white background, centered, 3D render.png"
prior2B = "/home/ahc/Documents/vggt2/digitizing_reality/eval_data/FLIP_CALENDAR_RED/pred1/Red flip paper calendar with many binder rings showing month of April (on a yellow paper on top of the red flip calendar), white background, centered, 3D render.png"
prior2C = "/home/ahc/Documents/vggt2/digitizing_reality/eval_data/FLIP_CALENDAR_RED/pred2/Red flip paper calendar with many binder rings showing with two large flip placards representing the month and the day, white background, centered, 3D render.png"

masked_image1 = "/home/ahc/Documents/vggt2/digitizing_reality/eval_data/DUCK/gt_obs_segmented/frame_000000.png"
masked_image2 = "/home/ahc/Documents/vggt2/digitizing_reality/eval_data/FLIP_CALENDAR_RED/gt_obs_segmented/frame_000001.png"

for masked_img, prior, path in [
    # (masked_image1, prior1A, "DUCK/pred0"),
    # (masked_image1, prior1B, "DUCK/pred1"),
    # (masked_image1, prior1C, "DUCK/pred2"),
    # (masked_image2, prior2A, "FLIP_CALENDAR_RED/pred0"),
    (masked_image2, prior2B, "FLIP_CALENDAR_RED/pred1"),
    (masked_image2, prior2C, "FLIP_CALENDAR_RED/pred2"),
]:
    relaxflow_dir = Path("/home/ahc/Documents/vggt2/RelaxFlow")
    out_folder = Path(f"/home/ahc/Documents/vggt2/digitizing_reality/eval_data/{path}/SAM3D")

    cmd = [
        "python", "demo_relaxflow.py",
        "--image", masked_img,
        # "--mask", str(folder / "mask.png"),
        "--prior-images", Path(prior),
        "--output-name", out_folder,
        "--render-backend", "gsplat",
    ]

    subprocess.run(cmd, cwd=relaxflow_dir, check=True)
# Out:
# /home/ahc/miniconda3/envs/relax-flow/lib/python3.11/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Warp 1.12.0 initialized:
#    CUDA Toolkit 12.9, Driver 12.8
#    Devices:
#      "cpu"      : "x86_64"
#      "cuda:0"   : "NVIDIA GeForce RTX 3090 Ti" (22 GiB, sm_86, mempool enabled)
#    Kernel cache:
#      /home/ahc/.cache/warp/1.12.0
# 2026-04-06 21:23:35.741 | INFO     | sam3d_objects.pipeline.inference_pipeline:set_attention_backend:14 - GPU name is NVIDIA GeForce RTX 3090 Ti
# 2026-04-06 21:23:36.920 | INFO     | sam3d_objects.model.backbone.tdfy_dit.modules.sparse:__from_env:39 - [SPARSE] Backend: spconv, Attention: sdpa
# ...

# %%
# modified code in relaxflow's sam3d to prevent splitting on commas ","
