# %%
# !python WNNC/main_wnnc.py image_vggt_pointcloud.ply --width_config l0 --tqdm
# Out:
# num_nodes: 1853565, num_leaves: 1218286, tree depth: 15
# tree_depth*num_points: 18275040, stdvec_node2point_index.size(): 14592326
# [LOG] You are using width config l0 width wsmin = 0.002, wsmax = 0.016
# 100%|███████████████████████████████████████████| 40/40 [01:33<00:00,  2.35s/it]
# [LOG] time_preproc: 0.5702807903289795
# [LOG] time_main: 106.29021620750427
# [LOG] mem: 13788.60546875

# %%
# !python WNNC/main_wnnc.py image_vggt_pointcloud.ply --width_config l1 --tqdm
# Out:
# num_nodes: 1853565, num_leaves: 1218286, tree depth: 15
# tree_depth*num_points: 18275040, stdvec_node2point_index.size(): 14592326
# [LOG] You are using width config l1 width wsmin = 0.01, wsmax = 0.04
# 100%|███████████████████████████████████████████| 40/40 [01:31<00:00,  2.29s/it]
# [LOG] time_preproc: 0.5643713474273682
# [LOG] time_main: 103.6985068321228
# [LOG] mem: 13727.53125

# %%
# !./WNNC/main_GaussRecon_cuda -i results//image_vggt_pointcloud.xyz -o results/pointcloud_to_mesh.ply -a 16 -w 0.01
# Out:
# [In PGROctree] Max Depth: 10
# [LOG] time (build tree): 3.64148
# [DEBUG] samplePoints.size(): 1218336
# [DEBUG] N_sample_pts: 1218336
# [DEBUG] wn_pts_input.size(): 3655008
# [DEBUG] num_points: 1218336
# num_nodes: 1853576, num_leaves: 1218286, tree depth: 15
# tree_depth*num_points: 18275040, stdvec_node2point_index.size(): 14592344
# [DEBUG] N_grid: 4649919
# [DEBUG] Isovalue: -2.02312
# [DEBUG] initLeaf done:
# [DEBUG] num leaves: 3784313
# [DEBUG] triangles got: -2.02312
# [DEBUG] Polygon Written to results/pointcloud_to_mesh.ply

# %%
# !python WNNC/main_wnnc.py results_dtu_eval/vggt_aligned.ply --width_config l1 --tqdm
# !./WNNC/main_GaussRecon_cuda -i results//vggt_aligned.xyz -o results_dtu_eval/pointcloud_to_mesh.ply -a 16 -w 0.01
# Out:
# num_nodes: 1109994, num_leaves: 735553, tree depth: 15
# tree_depth*num_points: 11033400, stdvec_node2point_index.size(): 8029563
# [LOG] You are using width config l1 width wsmin = 0.01, wsmax = 0.04
# 100%|███████████████████████████████████████████| 40/40 [00:52<00:00,  1.31s/it]
# [LOG] time_preproc: 0.38088417053222656
# [LOG] time_main: 59.464595317840576
# [LOG] mem: 2780.6875
# [In PGROctree] Max Depth: 10
# [LOG] time (build tree): 5.59648
# [DEBUG] samplePoints.size(): 735560
# [DEBUG] N_sample_pts: 735560
# [DEBUG] wn_pts_input.size(): 2206680
# [DEBUG] num_points: 735560
# num_nodes: 1110007, num_leaves: 735553, tree depth: 15
# tree_depth*num_points: 11033400, stdvec_node2point_index.size(): 8029589
# [DEBUG] N_grid: 7490865
# [DEBUG] Isovalue: -1.12427
# [DEBUG] initLeaf done:
# [DEBUG] num leaves: 6264700
# [DEBUG] triangles got: -1.12427
# [DEBUG] Polygon Written to results_dtu_eval/pointcloud_to_mesh.ply

# %%
# !python WNNC/main_wnnc.py image_vggt_pointcloud.ply --width_config l1 --tqdm
# !./WNNC/main_GaussRecon_cuda -i results//image_vggt_pointcloud.xyz -o results/pointcloud_to_mesh.ply -a 16 -w 0.01
# Out:
# [In PGROctree] Max Depth: 10
# [LOG] time (build tree): 5.60444
# [DEBUG] samplePoints.size(): 735560
# [DEBUG] N_sample_pts: 735560
# [DEBUG] wn_pts_input.size(): 2206680
# [DEBUG] num_points: 735560
# num_nodes: 1110007, num_leaves: 735553, tree depth: 15
# tree_depth*num_points: 11033400, stdvec_node2point_index.size(): 8029589
# [DEBUG] N_grid: 7490865
# [DEBUG] Isovalue: -1.12427
# [DEBUG] initLeaf done:
# [DEBUG] num leaves: 6264700
# [DEBUG] triangles got: -1.12427
# [DEBUG] Polygon Written to results_dtu_eval/pointcloud_to_mesh.ply
