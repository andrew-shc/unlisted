# %%
"""
https://github.com/mikedh/trimesh/releases/tag/4.10.0

must be <4.10.0 to have remove_degenerate_faces() method.


Blender linux <4.0 is needed
OR

Fixed. Blender 4.0 moved OBJ import/export from import_scene.obj/export_scene.obj to wm.obj_import/wm.obj_export, and renamed the export flags (use_normals → export_normals, use_materials → export_materials, use_selection → export_selected_objects).

""";

# !pip install trimesh==4.9
# Out:
# '\nhttps://github.com/mikedh/trimesh/releases/tag/4.10.0\n\nmust be <4.10.0 to have remove_degenerate_faces() method.\n\n\nBlender linux <4.0 is needed\nOR\n\n'

# %%
# !python DigitalTwinCatalog/neural_pbir/scripts/preprocess/stanford_orb.py /home/ahc/Datasets/Stanford-ORB/blender_HDR/baking_scene001
# Out:
# /home/ahc/Documents/metrology_ir/DigitalTwinCatalog/neural_pbir/scripts/preprocess/stanford_orb.py:49: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   mask = imageio.imread(
# Result is saved to /home/ahc/Datasets/Stanford-ORB/blender_HDR/baking_scene001/cameras.json
# Result is saved to /home/ahc/Datasets/Stanford-ORB/blender_HDR/baking_scene001/cameras_novel/baking_scene002_0060.json
# Result is saved to /home/ahc/Datasets/Stanford-ORB/blender_HDR/baking_scene001/cameras_novel/baking_scene002_0061.json
# Result is saved to /home/ahc/Datasets/Stanford-ORB/blender_HDR/baking_scene001/cameras_novel/baking_scene002_0062.json
# Result is saved to /home/ahc/Datasets/Stanford-ORB/blender_HDR/baking_scene001/cameras_novel/baking_scene002_0063.json
# Result is saved to /home/ahc/Datasets/Stanford-ORB/blender_HDR/baking_scene001/cameras_novel/baking_scene002_0064.json
# Result is saved to /home/ahc/Datasets/Stanford-ORB/blender_HDR/baking_scene001/cameras_novel/baking_scene002_0065.json
# Result is saved to /home/ahc/Datasets/Stanford-ORB/blender_HDR/baking_scene001/cameras_novel/baking_scene002_0066.json
# Result is saved to /home/ahc/Datasets/Stanford-ORB/blender_HDR/baking_scene001/cameras_novel/baking_scene002_0067.json
# Result is saved to /home/ahc/Datasets/Stanford-ORB/blender_HDR/baking_scene001/cameras_novel/baking_scene002_0068.json
# Result is saved to /home/ahc/Datasets/Stanford-ORB/blender_HDR/baking_scene001/cameras_novel/baking_scene002_0069.json
# Result is saved to /home/ahc/Datasets/Stanford-ORB/blender_HDR/baking_scene001/cameras_novel/baking_scene003_0059.json
# Result is saved to /home/ahc/Datasets/Stanford-ORB/blender_HDR/baking_scene001/cameras_novel/baking_scene003_0060.json
# Result is saved to /home/ahc/Datasets/Stanford-ORB/blender_HDR/baking_scene001/cameras_novel/baking_scene003_0061.json
# Result is saved to /home/ahc/Datasets/Stanford-ORB/blender_HDR/baking_scene001/cameras_novel/baking_scene003_0062.json
# Result is saved to /home/ahc/Datasets/Stanford-ORB/blender_HDR/baking_scene001/cameras_novel/baking_scene003_0063.json
# Result is saved to /home/ahc/Datasets/Stanford-ORB/blender_HDR/baking_scene001/cameras_novel/baking_scene003_0064.json
# Result is saved to /home/ahc/Datasets/Stanford-ORB/blender_HDR/baking_scene001/cameras_novel/baking_scene003_0065.json
# Result is saved to /home/ahc/Datasets/Stanford-ORB/blender_HDR/baking_scene001/cameras_novel/baking_scene003_0066.json
# Result is saved to /home/ahc/Datasets/Stanford-ORB/blender_HDR/baking_scene001/cameras_novel/baking_scene003_0067.json
# Result is saved to /home/ahc/Datasets/Stanford-ORB/blender_HDR/baking_scene001/cameras_novel/baking_scene003_0068.json

# %%
NPBIR="./DigitalTwinCatalog/neural_pbir"
# !python {NPBIR}/neural_surface_recon/run_template.py --template {NPBIR}/neural_surface_recon/configs/template_stanford_orb.py --savemem /home/ahc/Datasets/Stanford-ORB/blender_HDR/baking_scene001/
# Out:
# /home/ahc/miniconda3/envs/metrology_ir/lib/python3.11/site-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# ==> disable pre-load all training data to save GPU memory
# /home/ahc/miniconda3/envs/metrology_ir/lib/python3.11/site-packages/torch/__init__.py:955: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:432.)
#   _C._set_default_tensor_type(t)
# Start loading dataset...
# 100%|██████████████████████████████████████████| 70/70 [00:00<00:00, 336.50it/s]
# Finish loading dataset in 0.4 sec.
# Loaded dataset: (70, 512, 512, 3) /home/ahc/Datasets/Stanford-ORB/blender_HDR/baking_scene001
# # train: 60
# # test: 10 [60 61 62 63 64 65 66 67 68 69]
# train: start
# compute_bbox: start
# compute_bbox: xyz_min tensor([-0.6000, -0.6000, -0.6000])
# compute_bbox: xyz_max tensor([0.6000, 0.6000, 0.6000])
# compute_bbox: finish
# train: skip coarse geometry searching
# scene_rep_reconstruction (fine): train from scratch
# VolRepr-fg: voxel_size       tensor(0.0320)
# VolRepr-fg: world_size       tensor([37, 37, 37])
# VolRepr-fg: world_size_k0    tensor([37, 37, 37])
# VolRepr-fg: voxel_size_base  tensor(0.0075)
# VolRepr-fg: voxel_size_ratio tensor(4.2667)
# VolRepr-fg: geometry grid DenseGrid(channels=1, world_size=[37, 37, 37])
# VolRepr-fg: feature voxel grid DenseGrid(channels=12, world_size=[37, 37, 37])
# VolRepr-fg: mlp MLP_torch(
#   (mlp): Sequential(
#     (0): Linear(in_features=39, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Sequential(
#       (0): Linear(in_features=128, out_features=128, bias=True)
#       (1): ReLU(inplace=True)
#     )
#     (3): Linear(in_features=128, out_features=3, bias=True)
#   )
# )
# VolRepr-bg: set density bias shift to tensor([-4.5951], device='cpu')
# VolRepr-bg: voxel_size       tensor(0.5120)
# VolRepr-bg: world_size       tensor([37, 37, 37])
# VolRepr-bg: world_size_k0    tensor([37, 37, 37])
# VolRepr-bg: voxel_size_base  tensor(0.1200)
# VolRepr-bg: voxel_size_ratio tensor(4.2667)
# VolRepr-bg: geometry grid DenseGrid(channels=1, world_size=[37, 37, 37])
# VolRepr-bg: feature voxel grid DenseGrid(channels=8, world_size=[37, 37, 37])
# VolRepr-bg: mlp MLP_tcnn(
#   (mlp): Network(n_input_dims=35, n_output_dims=3, seed=1337, dtype=torch.float16, hyperparams={'encoding': {'offset': 0.0, 'otype': 'Identity', 'scale': 1.0}, 'network': {'activation': 'ReLU', 'n_hidden_layers': 2, 'n_neurons': 64, 'otype': 'FullyFusedMLP', 'output_activation': 'None'}, 'otype': 'NetworkWithInputEncoding'})
# )
# create_optimizer_or_freeze_model: param density lr 0.003
# create_optimizer_or_freeze_model: param k0 lr 0.1
# create_optimizer_or_freeze_model: param sdf_scale freeze
# create_optimizer_or_freeze_model: param rgbnet lr 0.001
# create_optimizer_or_freeze_model: param bg_model.density lr 0.1
# create_optimizer_or_freeze_model: param bg_model.k0 lr 0.1
# create_optimizer_or_freeze_model: param bg_model.rgbnet lr 0.001
# get_training_rays_offline_sampler: start
# get_training_rays_offline_sampler: ratio tensor(0.9082)
# get_training_rays_offline_sampler: finish (eps time: 0.14756464958190918 sec)
# loss weight_main 1.0
# loss weight_rgbper 0.001
# loss weight_entropy_last 0
# loss weight_mask 0.001
# loss weight_laplace 1e-08
#   0%|▏                                       | 97/25000 [00:02<08:19, 49.88it/s]geo grid grad stat: %=0.9996 mu=-1.57e-08 mu=6.45e-08 std=1.12e-07 min=-2.07e-06 max=1.60e-06
#   1%|▎                                      | 197/25000 [00:04<08:02, 51.42it/s]geo grid grad stat: %=0.9983 mu=-4.98e-10 mu=4.99e-08 std=1.00e-07 min=-3.32e-06 max=1.66e-06
#   1%|▍                                      | 299/25000 [00:05<07:47, 52.81it/s]geo grid grad stat: %=0.9956 mu=1.45e-09 mu=3.05e-08 std=6.38e-08 min=-1.19e-06 max=9.96e-07
#   2%|▌                                      | 395/25000 [00:07<07:35, 54.03it/s]geo grid grad stat: %=0.9896 mu=-5.52e-10 mu=1.98e-08 std=4.48e-08 min=-1.13e-06 max=8.95e-07
#   2%|▊                                      | 497/25000 [00:09<07:11, 56.76it/s]VolRepr-fg: sharpness 44.95
# VolRepr-fg: occupancy mask activated ratio 1.0000 => 1.0000
# VolRepr-bg: occupancy mask activated ratio 1.0000 => 1.0000
# geo grid grad stat: %=0.9812 mu=-2.09e-09 mu=1.47e-08 std=3.43e-08 min=-9.95e-07 max=4.85e-07
# scene_rep_reconstruction (fine): iter    500 / Loss: 0.002037789 / PSNR: 20.70 / Eps: 00:00:10
#   2%|▉                                      | 599/25000 [00:11<06:54, 58.94it/s]geo grid grad stat: %=0.9714 mu=2.11e-09 mu=1.18e-08 std=2.89e-08 min=-6.91e-07 max=4.73e-07
#   3%|█                                      | 695/25000 [00:12<06:36, 61.24it/s]geo grid grad stat: %=0.9610 mu=-1.28e-10 mu=1.06e-08 std=2.61e-08 min=-6.34e-07 max=4.95e-07
#   3%|█▏                                     | 793/25000 [00:14<06:27, 62.48it/s]geo grid grad stat: %=0.9521 mu=5.13e-10 mu=1.01e-08 std=2.62e-08 min=-8.47e-07 max=5.84e-07
#   4%|█▍                                     | 898/25000 [00:16<06:17, 63.80it/s]geo grid grad stat: %=0.9456 mu=2.83e-10 mu=9.87e-09 std=2.60e-08 min=-9.83e-07 max=5.55e-07
#   4%|█▌                                     | 996/25000 [00:17<06:13, 64.23it/s]VolRepr-fg: scale_volume_grid start
# VolRepr-fg: voxel_size       tensor(0.0254)
# VolRepr-fg: world_size       tensor([47, 47, 47])
# VolRepr-fg: world_size_k0    tensor([47, 47, 47])
# VolRepr-fg: voxel_size_base  tensor(0.0075)
# VolRepr-fg: voxel_size_ratio tensor(3.3865)
# VolRepr-fg: scale_volume_grid scale world_size from [37, 37, 37] to [47, 47, 47]
# VolRepr-fg: scale_volume_grid finish
# VolRepr-bg: scale_volume_grid start
# VolRepr-bg: voxel_size       tensor(0.4064)
# VolRepr-bg: world_size       tensor([47, 47, 47])
# VolRepr-bg: world_size_k0    tensor([47, 47, 47])
# VolRepr-bg: voxel_size_base  tensor(0.1200)
# VolRepr-bg: voxel_size_ratio tensor(3.3865)
# VolRepr-bg: scale_volume_grid scale world_size from [37, 37, 37] to [47, 47, 47]
# VolRepr-bg: scale_volume_grid finish
# create_optimizer_or_freeze_model: param density lr 0.002495291313308013
# create_optimizer_or_freeze_model: param k0 lr 0.09120108393559098
# create_optimizer_or_freeze_model: param sdf_scale freeze
# create_optimizer_or_freeze_model: param rgbnet lr 0.0009120108393559097
# create_optimizer_or_freeze_model: param bg_model.density lr 0.09120108393559098
# create_optimizer_or_freeze_model: param bg_model.k0 lr 0.09120108393559098
# create_optimizer_or_freeze_model: param bg_model.rgbnet lr 0.0009120108393559097
# geo grid grad stat: %=0.9094 mu=1.83e-09 mu=6.28e-09 std=1.65e-08 min=-3.12e-07 max=5.05e-07
# scene_rep_reconstruction (fine): iter   1000 / Loss: 0.002240320 / PSNR: 23.64 / Eps: 00:00:18
#   4%|█▋                                    | 1099/25000 [00:19<07:36, 52.34it/s]geo grid grad stat: %=0.9165 mu=1.97e-10 mu=6.37e-09 std=1.80e-08 min=-1.26e-06 max=3.76e-07
#   5%|█▊                                    | 1195/25000 [00:21<07:32, 52.56it/s]geo grid grad stat: %=0.9271 mu=-1.11e-10 mu=6.03e-09 std=1.79e-08 min=-6.63e-07 max=4.45e-07
#   5%|█▉                                    | 1297/25000 [00:23<07:20, 53.78it/s]geo grid grad stat: %=0.9295 mu=-4.32e-10 mu=5.67e-09 std=1.66e-08 min=-4.86e-07 max=5.34e-07
#   6%|██▏                                   | 1399/25000 [00:25<06:56, 56.66it/s]geo grid grad stat: %=0.9322 mu=3.54e-11 mu=5.40e-09 std=1.55e-08 min=-6.13e-07 max=3.17e-07
#   6%|██▎                                   | 1495/25000 [00:27<06:47, 57.63it/s]VolRepr-fg: sharpness 94.95
# VolRepr-fg: occupancy mask activated ratio 0.9995 => 0.9985
# VolRepr-bg: occupancy mask activated ratio 1.0000 => 1.0000
# geo grid grad stat: %=0.9328 mu=1.19e-10 mu=5.12e-09 std=1.54e-08 min=-6.27e-07 max=3.41e-07
# scene_rep_reconstruction (fine): iter   1500 / Loss: 0.001048000 / PSNR: 24.07 / Eps: 00:00:27
#   6%|██▍                                   | 1597/25000 [00:28<06:33, 59.44it/s]geo grid grad stat: %=0.9325 mu=1.21e-10 mu=5.09e-09 std=1.63e-08 min=-6.96e-07 max=5.35e-07
#   7%|██▌                                   | 1693/25000 [00:30<06:10, 62.90it/s]geo grid grad stat: %=0.9321 mu=-1.99e-10 mu=5.28e-09 std=1.72e-08 min=-6.59e-07 max=3.73e-07
#   7%|██▋                                   | 1798/25000 [00:31<05:47, 66.78it/s]geo grid grad stat: %=0.9300 mu=3.94e-10 mu=4.88e-09 std=1.59e-08 min=-6.64e-07 max=4.33e-07
#   8%|██▉                                   | 1894/25000 [00:33<05:24, 71.15it/s]geo grid grad stat: %=0.9282 mu=-6.10e-11 mu=4.77e-09 std=1.50e-08 min=-9.16e-07 max=5.00e-07
#   8%|███                                   | 1998/25000 [00:34<05:01, 76.21it/s]VolRepr-fg: scale_volume_grid start
# VolRepr-fg: voxel_size       tensor(0.0202)
# VolRepr-fg: world_size       tensor([59, 59, 59])
# VolRepr-fg: world_size_k0    tensor([59, 59, 59])
# VolRepr-fg: voxel_size_base  tensor(0.0075)
# VolRepr-fg: voxel_size_ratio tensor(2.6878)
# VolRepr-fg: scale_volume_grid scale world_size from [47, 47, 47] to [59, 59, 59]
# VolRepr-fg: scale_volume_grid finish
# VolRepr-bg: scale_volume_grid start
# VolRepr-bg: voxel_size       tensor(0.3225)
# VolRepr-bg: world_size       tensor([59, 59, 59])
# VolRepr-bg: world_size_k0    tensor([59, 59, 59])
# VolRepr-bg: voxel_size_base  tensor(0.1200)
# VolRepr-bg: voxel_size_ratio tensor(2.6878)
# VolRepr-bg: scale_volume_grid scale world_size from [47, 47, 47] to [59, 59, 59]
# VolRepr-bg: scale_volume_grid finish
# create_optimizer_or_freeze_model: param density lr 0.0020754929127568098
# create_optimizer_or_freeze_model: param k0 lr 0.0831763771102671
# create_optimizer_or_freeze_model: param sdf_scale freeze
# create_optimizer_or_freeze_model: param rgbnet lr 0.000831763771102671
# create_optimizer_or_freeze_model: param bg_model.density lr 0.0831763771102671
# create_optimizer_or_freeze_model: param bg_model.k0 lr 0.0831763771102671
# create_optimizer_or_freeze_model: param bg_model.rgbnet lr 0.000831763771102671
# geo grid grad stat: %=0.8655 mu=4.69e-10 mu=3.36e-09 std=1.07e-08 min=-3.60e-07 max=5.65e-07
# scene_rep_reconstruction (fine): iter   2000 / Loss: 0.001790581 / PSNR: 25.52 / Eps: 00:00:35
#   8%|███▏                                  | 2097/25000 [00:36<06:11, 61.61it/s]geo grid grad stat: %=0.8735 mu=-2.24e-10 mu=3.97e-09 std=1.35e-08 min=-7.32e-07 max=7.14e-07
#   9%|███▎                                  | 2195/25000 [00:37<06:05, 62.31it/s]geo grid grad stat: %=0.8741 mu=-1.57e-10 mu=3.38e-09 std=1.18e-08 min=-6.70e-07 max=5.09e-07
#   9%|███▍                                  | 2293/25000 [00:39<05:55, 63.83it/s]geo grid grad stat: %=0.8689 mu=6.68e-11 mu=3.10e-09 std=1.10e-08 min=-6.63e-07 max=4.24e-07
#  10%|███▋                                  | 2398/25000 [00:41<05:49, 64.58it/s]geo grid grad stat: %=0.8622 mu=-1.84e-10 mu=2.92e-09 std=1.13e-08 min=-5.27e-07 max=4.45e-07
#  10%|███▊                                  | 2496/25000 [00:42<05:42, 65.77it/s]VolRepr-fg: sharpness 144.95
# VolRepr-fg: occupancy mask activated ratio 0.9976 => 0.9969
# VolRepr-bg: occupancy mask activated ratio 1.0000 => 1.0000
# geo grid grad stat: %=0.8588 mu=2.64e-11 mu=2.64e-09 std=1.03e-08 min=-6.02e-07 max=3.71e-07
# scene_rep_reconstruction (fine): iter   2500 / Loss: 0.000773384 / PSNR: 25.22 / Eps: 00:00:43
#  10%|███▉                                  | 2594/25000 [00:44<05:37, 66.38it/s]geo grid grad stat: %=0.8521 mu=4.89e-11 mu=2.46e-09 std=9.26e-09 min=-6.78e-07 max=5.76e-07
#  11%|████                                  | 2699/25000 [00:45<05:31, 67.33it/s]geo grid grad stat: %=0.8459 mu=9.13e-11 mu=2.30e-09 std=8.70e-09 min=-6.40e-07 max=3.13e-07
#  11%|████▎                                 | 2797/25000 [00:47<05:20, 69.24it/s]geo grid grad stat: %=0.8403 mu=-4.01e-11 mu=2.19e-09 std=8.85e-09 min=-5.03e-07 max=2.52e-07
#  12%|████▍                                 | 2895/25000 [00:48<05:15, 70.09it/s]geo grid grad stat: %=0.8324 mu=3.18e-11 mu=2.07e-09 std=8.24e-09 min=-5.62e-07 max=3.00e-07
#  12%|████▌                                 | 2999/25000 [00:49<05:12, 70.39it/s]VolRepr-fg: scale_volume_grid start
# VolRepr-fg: voxel_size       tensor(0.0160)
# VolRepr-fg: world_size       tensor([75, 75, 75])
# VolRepr-fg: world_size_k0    tensor([75, 75, 75])
# VolRepr-fg: voxel_size_base  tensor(0.0075)
# VolRepr-fg: voxel_size_ratio tensor(2.1333)
# VolRepr-fg: scale_volume_grid scale world_size from [59, 59, 59] to [75, 75, 75]
# VolRepr-fg: scale_volume_grid finish
# VolRepr-bg: scale_volume_grid start
# VolRepr-bg: voxel_size       tensor(0.2560)
# VolRepr-bg: world_size       tensor([75, 75, 75])
# VolRepr-bg: world_size_k0    tensor([75, 75, 75])
# VolRepr-bg: voxel_size_base  tensor(0.1200)
# VolRepr-bg: voxel_size_ratio tensor(2.1333)
# VolRepr-bg: scale_volume_grid scale world_size from [59, 59, 59] to [75, 75, 75]
# VolRepr-bg: scale_volume_grid finish
# create_optimizer_or_freeze_model: param density lr 0.001726319812011471
# create_optimizer_or_freeze_model: param k0 lr 0.07585775750291839
# create_optimizer_or_freeze_model: param sdf_scale freeze
# create_optimizer_or_freeze_model: param rgbnet lr 0.0007585775750291837
# create_optimizer_or_freeze_model: param bg_model.density lr 0.07585775750291839
# create_optimizer_or_freeze_model: param bg_model.k0 lr 0.07585775750291839
# create_optimizer_or_freeze_model: param bg_model.rgbnet lr 0.0007585775750291837
# geo grid grad stat: %=0.7130 mu=1.05e-10 mu=1.43e-09 std=5.55e-09 min=-5.89e-07 max=4.05e-07
# scene_rep_reconstruction (fine): iter   3000 / Loss: 0.001365857 / PSNR: 26.66 / Eps: 00:00:50
#  12%|████▋                                 | 3099/25000 [00:51<06:41, 54.62it/s]geo grid grad stat: %=0.7392 mu=-1.50e-10 mu=1.73e-09 std=7.22e-09 min=-5.30e-07 max=2.76e-07
#  13%|████▊                                 | 3195/25000 [00:53<06:30, 55.89it/s]geo grid grad stat: %=0.7270 mu=2.77e-12 mu=1.42e-09 std=6.65e-09 min=-7.25e-07 max=3.70e-07
#  13%|█████                                 | 3297/25000 [00:55<06:17, 57.44it/s]geo grid grad stat: %=0.7143 mu=-2.51e-11 mu=1.30e-09 std=6.01e-09 min=-4.32e-07 max=2.78e-07
#  14%|█████▏                                | 3399/25000 [00:57<06:07, 58.85it/s]geo grid grad stat: %=0.7020 mu=-4.05e-11 mu=1.22e-09 std=5.99e-09 min=-5.89e-07 max=3.63e-07
#  14%|█████▎                                | 3495/25000 [00:58<06:04, 58.93it/s]VolRepr-fg: sharpness 194.96
# VolRepr-fg: occupancy mask activated ratio 0.9950 => 0.9928
# VolRepr-bg: occupancy mask activated ratio 0.4324 => 0.4323
# geo grid grad stat: %=0.6880 mu=-3.73e-11 mu=1.15e-09 std=5.64e-09 min=-4.30e-07 max=2.38e-07
# scene_rep_reconstruction (fine): iter   3500 / Loss: 0.000594955 / PSNR: 26.24 / Eps: 00:00:59
#  14%|█████▍                                | 3598/25000 [01:00<05:46, 61.74it/s]geo grid grad stat: %=0.6724 mu=3.56e-11 mu=1.08e-09 std=5.21e-09 min=-3.03e-07 max=6.01e-07
#  15%|█████▌                                | 3696/25000 [01:01<05:46, 61.53it/s]geo grid grad stat: %=0.6591 mu=-1.80e-13 mu=1.06e-09 std=5.35e-09 min=-4.38e-07 max=3.31e-07
#  15%|█████▊                                | 3794/25000 [01:03<05:33, 63.64it/s]geo grid grad stat: %=0.6468 mu=1.86e-11 mu=9.90e-10 std=5.39e-09 min=-5.26e-07 max=1.94e-07
#  16%|█████▉                                | 3899/25000 [01:05<05:23, 65.30it/s]geo grid grad stat: %=0.6344 mu=-3.74e-11 mu=1.02e-09 std=5.69e-09 min=-5.29e-07 max=2.57e-07
#  16%|██████                                | 3997/25000 [01:06<05:18, 65.98it/s]VolRepr-fg: scale_volume_grid start
# VolRepr-fg: voxel_size       tensor(0.0127)
# VolRepr-fg: world_size       tensor([94, 94, 94])
# VolRepr-fg: world_size_k0    tensor([94, 94, 94])
# VolRepr-fg: voxel_size_base  tensor(0.0075)
# VolRepr-fg: voxel_size_ratio tensor(1.6932)
# VolRepr-fg: scale_volume_grid scale world_size from [75, 75, 75] to [94, 94, 94]
# VolRepr-fg: scale_volume_grid finish
# VolRepr-bg: scale_volume_grid start
# VolRepr-bg: voxel_size       tensor(0.2032)
# VolRepr-bg: world_size       tensor([94, 94, 94])
# VolRepr-bg: world_size_k0    tensor([94, 94, 94])
# VolRepr-bg: voxel_size_base  tensor(0.1200)
# VolRepr-bg: voxel_size_ratio tensor(1.6932)
# VolRepr-bg: scale_volume_grid scale world_size from [75, 75, 75] to [94, 94, 94]
# VolRepr-bg: scale_volume_grid finish
# create_optimizer_or_freeze_model: param density lr 0.001435890276967915
# create_optimizer_or_freeze_model: param k0 lr 0.06918309709189366
# create_optimizer_or_freeze_model: param sdf_scale freeze
# create_optimizer_or_freeze_model: param rgbnet lr 0.0006918309709189366
# create_optimizer_or_freeze_model: param bg_model.density lr 0.06918309709189366
# create_optimizer_or_freeze_model: param bg_model.k0 lr 0.06918309709189366
# create_optimizer_or_freeze_model: param bg_model.rgbnet lr 0.0006918309709189366
# geo grid grad stat: %=0.4609 mu=1.02e-10 mu=7.60e-10 std=3.55e-09 min=-2.98e-07 max=2.50e-07
# scene_rep_reconstruction (fine): iter   4000 / Loss: 0.001071493 / PSNR: 27.62 / Eps: 00:01:07
#  16%|██████▏                               | 4094/25000 [01:08<06:44, 51.70it/s]geo grid grad stat: %=0.5113 mu=-5.01e-11 mu=8.98e-10 std=4.69e-09 min=-4.04e-07 max=2.67e-07
#  17%|██████▍                               | 4196/25000 [01:10<06:42, 51.66it/s]geo grid grad stat: %=0.4997 mu=-6.53e-11 mu=8.03e-10 std=4.66e-09 min=-4.93e-07 max=3.20e-07
#  17%|██████▌                               | 4298/25000 [01:12<06:27, 53.49it/s]geo grid grad stat: %=0.4837 mu=-7.91e-12 mu=7.59e-10 std=4.15e-09 min=-3.72e-07 max=2.62e-07
#  18%|██████▋                               | 4394/25000 [01:14<06:12, 55.36it/s]geo grid grad stat: %=0.4630 mu=-1.86e-11 mu=7.35e-10 std=4.20e-09 min=-3.80e-07 max=2.94e-07
#  18%|██████▊                               | 4496/25000 [01:16<05:59, 56.97it/s]VolRepr-fg: sharpness 244.96
# VolRepr-fg: occupancy mask activated ratio 0.9853 => 0.9779
# VolRepr-bg: occupancy mask activated ratio 0.3951 => 0.3951
# geo grid grad stat: %=0.4463 mu=-7.27e-12 mu=6.80e-10 std=4.25e-09 min=-5.42e-07 max=2.27e-07
# scene_rep_reconstruction (fine): iter   4500 / Loss: 0.000505475 / PSNR: 26.77 / Eps: 00:01:16
#  18%|██████▉                               | 4598/25000 [01:17<05:47, 58.74it/s]geo grid grad stat: %=0.4264 mu=2.01e-11 mu=6.46e-10 std=3.76e-09 min=-3.27e-07 max=1.85e-07
#  19%|███████▏                              | 4697/25000 [01:19<05:37, 60.13it/s]geo grid grad stat: %=0.4098 mu=-7.91e-12 mu=6.47e-10 std=4.00e-09 min=-5.80e-07 max=1.63e-07
#  19%|███████▎                              | 4795/25000 [01:21<05:28, 61.57it/s]geo grid grad stat: %=0.3917 mu=-7.59e-12 mu=6.62e-10 std=4.02e-09 min=-4.30e-07 max=2.55e-07
#  20%|███████▍                              | 4893/25000 [01:22<05:22, 62.27it/s]geo grid grad stat: %=0.3744 mu=7.36e-12 mu=6.44e-10 std=3.87e-09 min=-4.10e-07 max=1.80e-07
#  20%|███████▌                              | 4998/25000 [01:24<05:09, 64.57it/s]VolRepr-fg: scale_volume_grid start
# VolRepr-fg: voxel_size       tensor(0.0101)
# VolRepr-fg: world_size       tensor([119, 119, 119])
# VolRepr-fg: world_size_k0    tensor([119, 119, 119])
# VolRepr-fg: voxel_size_base  tensor(0.0075)
# VolRepr-fg: voxel_size_ratio tensor(1.3439)
# VolRepr-fg: scale_volume_grid scale world_size from [94, 94, 94] to [119, 119, 119]
# VolRepr-fg: scale_volume_grid finish
# VolRepr-bg: scale_volume_grid start
# VolRepr-bg: voxel_size       tensor(0.1613)
# VolRepr-bg: world_size       tensor([119, 119, 119])
# VolRepr-bg: world_size_k0    tensor([119, 119, 119])
# VolRepr-bg: voxel_size_base  tensor(0.1200)
# VolRepr-bg: voxel_size_ratio tensor(1.3439)
# VolRepr-bg: scale_volume_grid scale world_size from [94, 94, 94] to [119, 119, 119]
# VolRepr-bg: scale_volume_grid finish
# create_optimizer_or_freeze_model: param density lr 0.001194321511660492
# create_optimizer_or_freeze_model: param k0 lr 0.06309573444801933
# create_optimizer_or_freeze_model: param sdf_scale freeze
# create_optimizer_or_freeze_model: param rgbnet lr 0.0006309573444801933
# create_optimizer_or_freeze_model: param bg_model.density lr 0.06309573444801933
# create_optimizer_or_freeze_model: param bg_model.k0 lr 0.06309573444801933
# create_optimizer_or_freeze_model: param bg_model.rgbnet lr 0.0006309573444801933
# geo grid grad stat: %=0.2284 mu=8.28e-11 mu=6.07e-10 std=3.19e-09 min=-3.08e-07 max=2.08e-07
# scene_rep_reconstruction (fine): iter   5000 / Loss: 0.000897303 / PSNR: 28.19 / Eps: 00:01:24
#  20%|███████▋                              | 5097/25000 [01:26<06:59, 47.50it/s]geo grid grad stat: %=0.2682 mu=-1.15e-11 mu=5.95e-10 std=3.21e-09 min=-4.31e-07 max=1.96e-07
#  21%|███████▉                              | 5197/25000 [01:28<06:47, 48.58it/s]geo grid grad stat: %=0.2620 mu=-3.51e-11 mu=5.58e-10 std=3.43e-09 min=-3.12e-07 max=2.01e-07
#  21%|████████                              | 5299/25000 [01:30<06:32, 50.18it/s]geo grid grad stat: %=0.2469 mu=-1.50e-11 mu=5.49e-10 std=3.29e-09 min=-2.77e-07 max=1.49e-07
#  22%|████████▏                             | 5394/25000 [01:32<06:22, 51.23it/s]geo grid grad stat: %=0.2339 mu=-1.76e-11 mu=5.57e-10 std=3.58e-09 min=-4.16e-07 max=2.08e-07
#  22%|████████▎                             | 5496/25000 [01:34<06:05, 53.40it/s]VolRepr-fg: sharpness 294.95
# VolRepr-fg: occupancy mask activated ratio 0.9638 => 0.9521
# VolRepr-bg: occupancy mask activated ratio 0.3691 => 0.3690
# geo grid grad stat: %=0.2214 mu=-1.46e-11 mu=5.48e-10 std=3.57e-09 min=-5.31e-07 max=2.29e-07
# scene_rep_reconstruction (fine): iter   5500 / Loss: 0.000430380 / PSNR: 27.50 / Eps: 00:01:34
#  22%|████████▌                             | 5598/25000 [01:36<05:55, 54.61it/s]geo grid grad stat: %=0.2074 mu=-4.72e-11 mu=5.63e-10 std=3.74e-09 min=-4.38e-07 max=2.28e-07
#  23%|████████▋                             | 5694/25000 [01:38<05:40, 56.69it/s]geo grid grad stat: %=0.1942 mu=-6.58e-12 mu=5.63e-10 std=3.70e-09 min=-4.49e-07 max=1.68e-07
#  23%|████████▊                             | 5796/25000 [01:39<05:28, 58.45it/s]geo grid grad stat: %=0.1822 mu=-4.15e-11 mu=5.63e-10 std=3.53e-09 min=-3.22e-07 max=1.82e-07
#  24%|████████▉                             | 5899/25000 [01:41<05:19, 59.78it/s]geo grid grad stat: %=0.1711 mu=-4.07e-11 mu=5.72e-10 std=3.55e-09 min=-2.83e-07 max=1.53e-07
#  24%|█████████                             | 5996/25000 [01:43<05:11, 61.04it/s]VolRepr-fg: scale_volume_grid start
# VolRepr-fg: voxel_size       tensor(0.0080)
# VolRepr-fg: world_size       tensor([150, 150, 150])
# VolRepr-fg: world_size_k0    tensor([150, 150, 150])
# VolRepr-fg: voxel_size_base  tensor(0.0075)
# VolRepr-fg: voxel_size_ratio tensor(1.0667)
# VolRepr-fg: scale_volume_grid scale world_size from [119, 119, 119] to [150, 150, 150]
# VolRepr-fg: scale_volume_grid finish
# VolRepr-bg: scale_volume_grid start
# VolRepr-bg: voxel_size       tensor(0.1280)
# VolRepr-bg: world_size       tensor([150, 150, 150])
# VolRepr-bg: world_size_k0    tensor([150, 150, 150])
# VolRepr-bg: voxel_size_base  tensor(0.1200)
# VolRepr-bg: voxel_size_ratio tensor(1.0667)
# VolRepr-bg: scale_volume_grid scale world_size from [119, 119, 119] to [150, 150, 150]
# VolRepr-bg: scale_volume_grid finish
# create_optimizer_or_freeze_model: param density lr 0.0009933933644477734
# create_optimizer_or_freeze_model: param k0 lr 0.057543993733715694
# create_optimizer_or_freeze_model: param sdf_scale freeze
# create_optimizer_or_freeze_model: param rgbnet lr 0.000575439937337157
# create_optimizer_or_freeze_model: param bg_model.density lr 0.057543993733715694
# create_optimizer_or_freeze_model: param bg_model.k0 lr 0.057543993733715694
# create_optimizer_or_freeze_model: param bg_model.rgbnet lr 0.000575439937337157
# geo grid grad stat: %=0.0893 mu=7.83e-11 mu=5.17e-10 std=2.50e-09 min=-2.02e-07 max=1.38e-07
# scene_rep_reconstruction (fine): iter   6000 / Loss: 0.000671589 / PSNR: 28.69 / Eps: 00:01:43
#  24%|█████████▎                            | 6096/25000 [01:45<06:49, 46.12it/s]geo grid grad stat: %=0.1100 mu=-1.27e-11 mu=5.01e-10 std=2.69e-09 min=-3.06e-07 max=2.01e-07
#  25%|█████████▍                            | 6196/25000 [01:47<06:51, 45.65it/s]geo grid grad stat: %=0.1070 mu=-2.26e-11 mu=5.06e-10 std=3.06e-09 min=-3.19e-07 max=2.51e-07
#  25%|█████████▌                            | 6296/25000 [01:49<06:41, 46.54it/s]geo grid grad stat: %=0.0999 mu=8.70e-12 mu=5.31e-10 std=3.20e-09 min=-4.42e-07 max=1.85e-07
#  26%|█████████▋                            | 6396/25000 [01:51<06:31, 47.47it/s]geo grid grad stat: %=0.0951 mu=-5.36e-11 mu=5.87e-10 std=3.54e-09 min=-3.83e-07 max=1.85e-07
#  26%|█████████▊                            | 6496/25000 [01:53<06:13, 49.53it/s]VolRepr-fg: sharpness 344.94
# VolRepr-fg: occupancy mask activated ratio 0.9329 => 0.9176
# VolRepr-bg: occupancy mask activated ratio 0.3480 => 0.3480
# geo grid grad stat: %=0.0874 mu=1.13e-11 mu=5.28e-10 std=3.17e-09 min=-3.35e-07 max=2.17e-07
# scene_rep_reconstruction (fine): iter   6500 / Loss: 0.000357651 / PSNR: 28.16 / Eps: 00:01:54
#  26%|██████████                            | 6598/25000 [01:55<06:02, 50.70it/s]geo grid grad stat: %=0.0802 mu=-1.44e-11 mu=5.59e-10 std=3.13e-09 min=-3.14e-07 max=1.48e-07
#  27%|██████████▏                           | 6694/25000 [01:57<05:52, 51.87it/s]geo grid grad stat: %=0.0764 mu=-4.42e-11 mu=5.91e-10 std=3.47e-09 min=-4.77e-07 max=1.94e-07
#  27%|██████████▎                           | 6796/25000 [01:59<05:49, 52.06it/s]geo grid grad stat: %=0.0700 mu=-3.56e-11 mu=6.23e-10 std=3.49e-09 min=-2.65e-07 max=1.97e-07
#  28%|██████████▍                           | 6898/25000 [02:01<05:41, 53.02it/s]geo grid grad stat: %=0.0652 mu=-1.84e-11 mu=6.19e-10 std=3.48e-09 min=-3.19e-07 max=1.20e-07
#  28%|██████████▋                           | 6994/25000 [02:03<05:34, 53.83it/s]VolRepr-fg: scale_volume_grid start
# VolRepr-fg: voxel_size       tensor(0.0063)
# VolRepr-fg: world_size       tensor([188, 188, 188])
# VolRepr-fg: world_size_k0    tensor([188, 188, 188])
# VolRepr-fg: voxel_size_base  tensor(0.0075)
# VolRepr-fg: voxel_size_ratio tensor(0.8466)
# VolRepr-fg: scale_volume_grid scale world_size from [150, 150, 150] to [188, 188, 188]
# VolRepr-fg: scale_volume_grid finish
# VolRepr-bg: scale_volume_grid start
# VolRepr-bg: voxel_size       tensor(0.1200)
# VolRepr-bg: world_size       tensor([160, 160, 160])
# VolRepr-bg: world_size_k0    tensor([160, 160, 160])
# VolRepr-bg: voxel_size_base  tensor(0.1200)
# VolRepr-bg: voxel_size_ratio tensor(1.)
# VolRepr-bg: scale_volume_grid scale world_size from [150, 150, 150] to [160, 160, 160]
# VolRepr-bg: scale_volume_grid finish
# create_optimizer_or_freeze_model: param density lr 0.0008262686110014499
# create_optimizer_or_freeze_model: param k0 lr 0.05248074602497726
# create_optimizer_or_freeze_model: param sdf_scale freeze
# create_optimizer_or_freeze_model: param rgbnet lr 0.0005248074602497725
# create_optimizer_or_freeze_model: param bg_model.density lr 0.05248074602497726
# create_optimizer_or_freeze_model: param bg_model.k0 lr 0.05248074602497726
# create_optimizer_or_freeze_model: param bg_model.rgbnet lr 0.0005248074602497725
# geo grid grad stat: %=0.0330 mu=1.08e-10 mu=5.98e-10 std=2.64e-09 min=-2.05e-07 max=1.43e-07
# scene_rep_reconstruction (fine): iter   7000 / Loss: 0.000656163 / PSNR: 29.20 / Eps: 00:02:04
#  28%|██████████▊                           | 7095/25000 [02:05<06:40, 44.69it/s]geo grid grad stat: %=0.0399 mu=-7.62e-11 mu=6.22e-10 std=3.20e-09 min=-2.78e-07 max=2.36e-07
#  29%|██████████▉                           | 7195/25000 [02:08<06:43, 44.18it/s]geo grid grad stat: %=0.0395 mu=1.10e-12 mu=5.95e-10 std=3.00e-09 min=-3.48e-07 max=9.36e-08
#  29%|███████████                           | 7295/25000 [02:10<06:31, 45.18it/s]geo grid grad stat: %=0.0368 mu=-2.00e-11 mu=5.59e-10 std=2.93e-09 min=-2.78e-07 max=1.55e-07
#  30%|███████████▏                          | 7395/25000 [02:12<06:19, 46.37it/s]geo grid grad stat: %=0.0359 mu=-2.12e-11 mu=5.93e-10 std=3.24e-09 min=-4.36e-07 max=1.07e-07
#  30%|███████████▍                          | 7495/25000 [02:14<06:12, 46.94it/s]VolRepr-fg: sharpness 394.93
# VolRepr-fg: occupancy mask activated ratio 0.8931 => 0.8728
# VolRepr-bg: occupancy mask activated ratio 0.3331 => 0.3330
# geo grid grad stat: %=0.0330 mu=-1.58e-11 mu=6.02e-10 std=3.01e-09 min=-3.04e-07 max=1.73e-07
# scene_rep_reconstruction (fine): iter   7500 / Loss: 0.000307992 / PSNR: 28.41 / Eps: 00:02:15
#  30%|███████████▌                          | 7595/25000 [02:16<06:07, 47.41it/s]geo grid grad stat: %=0.0327 mu=-8.29e-11 mu=6.49e-10 std=3.43e-09 min=-3.92e-07 max=1.15e-07
#  31%|███████████▋                          | 7695/25000 [02:18<06:03, 47.55it/s]geo grid grad stat: %=0.0306 mu=-4.94e-11 mu=6.85e-10 std=3.39e-09 min=-2.58e-07 max=1.32e-07
#  31%|███████████▊                          | 7795/25000 [02:21<05:56, 48.26it/s]geo grid grad stat: %=0.0289 mu=-4.28e-11 mu=7.30e-10 std=3.47e-09 min=-2.32e-07 max=1.42e-07
#  32%|████████████                          | 7895/25000 [02:23<05:47, 49.19it/s]geo grid grad stat: %=0.0271 mu=-4.61e-11 mu=7.46e-10 std=3.62e-09 min=-3.02e-07 max=1.26e-07
#  32%|████████████▏                         | 7996/25000 [02:25<05:41, 49.74it/s]VolRepr-fg: scale_volume_grid start
# VolRepr-fg: voxel_size       tensor(0.0050)
# VolRepr-fg: world_size       tensor([238, 238, 238])
# VolRepr-fg: world_size_k0    tensor([238, 238, 238])
# VolRepr-fg: voxel_size_base  tensor(0.0075)
# VolRepr-fg: voxel_size_ratio tensor(0.6720)
# VolRepr-fg: scale_volume_grid scale world_size from [188, 188, 188] to [238, 238, 238]
# VolRepr-fg: scale_volume_grid finish
# create_optimizer_or_freeze_model: param density lr 0.0006872602958303319
# create_optimizer_or_freeze_model: param k0 lr 0.04786300923226384
# create_optimizer_or_freeze_model: param sdf_scale freeze
# create_optimizer_or_freeze_model: param rgbnet lr 0.0004786300923226384
# create_optimizer_or_freeze_model: param bg_model.density lr 0.04786300923226384
# create_optimizer_or_freeze_model: param bg_model.k0 lr 0.04786300923226384
# create_optimizer_or_freeze_model: param bg_model.rgbnet lr 0.0004786300923226384
# geo grid grad stat: %=0.0142 mu=1.42e-10 mu=6.59e-10 std=2.48e-09 min=-1.35e-07 max=1.01e-07
# scene_rep_reconstruction (fine): iter   8000 / Loss: 0.000282335 / PSNR: 29.44 / Eps: 00:02:25
#  32%|████████████▎                         | 8096/25000 [02:27<06:31, 43.23it/s]geo grid grad stat: %=0.0155 mu=-4.85e-11 mu=6.98e-10 std=3.08e-09 min=-2.23e-07 max=6.84e-08
#  33%|████████████▍                         | 8196/25000 [02:29<06:24, 43.70it/s]geo grid grad stat: %=0.0145 mu=-9.04e-11 mu=7.09e-10 std=3.10e-09 min=-2.02e-07 max=9.31e-08
#  33%|████████████▌                         | 8296/25000 [02:32<06:17, 44.22it/s]geo grid grad stat: %=0.0142 mu=-9.64e-11 mu=7.74e-10 std=3.46e-09 min=-3.11e-07 max=8.11e-08
#  34%|████████████▊                         | 8396/25000 [02:34<06:16, 44.05it/s]geo grid grad stat: %=0.0136 mu=-4.17e-11 mu=7.45e-10 std=3.31e-09 min=-3.33e-07 max=1.72e-07
#  34%|████████████▉                         | 8496/25000 [02:36<06:07, 44.91it/s]VolRepr-fg: sharpness 444.91
# VolRepr-fg: occupancy mask activated ratio 0.8428 => 0.8177
# VolRepr-bg: occupancy mask activated ratio 0.3330 => 0.3223
# geo grid grad stat: %=0.0128 mu=-6.30e-11 mu=7.13e-10 std=3.05e-09 min=-2.51e-07 max=8.78e-08
# scene_rep_reconstruction (fine): iter   8500 / Loss: 0.000255945 / PSNR: 29.87 / Eps: 00:02:37
#  34%|█████████████                         | 8596/25000 [02:38<06:01, 45.43it/s]geo grid grad stat: %=0.0123 mu=-1.49e-11 mu=7.36e-10 std=3.07e-09 min=-2.47e-07 max=1.07e-07
#  35%|█████████████▏                        | 8696/25000 [02:41<05:56, 45.73it/s]geo grid grad stat: %=0.0117 mu=-2.97e-11 mu=7.52e-10 std=3.22e-09 min=-2.40e-07 max=1.05e-07
#  35%|█████████████▎                        | 8796/25000 [02:43<05:54, 45.73it/s]geo grid grad stat: %=0.0120 mu=-4.09e-11 mu=8.22e-10 std=3.40e-09 min=-3.10e-07 max=1.57e-07
#  36%|█████████████▌                        | 8896/25000 [02:45<05:52, 45.72it/s]geo grid grad stat: %=0.0115 mu=-7.10e-11 mu=8.00e-10 std=3.24e-09 min=-2.12e-07 max=8.22e-08
#  36%|█████████████▋                        | 8996/25000 [02:47<05:47, 46.03it/s]VolRepr-fg: scale_volume_grid start
# VolRepr-fg: voxel_size       tensor(0.0040)
# VolRepr-fg: world_size       tensor([300, 300, 300])
# VolRepr-fg: world_size_k0    tensor([300, 300, 300])
# VolRepr-fg: voxel_size_base  tensor(0.0075)
# VolRepr-fg: voxel_size_ratio tensor(0.5333)
# VolRepr-fg: scale_volume_grid scale world_size from [238, 238, 238] to [300, 300, 300]
# VolRepr-fg: scale_volume_grid finish
# create_optimizer_or_freeze_model: param density lr 0.0005716382153889742
# create_optimizer_or_freeze_model: param k0 lr 0.043651583224016605
# create_optimizer_or_freeze_model: param sdf_scale freeze
# create_optimizer_or_freeze_model: param rgbnet lr 0.000436515832240166
# create_optimizer_or_freeze_model: param bg_model.density lr 0.043651583224016605
# create_optimizer_or_freeze_model: param bg_model.k0 lr 0.043651583224016605
# create_optimizer_or_freeze_model: param bg_model.rgbnet lr 0.000436515832240166
# geo grid grad stat: %=0.0065 mu=1.27e-10 mu=6.63e-10 std=2.33e-09 min=-1.48e-07 max=1.13e-07
# scene_rep_reconstruction (fine): iter   9000 / Loss: 0.000242546 / PSNR: 30.06 / Eps: 00:02:48
#  36%|█████████████▊                        | 9097/25000 [02:50<07:01, 37.72it/s]geo grid grad stat: %=0.0066 mu=-5.31e-11 mu=7.09e-10 std=2.79e-09 min=-2.09e-07 max=6.72e-08
#  37%|█████████████▉                        | 9197/25000 [02:53<06:57, 37.84it/s]geo grid grad stat: %=0.0070 mu=-6.24e-11 mu=7.81e-10 std=2.85e-09 min=-1.47e-07 max=1.36e-07
#  37%|██████████████▏                       | 9297/25000 [02:55<06:48, 38.45it/s]geo grid grad stat: %=0.0064 mu=-3.05e-11 mu=6.92e-10 std=2.69e-09 min=-1.95e-07 max=1.08e-07
#  38%|██████████████▎                       | 9397/25000 [02:58<06:43, 38.64it/s]geo grid grad stat: %=0.0064 mu=-4.15e-11 mu=7.24e-10 std=2.99e-09 min=-3.03e-07 max=7.30e-08
#  38%|██████████████▍                       | 9497/25000 [03:01<06:43, 38.41it/s]VolRepr-fg: sharpness 494.90
# VolRepr-fg: occupancy mask activated ratio 0.8177 => 0.7602
# VolRepr-bg: occupancy mask activated ratio 0.3223 => 0.3164
# geo grid grad stat: %=0.0064 mu=-7.43e-11 mu=7.38e-10 std=2.96e-09 min=-2.71e-07 max=8.17e-08
# scene_rep_reconstruction (fine): iter   9500 / Loss: 0.000225859 / PSNR: 30.31 / Eps: 00:03:01
#  38%|██████████████▌                       | 9597/25000 [03:03<06:37, 38.71it/s]geo grid grad stat: %=0.0060 mu=-5.83e-12 mu=6.42e-10 std=2.43e-09 min=-1.76e-07 max=9.32e-08
#  39%|██████████████▋                       | 9697/25000 [03:06<06:33, 38.86it/s]geo grid grad stat: %=0.0061 mu=-8.85e-11 mu=7.52e-10 std=3.02e-09 min=-2.64e-07 max=1.19e-07
#  39%|██████████████▉                       | 9797/25000 [03:08<06:35, 38.43it/s]geo grid grad stat: %=0.0063 mu=-3.67e-11 mu=7.18e-10 std=2.76e-09 min=-2.19e-07 max=7.05e-08
#  40%|███████████████                       | 9897/25000 [03:11<06:26, 39.07it/s]geo grid grad stat: %=0.0060 mu=-9.74e-11 mu=8.19e-10 std=2.99e-09 min=-1.67e-07 max=8.37e-08
#  40%|███████████████▏                      | 9997/25000 [03:14<06:21, 39.37it/s]geo grid grad stat: %=0.0060 mu=-6.77e-11 mu=7.64e-10 std=2.82e-09 min=-1.53e-07 max=9.32e-08
# scene_rep_reconstruction (fine): iter  10000 / Loss: 0.000220486 / PSNR: 30.41 / Eps: 00:03:14
#  40%|██████████████▉                      | 10097/25000 [03:16<06:22, 39.01it/s]geo grid grad stat: %=0.0061 mu=-3.01e-11 mu=7.32e-10 std=2.60e-09 min=-1.91e-07 max=1.12e-07
#  41%|███████████████                      | 10197/25000 [03:19<06:14, 39.56it/s]geo grid grad stat: %=0.0059 mu=-5.53e-11 mu=7.58e-10 std=2.88e-09 min=-2.03e-07 max=1.11e-07
#  41%|███████████████▏                     | 10297/25000 [03:21<06:14, 39.29it/s]geo grid grad stat: %=0.0058 mu=-2.66e-11 mu=7.07e-10 std=2.71e-09 min=-1.95e-07 max=5.73e-08
#  42%|███████████████▍                     | 10399/25000 [03:24<06:06, 39.88it/s]geo grid grad stat: %=0.0061 mu=-4.19e-11 mu=7.16e-10 std=2.55e-09 min=-1.49e-07 max=1.26e-07
#  42%|███████████████▌                     | 10495/25000 [03:26<06:01, 40.16it/s]VolRepr-fg: sharpness 544.89
# VolRepr-fg: occupancy mask activated ratio 0.7602 => 0.6958
# VolRepr-bg: occupancy mask activated ratio 0.3164 => 0.3163
# geo grid grad stat: %=0.0058 mu=-3.19e-11 mu=7.50e-10 std=2.70e-09 min=-1.28e-07 max=7.91e-08
# scene_rep_reconstruction (fine): iter  10500 / Loss: 0.000216307 / PSNR: 30.55 / Eps: 00:03:27
#  42%|███████████████▋                     | 10595/25000 [03:29<05:54, 40.63it/s]geo grid grad stat: %=0.0056 mu=-3.97e-12 mu=6.94e-10 std=2.48e-09 min=-1.64e-07 max=8.30e-08
#  43%|███████████████▊                     | 10695/25000 [03:31<05:52, 40.62it/s]geo grid grad stat: %=0.0056 mu=-3.49e-11 mu=7.50e-10 std=2.64e-09 min=-1.71e-07 max=6.10e-08
#  43%|███████████████▉                     | 10795/25000 [03:34<05:53, 40.21it/s]geo grid grad stat: %=0.0059 mu=-3.55e-11 mu=7.50e-10 std=2.70e-09 min=-1.88e-07 max=6.25e-08
#  44%|████████████████▏                    | 10899/25000 [03:37<06:08, 38.25it/s]geo grid grad stat: %=0.0056 mu=-1.84e-11 mu=7.21e-10 std=2.57e-09 min=-2.65e-07 max=7.09e-08
#  44%|████████████████▎                    | 10998/25000 [03:39<05:46, 40.39it/s]geo grid grad stat: %=0.0054 mu=-1.43e-11 mu=7.23e-10 std=2.51e-09 min=-1.25e-07 max=8.33e-08
# scene_rep_reconstruction (fine): iter  11000 / Loss: 0.000190571 / PSNR: 30.68 / Eps: 00:03:40
#  44%|████████████████▍                    | 11097/25000 [03:42<05:44, 40.33it/s]geo grid grad stat: %=0.0057 mu=-4.57e-11 mu=7.31e-10 std=2.65e-09 min=-1.62e-07 max=5.60e-08
#  45%|████████████████▌                    | 11197/25000 [03:44<05:36, 40.97it/s]geo grid grad stat: %=0.0056 mu=-9.43e-11 mu=7.48e-10 std=2.82e-09 min=-2.54e-07 max=7.17e-08
#  45%|████████████████▋                    | 11297/25000 [03:47<05:38, 40.47it/s]geo grid grad stat: %=0.0050 mu=-7.29e-11 mu=7.50e-10 std=2.80e-09 min=-2.17e-07 max=1.34e-07
#  46%|████████████████▊                    | 11397/25000 [03:49<05:33, 40.80it/s]geo grid grad stat: %=0.0055 mu=-4.30e-11 mu=7.32e-10 std=2.58e-09 min=-2.19e-07 max=6.97e-08
#  46%|█████████████████                    | 11497/25000 [03:52<05:30, 40.81it/s]VolRepr-fg: sharpness 594.88
# VolRepr-fg: occupancy mask activated ratio 0.6958 => 0.6243
# VolRepr-bg: occupancy mask activated ratio 0.3163 => 0.3162
# geo grid grad stat: %=0.0052 mu=-2.90e-11 mu=7.30e-10 std=2.52e-09 min=-1.71e-07 max=6.81e-08
# scene_rep_reconstruction (fine): iter  11500 / Loss: 0.000190396 / PSNR: 30.78 / Eps: 00:03:52
#  46%|█████████████████▏                   | 11597/25000 [03:54<05:25, 41.21it/s]geo grid grad stat: %=0.0054 mu=-2.68e-11 mu=6.98e-10 std=2.40e-09 min=-1.13e-07 max=1.04e-07
#  47%|█████████████████▎                   | 11697/25000 [03:56<05:20, 41.56it/s]geo grid grad stat: %=0.0050 mu=-5.25e-11 mu=6.95e-10 std=2.72e-09 min=-2.94e-07 max=1.15e-07
#  47%|█████████████████▍                   | 11797/25000 [03:59<05:17, 41.53it/s]geo grid grad stat: %=0.0054 mu=-5.25e-11 mu=7.40e-10 std=2.65e-09 min=-2.03e-07 max=1.02e-07
#  48%|█████████████████▌                   | 11897/25000 [04:01<05:18, 41.17it/s]geo grid grad stat: %=0.0054 mu=-2.62e-11 mu=6.84e-10 std=2.37e-09 min=-1.66e-07 max=8.45e-08
#  48%|█████████████████▊                   | 11997/25000 [04:04<05:13, 41.46it/s]geo grid grad stat: %=0.0054 mu=-2.83e-11 mu=7.12e-10 std=2.48e-09 min=-2.61e-07 max=7.30e-08
# scene_rep_reconstruction (fine): iter  12000 / Loss: 0.000187420 / PSNR: 30.84 / Eps: 00:04:04
#  48%|█████████████████▉                   | 12097/25000 [04:06<05:13, 41.10it/s]geo grid grad stat: %=0.0051 mu=-2.98e-11 mu=7.10e-10 std=2.41e-09 min=-1.69e-07 max=6.24e-08
#  49%|██████████████████                   | 12197/25000 [04:09<05:10, 41.19it/s]geo grid grad stat: %=0.0053 mu=-3.19e-11 mu=7.65e-10 std=2.77e-09 min=-2.10e-07 max=1.40e-07
#  49%|██████████████████▏                  | 12297/25000 [04:11<05:05, 41.53it/s]geo grid grad stat: %=0.0053 mu=-6.10e-11 mu=7.09e-10 std=2.54e-09 min=-2.25e-07 max=6.61e-08
#  50%|██████████████████▎                  | 12397/25000 [04:14<05:02, 41.68it/s]geo grid grad stat: %=0.0055 mu=-5.08e-11 mu=7.74e-10 std=2.59e-09 min=-1.38e-07 max=1.43e-07
#  50%|██████████████████▍                  | 12497/25000 [04:16<05:01, 41.43it/s]VolRepr-fg: sharpness 644.87
# VolRepr-fg: occupancy mask activated ratio 0.6243 => 0.5489
# VolRepr-bg: occupancy mask activated ratio 0.3162 => 0.3161
# geo grid grad stat: %=0.0053 mu=-4.20e-11 mu=7.11e-10 std=2.38e-09 min=-1.18e-07 max=5.71e-08
# scene_rep_reconstruction (fine): iter  12500 / Loss: 0.000183194 / PSNR: 30.92 / Eps: 00:04:17
#  50%|██████████████████▋                  | 12597/25000 [04:18<04:55, 42.00it/s]geo grid grad stat: %=0.0052 mu=5.05e-12 mu=6.78e-10 std=2.22e-09 min=-1.62e-07 max=9.90e-08
#  51%|██████████████████▊                  | 12697/25000 [04:21<04:52, 42.07it/s]geo grid grad stat: %=0.0053 mu=-1.50e-11 mu=7.02e-10 std=2.55e-09 min=-3.10e-07 max=4.63e-08
#  51%|██████████████████▉                  | 12797/25000 [04:23<04:49, 42.18it/s]geo grid grad stat: %=0.0050 mu=-1.52e-11 mu=6.85e-10 std=2.45e-09 min=-1.46e-07 max=7.98e-08
#  52%|███████████████████                  | 12897/25000 [04:26<04:48, 41.95it/s]geo grid grad stat: %=0.0053 mu=-4.52e-11 mu=7.22e-10 std=2.47e-09 min=-1.38e-07 max=1.21e-07
#  52%|███████████████████▏                 | 12997/25000 [04:28<04:44, 42.13it/s]geo grid grad stat: %=0.0051 mu=-1.17e-11 mu=6.83e-10 std=2.24e-09 min=-1.17e-07 max=5.62e-08
# scene_rep_reconstruction (fine): iter  13000 / Loss: 0.000177307 / PSNR: 31.03 / Eps: 00:04:29
#  52%|███████████████████▍                 | 13097/25000 [04:31<04:43, 41.96it/s]geo grid grad stat: %=0.0049 mu=-5.28e-11 mu=7.22e-10 std=2.40e-09 min=-1.53e-07 max=1.15e-07
#  53%|███████████████████▌                 | 13197/25000 [04:33<04:40, 42.08it/s]geo grid grad stat: %=0.0052 mu=-3.13e-11 mu=7.08e-10 std=2.37e-09 min=-1.14e-07 max=7.89e-08
#  53%|███████████████████▋                 | 13297/25000 [04:35<04:37, 42.18it/s]geo grid grad stat: %=0.0054 mu=-5.15e-11 mu=7.58e-10 std=2.52e-09 min=-1.93e-07 max=6.20e-08
#  54%|███████████████████▊                 | 13397/25000 [04:38<04:33, 42.41it/s]geo grid grad stat: %=0.0051 mu=-3.64e-11 mu=6.92e-10 std=2.23e-09 min=-1.70e-07 max=5.73e-08
#  54%|███████████████████▉                 | 13497/25000 [04:40<04:28, 42.80it/s]VolRepr-fg: sharpness 694.85
# VolRepr-fg: occupancy mask activated ratio 0.5489 => 0.4696
# VolRepr-bg: occupancy mask activated ratio 0.3161 => 0.3161
# geo grid grad stat: %=0.0053 mu=-5.97e-11 mu=7.29e-10 std=2.43e-09 min=-1.45e-07 max=4.95e-08
# scene_rep_reconstruction (fine): iter  13500 / Loss: 0.000170632 / PSNR: 31.09 / Eps: 00:04:41
#  54%|████████████████████                 | 13597/25000 [04:43<04:23, 43.35it/s]geo grid grad stat: %=0.0049 mu=-3.40e-11 mu=6.72e-10 std=2.44e-09 min=-1.48e-07 max=6.67e-08
#  55%|████████████████████▎                | 13697/25000 [04:45<04:23, 42.92it/s]geo grid grad stat: %=0.0051 mu=-3.91e-11 mu=6.97e-10 std=2.29e-09 min=-1.02e-07 max=7.31e-08
#  55%|████████████████████▍                | 13797/25000 [04:47<04:19, 43.23it/s]geo grid grad stat: %=0.0051 mu=-2.86e-11 mu=6.75e-10 std=2.38e-09 min=-1.88e-07 max=1.05e-07
#  56%|████████████████████▌                | 13897/25000 [04:50<04:17, 43.04it/s]geo grid grad stat: %=0.0055 mu=-1.82e-11 mu=6.79e-10 std=2.22e-09 min=-1.38e-07 max=6.22e-08
#  56%|████████████████████▋                | 13997/25000 [04:52<04:16, 42.91it/s]geo grid grad stat: %=0.0054 mu=-1.75e-11 mu=6.93e-10 std=2.28e-09 min=-1.62e-07 max=5.66e-08
# scene_rep_reconstruction (fine): iter  14000 / Loss: 0.000172341 / PSNR: 31.13 / Eps: 00:04:53
#  56%|████████████████████▊                | 14097/25000 [04:54<04:15, 42.73it/s]geo grid grad stat: %=0.0054 mu=-3.58e-11 mu=7.20e-10 std=2.53e-09 min=-2.90e-07 max=6.59e-08
#  57%|█████████████████████                | 14197/25000 [04:57<04:11, 42.93it/s]geo grid grad stat: %=0.0051 mu=-1.27e-11 mu=6.91e-10 std=2.46e-09 min=-2.00e-07 max=8.36e-08
#  57%|█████████████████████▏               | 14297/25000 [04:59<04:08, 43.04it/s]geo grid grad stat: %=0.0051 mu=-2.54e-11 mu=6.91e-10 std=2.33e-09 min=-1.09e-07 max=1.38e-07
#  58%|█████████████████████▎               | 14397/25000 [05:01<04:05, 43.20it/s]geo grid grad stat: %=0.0052 mu=-4.24e-11 mu=7.07e-10 std=2.30e-09 min=-1.49e-07 max=8.01e-08
#  58%|█████████████████████▍               | 14497/25000 [05:04<04:03, 43.21it/s]VolRepr-fg: sharpness 744.84
# VolRepr-fg: occupancy mask activated ratio 0.4696 => 0.3878
# VolRepr-bg: occupancy mask activated ratio 0.3161 => 0.3160
# geo grid grad stat: %=0.0049 mu=-3.91e-11 mu=6.94e-10 std=2.43e-09 min=-1.69e-07 max=8.39e-08
# scene_rep_reconstruction (fine): iter  14500 / Loss: 0.000162480 / PSNR: 31.22 / Eps: 00:05:04
#  58%|█████████████████████▌               | 14597/25000 [05:06<03:58, 43.67it/s]geo grid grad stat: %=0.0049 mu=-3.57e-11 mu=7.47e-10 std=2.57e-09 min=-1.81e-07 max=7.51e-08
#  59%|█████████████████████▊               | 14697/25000 [05:08<03:52, 44.25it/s]geo grid grad stat: %=0.0050 mu=-8.77e-12 mu=6.70e-10 std=2.15e-09 min=-1.55e-07 max=7.20e-08
#  59%|█████████████████████▉               | 14797/25000 [05:11<03:50, 44.30it/s]geo grid grad stat: %=0.0048 mu=-2.44e-11 mu=6.42e-10 std=2.16e-09 min=-1.16e-07 max=9.46e-08
#  60%|██████████████████████               | 14897/25000 [05:13<03:50, 43.82it/s]geo grid grad stat: %=0.0048 mu=-9.45e-13 mu=6.80e-10 std=2.18e-09 min=-1.28e-07 max=8.15e-08
#  60%|██████████████████████▏              | 14997/25000 [05:15<03:48, 43.70it/s]geo grid grad stat: %=0.0048 mu=-4.85e-11 mu=7.22e-10 std=2.45e-09 min=-1.46e-07 max=8.32e-08
# scene_rep_reconstruction (fine): iter  15000 / Loss: 0.000167670 / PSNR: 31.27 / Eps: 00:05:16
#  60%|██████████████████████▎              | 15097/25000 [05:18<03:46, 43.66it/s]geo grid grad stat: %=0.0049 mu=-1.80e-11 mu=6.67e-10 std=2.19e-09 min=-1.79e-07 max=6.04e-08
#  61%|██████████████████████▍              | 15197/25000 [05:20<03:44, 43.75it/s]geo grid grad stat: %=0.0053 mu=-4.60e-11 mu=7.18e-10 std=2.37e-09 min=-2.14e-07 max=1.01e-07
#  61%|██████████████████████▋              | 15297/25000 [05:22<03:43, 43.38it/s]geo grid grad stat: %=0.0050 mu=-2.34e-11 mu=6.97e-10 std=2.48e-09 min=-1.72e-07 max=8.04e-08
#  62%|██████████████████████▊              | 15397/25000 [05:25<03:38, 43.89it/s]geo grid grad stat: %=0.0051 mu=-1.37e-11 mu=6.51e-10 std=2.17e-09 min=-1.20e-07 max=6.64e-08
#  62%|██████████████████████▉              | 15497/25000 [05:27<03:33, 44.46it/s]VolRepr-fg: sharpness 794.83
# VolRepr-fg: occupancy mask activated ratio 0.3878 => 0.3106
# VolRepr-bg: occupancy mask activated ratio 0.3160 => 0.3160
# geo grid grad stat: %=0.0049 mu=-3.76e-11 mu=7.04e-10 std=2.36e-09 min=-1.29e-07 max=6.16e-08
# scene_rep_reconstruction (fine): iter  15500 / Loss: 0.000158689 / PSNR: 31.32 / Eps: 00:05:28
#  62%|███████████████████████              | 15597/25000 [05:29<03:31, 44.55it/s]geo grid grad stat: %=0.0049 mu=1.75e-11 mu=6.29e-10 std=1.98e-09 min=-1.00e-07 max=5.30e-08
#  63%|███████████████████████▏             | 15697/25000 [05:32<03:29, 44.47it/s]geo grid grad stat: %=0.0050 mu=-3.92e-11 mu=7.03e-10 std=2.23e-09 min=-1.06e-07 max=4.79e-08
#  63%|███████████████████████▍             | 15797/25000 [05:34<03:26, 44.51it/s]geo grid grad stat: %=0.0050 mu=-2.33e-11 mu=6.31e-10 std=2.05e-09 min=-1.10e-07 max=5.53e-08
#  64%|███████████████████████▌             | 15897/25000 [05:36<03:21, 45.21it/s]geo grid grad stat: %=0.0052 mu=1.50e-13 mu=6.68e-10 std=2.21e-09 min=-1.58e-07 max=6.73e-08
#  64%|███████████████████████▋             | 15997/25000 [05:38<03:21, 44.71it/s]geo grid grad stat: %=0.0050 mu=-1.03e-11 mu=6.12e-10 std=2.10e-09 min=-2.96e-07 max=4.82e-08
# scene_rep_reconstruction (fine): iter  16000 / Loss: 0.000159919 / PSNR: 31.38 / Eps: 00:05:39
#  64%|███████████████████████▊             | 16097/25000 [05:41<03:17, 45.15it/s]geo grid grad stat: %=0.0051 mu=-5.14e-11 mu=6.75e-10 std=2.19e-09 min=-1.37e-07 max=4.98e-08
# ...
#  80%|█████████████████████████████▋       | 20097/25000 [07:09<01:44, 47.14it/s]geo grid grad stat: %=0.0050 mu=-1.91e-11 mu=6.70e-10 std=2.03e-09 min=-1.25e-07 max=4.64e-08
#  81%|█████████████████████████████▉       | 20197/25000 [07:11<01:41, 47.10it/s]geo grid grad stat: %=0.0047 mu=-1.86e-11 mu=6.57e-10 std=2.11e-09 min=-1.32e-07 max=5.59e-08
#  81%|██████████████████████████████       | 20297/25000 [07:13<01:40, 46.78it/s]geo grid grad stat: %=0.0049 mu=-2.89e-11 mu=6.69e-10 std=2.10e-09 min=-1.13e-07 max=6.61e-08
#  82%|██████████████████████████████▏      | 20397/25000 [07:15<01:37, 47.28it/s]geo grid grad stat: %=0.0047 mu=-2.96e-11 mu=6.83e-10 std=2.15e-09 min=-1.05e-07 max=4.74e-08
#  82%|██████████████████████████████▎      | 20497/25000 [07:17<01:35, 47.22it/s]VolRepr-fg: sharpness 1000.00
# VolRepr-fg: occupancy mask activated ratio 0.1047 => 0.1015
# VolRepr-bg: occupancy mask activated ratio 0.3159 => 0.3158
# geo grid grad stat: %=0.0045 mu=1.18e-11 mu=6.42e-10 std=1.99e-09 min=-1.14e-07 max=6.84e-08
# scene_rep_reconstruction (fine): iter  20500 / Loss: 0.000135886 / PSNR: 31.75 / Eps: 00:07:18
#  82%|██████████████████████████████▍      | 20597/25000 [07:19<01:33, 47.12it/s]geo grid grad stat: %=0.0047 mu=-3.66e-11 mu=6.75e-10 std=2.13e-09 min=-1.25e-07 max=6.20e-08
#  83%|██████████████████████████████▋      | 20697/25000 [07:22<01:31, 47.12it/s]geo grid grad stat: %=0.0047 mu=-6.46e-12 mu=6.51e-10 std=2.01e-09 min=-1.20e-07 max=1.12e-07
#  83%|██████████████████████████████▊      | 20797/25000 [07:24<01:29, 47.21it/s]geo grid grad stat: %=0.0049 mu=-2.97e-11 mu=6.77e-10 std=2.17e-09 min=-1.42e-07 max=5.12e-08
#  84%|██████████████████████████████▉      | 20897/25000 [07:26<01:26, 47.28it/s]geo grid grad stat: %=0.0050 mu=-1.48e-11 mu=6.61e-10 std=2.04e-09 min=-8.29e-08 max=7.82e-08
#  84%|███████████████████████████████      | 20997/25000 [07:28<01:25, 46.87it/s]geo grid grad stat: %=0.0049 mu=2.04e-12 mu=6.75e-10 std=2.04e-09 min=-1.02e-07 max=1.08e-07
# scene_rep_reconstruction (fine): iter  21000 / Loss: 0.000141086 / PSNR: 31.78 / Eps: 00:07:29
#  84%|███████████████████████████████▏     | 21097/25000 [07:30<01:23, 46.83it/s]geo grid grad stat: %=0.0050 mu=-2.66e-11 mu=6.72e-10 std=2.07e-09 min=-9.93e-08 max=7.79e-08
#  85%|███████████████████████████████▎     | 21197/25000 [07:32<01:19, 47.74it/s]geo grid grad stat: %=0.0048 mu=-2.05e-11 mu=6.87e-10 std=2.18e-09 min=-9.79e-08 max=6.62e-08
#  85%|███████████████████████████████▌     | 21297/25000 [07:35<01:19, 46.68it/s]geo grid grad stat: %=0.0047 mu=-1.12e-12 mu=6.48e-10 std=2.02e-09 min=-1.09e-07 max=6.15e-08
#  86%|███████████████████████████████▋     | 21397/25000 [07:37<01:17, 46.65it/s]geo grid grad stat: %=0.0048 mu=-3.00e-11 mu=6.88e-10 std=2.14e-09 min=-1.22e-07 max=5.94e-08
#  86%|███████████████████████████████▊     | 21497/25000 [07:39<01:14, 46.80it/s]VolRepr-fg: sharpness 1000.00
# VolRepr-fg: occupancy mask activated ratio 0.1015 => 0.1005
# VolRepr-bg: occupancy mask activated ratio 0.3158 => 0.3158
# geo grid grad stat: %=0.0048 mu=-1.62e-11 mu=6.78e-10 std=2.15e-09 min=-1.30e-07 max=9.51e-08
# scene_rep_reconstruction (fine): iter  21500 / Loss: 0.000135398 / PSNR: 31.80 / Eps: 00:07:40
#  86%|███████████████████████████████▉     | 21597/25000 [07:41<01:11, 47.47it/s]geo grid grad stat: %=0.0050 mu=-9.59e-12 mu=6.59e-10 std=1.93e-09 min=-6.12e-08 max=5.30e-08
#  87%|████████████████████████████████     | 21697/25000 [07:43<01:09, 47.22it/s]geo grid grad stat: %=0.0047 mu=-7.28e-12 mu=6.47e-10 std=1.99e-09 min=-1.29e-07 max=5.84e-08
#  87%|████████████████████████████████▎    | 21797/25000 [07:45<01:08, 46.89it/s]geo grid grad stat: %=0.0049 mu=-2.83e-11 mu=7.01e-10 std=2.14e-09 min=-1.08e-07 max=5.38e-08
#  88%|████████████████████████████████▍    | 21897/25000 [07:48<01:05, 47.22it/s]geo grid grad stat: %=0.0050 mu=-1.43e-11 mu=6.73e-10 std=2.04e-09 min=-8.27e-08 max=8.31e-08
#  88%|████████████████████████████████▌    | 21997/25000 [07:50<01:03, 47.03it/s]geo grid grad stat: %=0.0049 mu=-1.46e-11 mu=6.90e-10 std=2.11e-09 min=-1.08e-07 max=7.91e-08
# scene_rep_reconstruction (fine): iter  22000 / Loss: 0.000138591 / PSNR: 31.82 / Eps: 00:07:50
#  88%|████████████████████████████████▋    | 22097/25000 [07:52<01:01, 46.93it/s]geo grid grad stat: %=0.0050 mu=-2.23e-11 mu=6.76e-10 std=2.05e-09 min=-1.15e-07 max=6.56e-08
#  89%|████████████████████████████████▊    | 22197/25000 [07:54<00:59, 47.18it/s]geo grid grad stat: %=0.0049 mu=-1.40e-11 mu=6.74e-10 std=2.05e-09 min=-9.76e-08 max=5.93e-08
#  89%|████████████████████████████████▉    | 22297/25000 [07:56<00:57, 47.34it/s]geo grid grad stat: %=0.0049 mu=-1.74e-12 mu=6.42e-10 std=1.94e-09 min=-1.07e-07 max=6.10e-08
#  90%|█████████████████████████████████▏   | 22397/25000 [07:58<00:55, 46.98it/s]geo grid grad stat: %=0.0048 mu=-9.72e-12 mu=6.73e-10 std=1.97e-09 min=-8.62e-08 max=4.08e-08
#  90%|█████████████████████████████████▎   | 22497/25000 [08:01<00:53, 47.13it/s]VolRepr-fg: sharpness 1000.00
# VolRepr-fg: occupancy mask activated ratio 0.1005 => 0.0996
# VolRepr-bg: occupancy mask activated ratio 0.3158 => 0.3158
# geo grid grad stat: %=0.0048 mu=-2.99e-11 mu=6.78e-10 std=2.03e-09 min=-9.52e-08 max=6.22e-08
# scene_rep_reconstruction (fine): iter  22500 / Loss: 0.000133944 / PSNR: 31.84 / Eps: 00:08:01
#  90%|█████████████████████████████████▍   | 22597/25000 [08:03<00:51, 47.03it/s]geo grid grad stat: %=0.0050 mu=-1.25e-11 mu=6.68e-10 std=1.99e-09 min=-8.24e-08 max=8.00e-08
#  91%|█████████████████████████████████▌   | 22697/25000 [08:05<00:48, 47.03it/s]geo grid grad stat: %=0.0047 mu=-2.86e-11 mu=6.93e-10 std=2.13e-09 min=-1.50e-07 max=5.81e-08
#  91%|█████████████████████████████████▋   | 22797/25000 [08:07<00:46, 47.22it/s]geo grid grad stat: %=0.0047 mu=-3.79e-11 mu=6.73e-10 std=2.00e-09 min=-1.19e-07 max=4.47e-08
#  92%|█████████████████████████████████▉   | 22897/25000 [08:09<00:44, 47.07it/s]geo grid grad stat: %=0.0049 mu=-2.08e-11 mu=6.70e-10 std=2.05e-09 min=-6.24e-08 max=1.34e-07
#  92%|██████████████████████████████████   | 22997/25000 [08:11<00:42, 47.17it/s]geo grid grad stat: %=0.0048 mu=-6.45e-12 mu=6.56e-10 std=1.96e-09 min=-1.11e-07 max=6.44e-08
# scene_rep_reconstruction (fine): iter  23000 / Loss: 0.000132363 / PSNR: 31.88 / Eps: 00:08:12
#  92%|██████████████████████████████████▏  | 23097/25000 [08:13<00:39, 47.62it/s]geo grid grad stat: %=0.0048 mu=-2.79e-11 mu=6.74e-10 std=2.09e-09 min=-1.23e-07 max=6.95e-08
#  93%|██████████████████████████████████▎  | 23197/25000 [08:16<00:37, 47.57it/s]geo grid grad stat: %=0.0048 mu=-6.92e-12 mu=6.41e-10 std=1.88e-09 min=-1.23e-07 max=6.85e-08
#  93%|██████████████████████████████████▍  | 23297/25000 [08:18<00:36, 47.29it/s]geo grid grad stat: %=0.0048 mu=-2.62e-11 mu=7.05e-10 std=2.10e-09 min=-1.24e-07 max=3.73e-08
#  94%|██████████████████████████████████▋  | 23397/25000 [08:20<00:33, 47.58it/s]geo grid grad stat: %=0.0049 mu=-5.79e-12 mu=6.22e-10 std=1.87e-09 min=-8.00e-08 max=7.50e-08
#  94%|██████████████████████████████████▊  | 23497/25000 [08:22<00:32, 46.84it/s]VolRepr-fg: sharpness 1000.00
# VolRepr-fg: occupancy mask activated ratio 0.0996 => 0.0988
# VolRepr-bg: occupancy mask activated ratio 0.3158 => 0.3158
# geo grid grad stat: %=0.0047 mu=-3.40e-11 mu=7.16e-10 std=2.28e-09 min=-1.24e-07 max=7.17e-08
# scene_rep_reconstruction (fine): iter  23500 / Loss: 0.000131774 / PSNR: 31.89 / Eps: 00:08:23
#  94%|██████████████████████████████████▉  | 23597/25000 [08:24<00:29, 47.03it/s]geo grid grad stat: %=0.0048 mu=-1.85e-11 mu=6.88e-10 std=2.03e-09 min=-9.46e-08 max=5.28e-08
#  95%|███████████████████████████████████  | 23697/25000 [08:26<00:27, 47.75it/s]geo grid grad stat: %=0.0048 mu=-3.16e-11 mu=6.80e-10 std=2.05e-09 min=-8.04e-08 max=6.28e-08
#  95%|███████████████████████████████████▏ | 23797/25000 [08:28<00:25, 47.34it/s]geo grid grad stat: %=0.0049 mu=-3.38e-11 mu=7.02e-10 std=2.19e-09 min=-2.28e-07 max=7.67e-08
#  96%|███████████████████████████████████▎ | 23897/25000 [08:31<00:23, 47.86it/s]geo grid grad stat: %=0.0048 mu=-1.04e-11 mu=6.77e-10 std=2.08e-09 min=-1.76e-07 max=1.10e-07
#  96%|███████████████████████████████████▌ | 23997/25000 [08:33<00:21, 47.72it/s]geo grid grad stat: %=0.0051 mu=-2.77e-11 mu=6.72e-10 std=2.02e-09 min=-7.73e-08 max=7.86e-08
# scene_rep_reconstruction (fine): iter  24000 / Loss: 0.000133216 / PSNR: 31.92 / Eps: 00:08:33
#  96%|███████████████████████████████████▋ | 24097/25000 [08:35<00:19, 47.44it/s]geo grid grad stat: %=0.0046 mu=-2.67e-11 mu=7.00e-10 std=2.05e-09 min=-8.69e-08 max=6.24e-08
#  97%|███████████████████████████████████▊ | 24197/25000 [08:37<00:16, 47.47it/s]geo grid grad stat: %=0.0047 mu=-2.38e-12 mu=6.44e-10 std=1.89e-09 min=-6.89e-08 max=8.26e-08
#  97%|███████████████████████████████████▉ | 24297/25000 [08:39<00:14, 46.93it/s]geo grid grad stat: %=0.0047 mu=-2.08e-11 mu=6.78e-10 std=2.05e-09 min=-8.47e-08 max=8.83e-08
#  98%|████████████████████████████████████ | 24397/25000 [08:41<00:12, 46.88it/s]geo grid grad stat: %=0.0047 mu=-3.96e-11 mu=6.39e-10 std=2.04e-09 min=-1.10e-07 max=4.84e-08
#  98%|████████████████████████████████████▎| 24497/25000 [08:44<00:10, 47.70it/s]VolRepr-fg: sharpness 1000.00
# VolRepr-fg: occupancy mask activated ratio 0.0988 => 0.0980
# VolRepr-bg: occupancy mask activated ratio 0.3158 => 0.3158
# geo grid grad stat: %=0.0047 mu=-1.69e-11 mu=6.29e-10 std=1.91e-09 min=-9.05e-08 max=4.88e-08
# scene_rep_reconstruction (fine): iter  24500 / Loss: 0.000125218 / PSNR: 31.92 / Eps: 00:08:44
#  98%|████████████████████████████████████▍| 24597/25000 [08:46<00:08, 47.34it/s]geo grid grad stat: %=0.0048 mu=-2.76e-11 mu=7.19e-10 std=2.13e-09 min=-9.27e-08 max=5.10e-08
#  99%|████████████████████████████████████▌| 24697/25000 [08:48<00:06, 47.09it/s]geo grid grad stat: %=0.0050 mu=-1.96e-11 mu=6.75e-10 std=2.04e-09 min=-1.08e-07 max=6.31e-08
#  99%|████████████████████████████████████▋| 24797/25000 [08:50<00:04, 47.38it/s]geo grid grad stat: %=0.0046 mu=-2.43e-11 mu=6.45e-10 std=1.99e-09 min=-6.47e-08 max=6.19e-08
# 100%|████████████████████████████████████▊| 24897/25000 [08:52<00:02, 47.21it/s]geo grid grad stat: %=0.0049 mu=-3.99e-11 mu=6.94e-10 std=2.10e-09 min=-6.85e-08 max=6.37e-08
# 100%|████████████████████████████████████▉| 24997/25000 [08:54<00:00, 47.61it/s]geo grid grad stat: %=0.0045 mu=-1.84e-11 mu=6.84e-10 std=2.12e-09 min=-6.94e-08 max=1.23e-07
# scene_rep_reconstruction (fine): iter  25000 / Loss: 0.000126646 / PSNR: 31.94 / Eps: 00:08:55
# 100%|█████████████████████████████████████| 25000/25000 [08:54<00:00, 46.74it/s]
# scene_rep_reconstruction (fine): saving checkpoints...
# scene_rep_reconstruction (fine): saved checkpoints at results/stanford_orb/baking_scene001/neural_surface_recon/fine_last.pth
# train: fine detail reconstruction in 00:08:56
# train: finish (eps time 00:08:56 )
# /home/ahc/Documents/metrology_ir/DigitalTwinCatalog/neural_pbir/neural_surface_recon/lib/utils.py:187: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(path, *args, **kwargs)
# VolRepr-fg: voxel_size       tensor(0.0040)
# VolRepr-fg: world_size       tensor([300, 300, 300])
# VolRepr-fg: world_size_k0    tensor([300, 300, 300])
# VolRepr-fg: voxel_size_base  tensor(0.0075)
# VolRepr-fg: voxel_size_ratio tensor(0.5333)
# VolRepr-fg: geometry grid DenseGrid(channels=1, world_size=[300, 300, 300])
# VolRepr-fg: feature voxel grid DenseGrid(channels=12, world_size=[300, 300, 300])
# VolRepr-fg: mlp MLP_torch(
#   (mlp): Sequential(
#     (0): Linear(in_features=39, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Sequential(
#       (0): Linear(in_features=128, out_features=128, bias=True)
#       (1): ReLU(inplace=True)
#     )
#     (3): Linear(in_features=128, out_features=3, bias=True)
#   )
# )
# VolRepr-bg: set density bias shift to tensor([-4.5951], device='cpu')
# VolRepr-bg: voxel_size       tensor(0.1200)
# VolRepr-bg: world_size       tensor([160, 160, 160])
# VolRepr-bg: world_size_k0    tensor([160, 160, 160])
# VolRepr-bg: voxel_size_base  tensor(0.1200)
# VolRepr-bg: voxel_size_ratio tensor(1.)
# VolRepr-bg: geometry grid DenseGrid(channels=1, world_size=[160, 160, 160])
# VolRepr-bg: feature voxel grid DenseGrid(channels=8, world_size=[160, 160, 160])
# VolRepr-bg: mlp MLP_tcnn(
#   (mlp): Network(n_input_dims=35, n_output_dims=3, seed=1337, dtype=torch.float16, hyperparams={'encoding': {'offset': 0.0, 'otype': 'Identity', 'scale': 1.0}, 'network': {'activation': 'ReLU', 'n_hidden_layers': 2, 'n_neurons': 64, 'otype': 'FullyFusedMLP', 'output_activation': 'None'}, 'otype': 'NetworkWithInputEncoding'})
# )
# All results are dumped into results/stanford_orb/baking_scene001/neural_surface_recon/render_video_fine_last
#   0%|                                                   | 0/120 [00:00<?, ?it/s]Testing (512, 512, 3)
# 100%|█████████████████████████████████████████| 120/120 [00:01<00:00, 85.89it/s]
# ==================================================
# Extracting mesh
# Removed 1 isolated connected components.
# Dumping mesh
# Remeshing...
# The mesh is dumped into results/stanford_orb/baking_scene001/neural_surface_recon/mesh.obj
# Using blender to uv unwrap for results/stanford_orb/baking_scene001/neural_surface_recon/mesh.obj
# Blender 4.0.2
# Traceback (most recent call last):
#   File "/home/ahc/Documents/metrology_ir/DigitalTwinCatalog/neural_pbir/neural_surface_recon/lib/uv_blender.py", line 29, in <module>
#     import_obj(obj_in_fn)
#   File "/home/ahc/Documents/metrology_ir/DigitalTwinCatalog/neural_pbir/neural_surface_recon/lib/uv_blender.py", line 15, in import_obj
#     bpy.ops.import_scene.obj(filepath=obj_path)
#   File "/usr/share/blender/scripts/modules/bpy/ops.py", line 109, in __call__
#     ret = _op_call(self.idname_py(), kw)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Calling operator "bpy.ops.import_scene.obj" error, could not be found
#
# Blender quit
# The uv mesh is dumped into results/stanford_orb/baking_scene001/neural_surface_recon/mesh.obj
# ==================================================
# The bg 360 image is dumped into results/stanford_orb/baking_scene001/neural_surface_recon/bg360.png
# /home/ahc/Documents/metrology_ir/DigitalTwinCatalog/neural_pbir/neural_surface_recon/lib/utils.py:187: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(path, *args, **kwargs)
# The cam2world matrices are dumped into results/stanford_orb/baking_scene001/neural_surface_recon/to_worlds_after.txt
# Done

# %%
CHKPT="./results/stanford_orb"

# !python {NPBIR}/neural_distillation/run.py {CHKPT}/baking_scene001/

# %%
# !python {NPBIR}/pbir/run.py {NPBIR}/configs/template {CHKPT}/blender_HDR/baking_scene001/

# %%
# !python {NPBIR}/scripts/stanford_orb/eval_preprocess.py --data_dir /home/ahc/Datasets/Stanford-ORB/  --ckpt_dir {CHKPT}/
