# %% [markdown]
# * Radiance field is tightly coupled with geometric SDF field (similiar to NeuS, NeRF, DVGO)
# * Distillation stage is tightly coupled with both radiance and geometric field ==> PBIR fine-tuning is tightly coupled with the distilled mesh (mesh with materials and lighting pre-distilled already)
# * Only viable (and probably most sensible anyway) method to test for geometric sensitivity in NPBIR is given the GT mesh, assign the best GT SDF values at each doubling of the voxel resolution (only at the geometric) for the purpose of learning the radiance field, and we just replace the final output mesh as the GT mesh again from Stanford-ORB.

# %%
ALL_METHODS = [
    "results___NPBIR___EST_g__EST_l",  # OG
    "results___NPBIR____GT_g__EST_l",
    "results___NPBIR___EST_g___GT_l",
    "results___NPBIR__VGGT_g__EST_l",
    "results___NPBIR__VGGT_g___GT_l",
    # "results_MITSUBA__VGGT_g__EST_l",
    # "results_MITSUBA____GT_g__EST_l",
    # "results_MITSUBA__VGGT_g___GT_l",
]


METHOD=ALL_METHODS[1]
NPBIR="./DigitalTwinCatalog/neural_pbir"
CHKPT=f"./{METHOD}/stanford_orb"
SORB = "/home/ahc/Datasets/Stanford-ORB"
SORB_HDR = f"{SORB}/blender_HDR"
SORB_GT = f"{SORB}/ground_truth"
SCENE = "teapot_scene001" # "baking_scene001"

# %%
# run once per new scene within the dataset itself (regardless of method, etc.)
# !python DigitalTwinCatalog/neural_pbir/scripts/preprocess/stanford_orb.py /home/ahc/Datasets/Stanford-ORB/blender_HDR/{SCENE}

# !python {NPBIR}/neural_surface_recon/run_template.py --template {NPBIR}/neural_surface_recon/configs/template_stanford_orb.py --savemem {SORB_HDR}/{SCENE}/ --mesh_init_path={SORB_GT}/{SCENE}/mesh_blender/mesh.obj
# !mv results {METHOD}
# ^^^^^^^^^^^^^^^^^^^^^
# we probably only care about neural_surface_recon/mesh.obj?????


# !python {NPBIR}/neural_distillation/run.py {CHKPT}/{SCENE}/
# !python {NPBIR}/pbir/run.py {NPBIR}/pbir/configs/template {CHKPT}/{SCENE}/
# !python {NPBIR}/scripts/stanford_orb/render_geo.py {SORB_HDR}/{SCENE}/cameras.json {CHKPT}/{SCENE}/pbir/mesh.obj

# !python {NPBIR}/scripts/stanford_orb/postproc_envmap_our.py "{CHKPT}/{SCENE}/pbir/envmap.exr"

# NOVEL VIEW SYNTHESIS
CAM=f"{SORB_HDR}/{SCENE}/cameras.json"
CKPT_GEO=f"{CHKPT}/{SCENE}/pbir/mesh.obj"
CKPT_ALBEDO=f"{CHKPT}/{SCENE}/pbir/diffuse.exr"
CKPT_ROUGH=f"{CHKPT}/{SCENE}/pbir/roughness.exr"
CKPT_ENV=f"{CHKPT}/{SCENE}/pbir/envmap_for_blender.exr"
# !python {NPBIR}/scripts/relit/relit.py {CKPT_GEO} {CKPT_ALBEDO} {CKPT_ROUGH} {CAM} --lgt_paths {CKPT_ENV} --render_exr --with_bg

# RELIGHTING
# !python {NPBIR}/scripts/stanford_orb/relit_nl.py --ckptroot {CHKPT} --dataroot {SORB}


# !python {NPBIR}/scripts/stanford_orb/eval_preprocess.py --data_dir {SORB}/  --ckpt_dir {CHKPT}/
# !cd Stanford-ORB && PYTHONPATH=. python scripts/test.py --input-path ../{CHKPT}/eval_inputs_pbir.json --output-path ../{CHKPT}/eval_outputs_pbir.json --scenes example
# Out:
# /home/ahc/miniconda3/envs/metrology_ir/lib/python3.11/site-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# /home/ahc/miniconda3/envs/metrology_ir/lib/python3.11/site-packages/torch/__init__.py:955: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:432.)
#   _C._set_default_tensor_type(t)
# ==> Load checkpoint
# /home/ahc/Documents/metrology_ir/./DigitalTwinCatalog/neural_pbir/neural_distillation/run.py:92: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(
# VolRepr-fg: voxel_size       tensor(0.0040)
# VolRepr-fg: world_size       tensor([300, 300, 300])
# VolRepr-fg: world_size_k0    tensor([300, 300, 300])
# VolRepr-fg: voxel_size_base  tensor(0.0075)
# VolRepr-fg: voxel_size_ratio tensor(0.5333)
# VolRepr-fg: geometry grid DenseGrid(channels=1, world_size=[300, 300, 300])
# VolRepr-fg: feature voxel grid DenseGrid(channels=12, world_size=[300, 300, 300])
# VolRepr-fg: mlp MLP_torch(
#   (mlp): Sequential(
#     (0): Linear(in_features=39, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Sequential(
#       (0): Linear(in_features=128, out_features=128, bias=True)
#       (1): ReLU(inplace=True)
#     )
#     (3): Linear(in_features=128, out_features=3, bias=True)
#   )
# )
# VolRepr-bg: set density bias shift to tensor([-4.5951], device='cpu')
# VolRepr-bg: voxel_size       tensor(0.1200)
# VolRepr-bg: world_size       tensor([160, 160, 160])
# VolRepr-bg: world_size_k0    tensor([160, 160, 160])
# VolRepr-bg: voxel_size_base  tensor(0.1200)
# VolRepr-bg: voxel_size_ratio tensor(1.)
# VolRepr-bg: geometry grid DenseGrid(channels=1, world_size=[160, 160, 160])
# VolRepr-bg: feature voxel grid DenseGrid(channels=8, world_size=[160, 160, 160])
# VolRepr-bg: mlp MLP_tcnn(
#   (mlp): Network(n_input_dims=35, n_output_dims=3, seed=1337, dtype=torch.float16, hyperparams={'encoding': {'offset': 0.0, 'otype': 'Identity', 'scale': 1.0}, 'network': {'activation': 'ReLU', 'n_hidden_layers': 2, 'n_neurons': 64, 'otype': 'FullyFusedMLP', 'output_activation': 'None'}, 'otype': 'NetworkWithInputEncoding'})
# )
# ==> Compute avg bg observation
# Start loading dataset...
# 100%|██████████████████████████████████████████| 70/70 [00:00<00:00, 281.98it/s]
# Finish loading dataset in 1.0 sec.
# Loaded dataset: (70, 512, 512, 3) /home/ahc/Datasets/Stanford-ORB/blender_HDR/teapot_scene001
# # train: 60
# # test: 10 [60 61 62 63 64 65 66 67 68 69]
# get_training_rays_offline_sampler: start
# get_training_rays_offline_sampler: ratio tensor(1.)
# get_training_rays_offline_sampler: finish (eps time: 0.15147948265075684 sec)
# 100%|████████████████████████████████████████| 241/241 [00:00<00:00, 282.70it/s]
# ==> Load mesh
# ====> # verts:     281038
# ====> # faces:     531290
# ====> # texel to optimize:    1045302
# ==> Create material field / envmap sg / optimizer
# 100%|█████████████████████████████████████████| 128/128 [00:01<00:00, 66.97it/s]
# ==> Pre-compute visibility and indirect illumination
# 100%|████████████████████████████████████████| 256/256 [00:01<00:00, 197.81it/s]
# ==> Split texels into 53 chunks to save gpu mem
# ==> Start training
#   0%|                                                  | 0/1000 [00:00<?, ?it/s]==> iter=    0: psnr=13.9
#  10%|████                                    | 100/1000 [00:32<04:54,  3.06it/s]==> iter=  100: psnr=19.4
#  20%|████████                                | 200/1000 [01:05<04:21,  3.05it/s]==> iter=  200: psnr=23.9
#  30%|████████████                            | 300/1000 [01:38<03:49,  3.05it/s]==> iter=  300: psnr=24.3
#  40%|████████████████                        | 400/1000 [02:10<03:16,  3.05it/s]==> iter=  400: psnr=24.4
#  50%|████████████████████                    | 500/1000 [02:43<02:43,  3.05it/s]==> iter=  500: psnr=24.6
#  60%|████████████████████████                | 600/1000 [03:16<02:11,  3.05it/s]==> iter=  600: psnr=24.7
#  70%|████████████████████████████            | 700/1000 [03:49<01:38,  3.05it/s]==> iter=  700: psnr=24.7
#  80%|████████████████████████████████        | 800/1000 [04:22<01:05,  3.05it/s]==> iter=  800: psnr=24.7
#  90%|████████████████████████████████████    | 900/1000 [04:54<00:32,  3.05it/s]==> iter=  900: psnr=24.8
# 100%|███████████████████████████████████████▉| 999/1000 [05:27<00:00,  3.05it/s]==> iter=  999: psnr=24.8
# 100%|███████████████████████████████████████| 1000/1000 [05:27<00:00,  3.05it/s]
# ==> Post-processing
# ==> Save to results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/neural_distillation/
# /home/ahc/miniconda3/envs/metrology_ir/lib/python3.11/site-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# Running stage microfacet_naive-envmap_sg...
# /home/ahc/miniconda3/envs/metrology_ir/lib/python3.11/site-packages/gin/config.py:615: FutureWarning: `NLLLoss2d` has been deprecated. Please use `NLLLoss` instead as a drop-in replacement and see https://pytorch.org/docs/main/nn.html#torch.nn.NLLLoss for more details.
#   decorated_class = decorating_meta(cls.__name__, (cls,), overrides)
# Envmap2SG step: 1, loss: 1.4601905345916748
# Envmap2SG step: 100, loss: 0.0018888640915974975
# Starting the optimization...
# 100%|█████████████████████████████████████████| 500/500 [01:29<00:00,  5.60it/s]
# Writing final outputs...
# Done.
# Running stage microfacet_basis-envmap_ls...
# Initializing using NMF...
# Done.
# Starting the optimization...
# 100%|█████████████████████████████████████████| 500/500 [01:40<00:00,  5.00it/s]
# Writing final outputs...
# Done.
# Final results are written to results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir
# /home/ahc/miniconda3/envs/metrology_ir/lib/python3.11/site-packages/pytorch3d/io/obj_io.py:547: UserWarning: No mtl file provided
#   warnings.warn("No mtl file provided")
# 100%|███████████████████████████████████████████| 10/10 [00:00<00:00, 10.38it/s]
# Save to results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/envmap_for_blender.exr
# Blender 3.6.21 (hash e7f18247b228 built 2025-02-18 08:11:48)
# xcb_connection_has_error() returned true
# Failed to open dir (No such file or directory): /run/user/1000/gvfs/
# Read blend: "/home/ahc/Documents/metrology_ir/DigitalTwinCatalog/neural_pbir/scripts/relit/relit.blend"
# Results are dumped to /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit
# Set fov: 20.327493328509615 deg
# Loading mesh: /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/mesh.obj
# (  0.0000 sec |   0.0000 sec) Importing OBJ '/home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/mesh.obj'...
#   (  0.0000 sec |   0.0000 sec) Parsing OBJ file...
#     (  2.3916 sec |   2.3916 sec) Done, loading materials and images...
#     (  2.3942 sec |   2.3941 sec) Done, building geometries (verts:265645 faces:531290 materials: 1 smoothgroups:0) ...
#     (  3.2836 sec |   3.2836 sec) Done.
#   (  3.2837 sec |   3.2837 sec) Finished importing: '/home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/mesh.obj'
# Progress: 100.00%
#
# Set albedo: /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/diffuse.exr
# Set roughenss: /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/roughness.exr
# /home/ahc/Documents/metrology_ir/DigitalTwinCatalog/neural_pbir/scripts/relit/blender_script.py:144: DeprecationWarning: Passing in context overrides is deprecated in favor of Context.temp_override(..), calling "object.delete"
#   bpy.ops.object.delete({"selected_objects": objs})
# Set environment map: /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/envmap_for_blender.exr
# Writing: im_0000_image_envmap_for_blender
# Fra:29 Mem:72.35M (Peak 72.36M) | Time:00:00.00 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Synchronizing object | mesh
# Fra:29 Mem:116.43M (Peak 128.59M) | Time:00:00.02 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Initializing
# Fra:29 Mem:116.42M (Peak 128.59M) | Time:00:00.02 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Updating Images | Loading sunrise.exr
# Fra:29 Mem:124.44M (Peak 140.43M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Waiting for render to start
# Fra:29 Mem:124.44M (Peak 140.43M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Loading render kernels (may take a few minutes the first time)
# Fra:29 Mem:124.44M (Peak 140.43M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Scene
# Fra:29 Mem:124.44M (Peak 140.43M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Shaders
# Fra:29 Mem:124.44M (Peak 140.43M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Procedurals
# Fra:29 Mem:124.44M (Peak 140.43M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Background
# Fra:29 Mem:124.44M (Peak 140.43M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Camera
# Fra:29 Mem:124.44M (Peak 140.43M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Meshes Flags
# Fra:29 Mem:124.44M (Peak 140.43M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Objects
# Fra:29 Mem:124.44M (Peak 140.43M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Objects | Copying Transformations to device
# Fra:29 Mem:124.44M (Peak 140.43M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Objects | Applying Static Transformations
# Fra:29 Mem:124.44M (Peak 140.43M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Particle Systems
# Fra:29 Mem:124.44M (Peak 140.43M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Particle Systems | Copying Particles to device
# Fra:29 Mem:124.44M (Peak 140.43M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Meshes
# Fra:29 Mem:132.55M (Peak 140.43M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Mesh | Computing attributes
# Fra:29 Mem:147.75M (Peak 147.75M) | Time:00:00.04 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Mesh | Copying Attributes to device
# Fra:29 Mem:147.75M (Peak 147.75M) | Time:00:00.04 | Mem:23.20M, Peak:23.20M | Scene, View Layer | Updating Scene BVH | Building
# Fra:29 Mem:147.75M (Peak 147.75M) | Time:00:00.04 | Mem:23.20M, Peak:23.20M | Scene, View Layer | Updating Scene BVH | Building BVH
# Fra:29 Mem:147.75M (Peak 147.75M) | Time:00:00.04 | Mem:39.42M, Peak:39.42M | Scene, View Layer | Updating Scene BVH | Building BVH 0%
# Fra:29 Mem:147.75M (Peak 147.75M) | Time:00:00.05 | Mem:58.74M, Peak:74.96M | Scene, View Layer | Updating Scene BVH | Copying BVH to device
# Fra:29 Mem:147.75M (Peak 147.75M) | Time:00:00.05 | Mem:58.74M, Peak:74.96M | Scene, View Layer | Updating Mesh | Computing normals
# Fra:29 Mem:165.99M (Peak 165.99M) | Time:00:00.05 | Mem:58.74M, Peak:74.96M | Scene, View Layer | Updating Mesh | Copying Mesh to device
# Fra:29 Mem:165.99M (Peak 165.99M) | Time:00:00.05 | Mem:76.98M, Peak:76.98M | Scene, View Layer | Updating Objects Flags
# Fra:29 Mem:165.99M (Peak 165.99M) | Time:00:00.05 | Mem:76.98M, Peak:76.98M | Scene, View Layer | Updating Primitive Offsets
# Fra:29 Mem:165.99M (Peak 165.99M) | Time:00:00.05 | Mem:76.98M, Peak:76.98M | Scene, View Layer | Updating Images
# Fra:29 Mem:157.99M (Peak 165.99M) | Time:00:00.05 | Mem:68.98M, Peak:76.98M | Scene, View Layer | Updating Images | Loading roughness.exr
# Fra:29 Mem:173.99M (Peak 173.99M) | Time:00:00.05 | Mem:68.98M, Peak:76.98M | Scene, View Layer | Updating Images | Loading diffuse.exr
# Fra:29 Mem:189.99M (Peak 189.99M) | Time:00:00.05 | Mem:68.98M, Peak:76.98M | Scene, View Layer | Updating Images | Loading envmap_for_blender.exr
# Fra:29 Mem:190.49M (Peak 190.49M) | Time:00:00.06 | Mem:101.48M, Peak:101.48M | Scene, View Layer | Updating Camera Volume
# Fra:29 Mem:190.49M (Peak 190.49M) | Time:00:00.06 | Mem:101.48M, Peak:101.48M | Scene, View Layer | Updating Lookup Tables
# Fra:29 Mem:190.49M (Peak 190.49M) | Time:00:00.06 | Mem:101.48M, Peak:101.48M | Scene, View Layer | Updating Lights
# Fra:29 Mem:190.49M (Peak 190.49M) | Time:00:00.06 | Mem:101.49M, Peak:101.49M | Scene, View Layer | Updating Lights | Importance map
# Fra:29 Mem:254.52M (Peak 542.49M) | Time:00:00.17 | Mem:165.53M, Peak:325.50M | Scene, View Layer | Updating Lights | Computing distribution
# Fra:29 Mem:254.52M (Peak 542.49M) | Time:00:00.17 | Mem:165.53M, Peak:325.50M | Scene, View Layer | Updating Integrator
# Fra:29 Mem:255.52M (Peak 542.49M) | Time:00:00.17 | Mem:166.53M, Peak:325.50M | Scene, View Layer | Updating Film
# Fra:29 Mem:255.52M (Peak 542.49M) | Time:00:00.17 | Mem:166.53M, Peak:325.50M | Scene, View Layer | Updating Lookup Tables
# Fra:29 Mem:255.52M (Peak 542.49M) | Time:00:00.17 | Mem:166.53M, Peak:325.50M | Scene, View Layer | Updating Baking
# Fra:29 Mem:255.52M (Peak 542.49M) | Time:00:00.17 | Mem:166.53M, Peak:325.50M | Scene, View Layer | Updating Device | Writing constant memory
# Fra:29 Mem:255.52M (Peak 542.49M) | Time:00:00.17 | Mem:166.53M, Peak:325.50M | Scene, View Layer | Sample 0/128
# Fra:29 Mem:273.51M (Peak 542.49M) | Time:00:00.18 | Remaining:00:01.01 | Mem:184.43M, Peak:325.50M | Scene, View Layer | Sample 1/128
# Fra:29 Mem:285.44M (Peak 542.49M) | Time:00:00.67 | Mem:184.43M, Peak:325.50M | Scene, View Layer | Sample 128/128
# Fra:29 Mem:285.44M (Peak 542.49M) | Time:00:00.67 | Mem:184.43M, Peak:325.50M | Scene, View Layer | Finished
# Fra:29 Mem:285.52M (Peak 542.49M) | Time:00:00.67 | Compositing
# Fra:29 Mem:285.52M (Peak 542.49M) | Time:00:00.68 | Compositing | Determining resolution
# Fra:29 Mem:285.52M (Peak 542.49M) | Time:00:00.68 | Compositing | Initializing execution
# Fra:29 Mem:296.59M (Peak 542.49M) | Time:00:00.68 | Compositing | Tile 1-4
# Fra:29 Mem:296.59M (Peak 542.49M) | Time:00:00.68 | Compositing | Tile 2-4
# Fra:29 Mem:296.59M (Peak 542.49M) | Time:00:00.68 | Compositing | Tile 3-4
# Fra:29 Mem:296.59M (Peak 542.49M) | Time:00:00.68 | Compositing | Tile 4-4
# Fra:29 Mem:296.59M (Peak 542.49M) | Time:00:00.68 | Compositing | Tile 1-4
# Fra:29 Mem:296.59M (Peak 542.49M) | Time:00:00.68 | Compositing | Tile 3-4
# Fra:29 Mem:296.59M (Peak 542.49M) | Time:00:00.68 | Compositing | Tile 2-4
# Fra:29 Mem:296.59M (Peak 542.49M) | Time:00:00.68 | Compositing | Tile 4-4
# Fra:29 Mem:296.59M (Peak 542.49M) | Time:00:00.68 | Compositing | Tile 1-4
# Fra:29 Mem:296.59M (Peak 542.49M) | Time:00:00.68 | Compositing | Tile 2-4
# Fra:29 Mem:296.59M (Peak 542.49M) | Time:00:00.68 | Compositing | Tile 3-4
# Fra:29 Mem:296.59M (Peak 542.49M) | Time:00:00.68 | Compositing | Tile 4-4
# Fra:29 Mem:296.59M (Peak 542.49M) | Time:00:00.68 | Compositing | Tile 1-4
# Fra:29 Mem:296.59M (Peak 542.49M) | Time:00:00.68 | Compositing | Tile 2-4
# Fra:29 Mem:296.59M (Peak 542.49M) | Time:00:00.68 | Compositing | Tile 3-4
# Fra:29 Mem:296.59M (Peak 542.49M) | Time:00:00.68 | Compositing | Tile 4-4
# Fra:29 Mem:296.52M (Peak 542.49M) | Time:00:00.68 | Compositing | De-initializing execution
# Saved: Image0029.png
# Saved: Image0029.png
# Saved: /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0000_image_albedo0029.exr
# Saved: '/home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0000_image_envmap_for_blender.exr'
#  Time: 00:00.71 (Saving: 00:00.00)
#
# Writing: im_0007_image_envmap_for_blender
# Fra:29 Mem:273.52M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Initializing
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Waiting for render to start
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Scene
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Shaders
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Background
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Camera
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Objects
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Particle Systems
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Meshes
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Objects Flags
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Primitive Offsets
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Images
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Camera Volume
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Lookup Tables
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Lights
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Integrator
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Film
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Lookup Tables
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Baking
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Device | Writing constant memory
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Sample 0/128
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Remaining:00:00.53 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Sample 1/128
# Fra:29 Mem:285.44M (Peak 301.35M) | Time:00:00.47 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Sample 128/128
# Fra:29 Mem:285.44M (Peak 301.35M) | Time:00:00.47 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Finished
# Fra:29 Mem:285.52M (Peak 301.35M) | Time:00:00.47 | Compositing
# Fra:29 Mem:285.52M (Peak 301.35M) | Time:00:00.47 | Compositing | Determining resolution
# Fra:29 Mem:285.52M (Peak 301.35M) | Time:00:00.47 | Compositing | Initializing execution
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.48 | Compositing | Tile 1-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.48 | Compositing | Tile 2-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.48 | Compositing | Tile 3-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.48 | Compositing | Tile 4-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.48 | Compositing | Tile 2-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.48 | Compositing | Tile 3-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.48 | Compositing | Tile 4-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.48 | Compositing | Tile 1-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.48 | Compositing | Tile 1-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.48 | Compositing | Tile 2-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.48 | Compositing | Tile 3-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.48 | Compositing | Tile 4-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.48 | Compositing | Tile 1-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.48 | Compositing | Tile 2-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.48 | Compositing | Tile 3-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.48 | Compositing | Tile 4-4
# Fra:29 Mem:296.52M (Peak 301.35M) | Time:00:00.48 | Compositing | De-initializing execution
# Saved: Image0029.png
# Saved: Image0029.png
# Saved: /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0007_image_albedo0029.exr
# Saved: '/home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0007_image_envmap_for_blender.exr'
#  Time: 00:00.50 (Saving: 00:00.00)
#
# Writing: im_0014_image_envmap_for_blender
# Fra:29 Mem:273.52M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Initializing
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Waiting for render to start
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Scene
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Shaders
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Background
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Camera
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Objects
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Particle Systems
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Meshes
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Objects Flags
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Primitive Offsets
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Images
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Camera Volume
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Lookup Tables
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Lights
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Integrator
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Film
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Lookup Tables
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Baking
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Device | Writing constant memory
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Sample 0/128
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Remaining:00:00.54 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Sample 1/128
# Fra:29 Mem:285.44M (Peak 301.35M) | Time:00:00.47 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Sample 128/128
# Fra:29 Mem:285.44M (Peak 301.35M) | Time:00:00.47 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Finished
# Fra:29 Mem:285.52M (Peak 301.35M) | Time:00:00.47 | Compositing
# Fra:29 Mem:285.52M (Peak 301.35M) | Time:00:00.47 | Compositing | Determining resolution
# Fra:29 Mem:285.52M (Peak 301.35M) | Time:00:00.47 | Compositing | Initializing execution
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.48 | Compositing | Tile 1-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.48 | Compositing | Tile 2-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.48 | Compositing | Tile 3-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.48 | Compositing | Tile 4-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.48 | Compositing | Tile 1-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.48 | Compositing | Tile 2-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.48 | Compositing | Tile 3-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.48 | Compositing | Tile 4-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.48 | Compositing | Tile 1-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.48 | Compositing | Tile 2-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.48 | Compositing | Tile 3-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.48 | Compositing | Tile 4-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.48 | Compositing | Tile 1-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.48 | Compositing | Tile 2-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.48 | Compositing | Tile 3-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.48 | Compositing | Tile 4-4
# Fra:29 Mem:296.52M (Peak 301.35M) | Time:00:00.48 | Compositing | De-initializing execution
# Saved: Image0029.png
# Saved: Image0029.png
# Saved: /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0014_image_albedo0029.exr
# Saved: '/home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0014_image_envmap_for_blender.exr'
#  Time: 00:00.50 (Saving: 00:00.00)
#
# Writing: im_0021_image_envmap_for_blender
# Fra:29 Mem:273.52M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Initializing
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Waiting for render to start
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Scene
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Shaders
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Background
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Camera
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Objects
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Particle Systems
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Meshes
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Objects Flags
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Primitive Offsets
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Images
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Camera Volume
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Lookup Tables
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Lights
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Integrator
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Film
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Lookup Tables
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Baking
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Device | Writing constant memory
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Sample 0/128
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Remaining:00:00.50 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Sample 1/128
# Fra:29 Mem:285.44M (Peak 301.35M) | Time:00:00.43 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Sample 128/128
# Fra:29 Mem:285.44M (Peak 301.35M) | Time:00:00.43 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Finished
# Fra:29 Mem:285.52M (Peak 301.35M) | Time:00:00.43 | Compositing
# Fra:29 Mem:285.52M (Peak 301.35M) | Time:00:00.43 | Compositing | Determining resolution
# Fra:29 Mem:285.52M (Peak 301.35M) | Time:00:00.43 | Compositing | Initializing execution
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.43 | Compositing | Tile 1-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.43 | Compositing | Tile 2-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.43 | Compositing | Tile 3-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.43 | Compositing | Tile 4-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.43 | Compositing | Tile 2-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.43 | Compositing | Tile 4-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.43 | Compositing | Tile 4-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.43 | Compositing | Tile 1-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.43 | Compositing | Tile 1-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.43 | Compositing | Tile 2-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.43 | Compositing | Tile 3-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.43 | Compositing | Tile 4-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.43 | Compositing | Tile 1-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.43 | Compositing | Tile 2-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.44 | Compositing | Tile 3-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.44 | Compositing | Tile 4-4
# Fra:29 Mem:296.52M (Peak 301.35M) | Time:00:00.44 | Compositing | De-initializing execution
# Saved: Image0029.png
# Saved: Image0029.png
# Saved: /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0021_image_albedo0029.exr
# Saved: '/home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0021_image_envmap_for_blender.exr'
#  Time: 00:00.45 (Saving: 00:00.00)
#
# Writing: im_0028_image_envmap_for_blender
# Fra:29 Mem:273.52M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Initializing
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Waiting for render to start
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Scene
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Shaders
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Background
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Camera
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Objects
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Particle Systems
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Meshes
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Objects Flags
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Primitive Offsets
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Images
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Camera Volume
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Lookup Tables
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Lights
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Integrator
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Film
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Lookup Tables
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Baking
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Device | Writing constant memory
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Sample 0/128
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Remaining:00:00.61 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Sample 1/128
# Fra:29 Mem:285.44M (Peak 301.35M) | Time:00:00.49 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Sample 128/128
# Fra:29 Mem:285.44M (Peak 301.35M) | Time:00:00.49 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Finished
# Fra:29 Mem:285.52M (Peak 301.35M) | Time:00:00.50 | Compositing
# Fra:29 Mem:285.52M (Peak 301.35M) | Time:00:00.50 | Compositing | Determining resolution
# Fra:29 Mem:285.52M (Peak 301.35M) | Time:00:00.50 | Compositing | Initializing execution
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.50 | Compositing | Tile 1-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.50 | Compositing | Tile 2-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.50 | Compositing | Tile 3-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.50 | Compositing | Tile 4-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.50 | Compositing | Tile 1-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.50 | Compositing | Tile 2-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.50 | Compositing | Tile 3-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.50 | Compositing | Tile 4-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.50 | Compositing | Tile 1-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.50 | Compositing | Tile 2-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.50 | Compositing | Tile 3-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.50 | Compositing | Tile 4-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.50 | Compositing | Tile 1-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.50 | Compositing | Tile 2-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.50 | Compositing | Tile 3-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.50 | Compositing | Tile 4-4
# Fra:29 Mem:296.52M (Peak 301.35M) | Time:00:00.50 | Compositing | De-initializing execution
# Saved: Image0029.png
# Saved: Image0029.png
# Saved: /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0028_image_albedo0029.exr
# Saved: '/home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0028_image_envmap_for_blender.exr'
#  Time: 00:00.52 (Saving: 00:00.00)
#
# Writing: im_0035_image_envmap_for_blender
# Fra:29 Mem:273.52M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Initializing
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Waiting for render to start
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Scene
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Shaders
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Background
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Camera
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Objects
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Particle Systems
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Meshes
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Objects Flags
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Primitive Offsets
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Images
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Camera Volume
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Lookup Tables
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Lights
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Integrator
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Film
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Lookup Tables
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Baking
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Device | Writing constant memory
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Sample 0/128
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Remaining:00:00.46 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Sample 1/128
# Fra:29 Mem:285.44M (Peak 301.35M) | Time:00:00.41 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Sample 128/128
# Fra:29 Mem:285.44M (Peak 301.35M) | Time:00:00.41 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Finished
# Fra:29 Mem:285.52M (Peak 301.35M) | Time:00:00.42 | Compositing
# Fra:29 Mem:285.52M (Peak 301.35M) | Time:00:00.42 | Compositing | Determining resolution
# Fra:29 Mem:285.52M (Peak 301.35M) | Time:00:00.42 | Compositing | Initializing execution
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.42 | Compositing | Tile 1-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.42 | Compositing | Tile 2-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.42 | Compositing | Tile 3-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.42 | Compositing | Tile 4-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.42 | Compositing | Tile 1-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.42 | Compositing | Tile 2-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.42 | Compositing | Tile 3-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.42 | Compositing | Tile 4-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.42 | Compositing | Tile 1-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.42 | Compositing | Tile 2-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.42 | Compositing | Tile 3-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.42 | Compositing | Tile 4-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.42 | Compositing | Tile 1-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.42 | Compositing | Tile 2-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.42 | Compositing | Tile 3-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.42 | Compositing | Tile 4-4
# Fra:29 Mem:296.52M (Peak 301.35M) | Time:00:00.42 | Compositing | De-initializing execution
# Saved: Image0029.png
# Saved: Image0029.png
# Saved: /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0035_image_albedo0029.exr
# Saved: '/home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0035_image_envmap_for_blender.exr'
#  Time: 00:00.44 (Saving: 00:00.00)
#
# Writing: im_0042_image_envmap_for_blender
# Fra:29 Mem:273.52M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Initializing
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Waiting for render to start
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Scene
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Shaders
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Background
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Camera
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Objects
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Particle Systems
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Meshes
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Objects Flags
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Primitive Offsets
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Images
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Camera Volume
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Lookup Tables
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Lights
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Integrator
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Film
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Lookup Tables
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Baking
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Device | Writing constant memory
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Sample 0/128
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Remaining:00:00.54 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Sample 1/128
# Fra:29 Mem:285.44M (Peak 301.35M) | Time:00:00.46 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Sample 128/128
# Fra:29 Mem:285.44M (Peak 301.35M) | Time:00:00.46 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Finished
# Fra:29 Mem:285.52M (Peak 301.35M) | Time:00:00.46 | Compositing
# Fra:29 Mem:285.52M (Peak 301.35M) | Time:00:00.46 | Compositing | Determining resolution
# Fra:29 Mem:285.52M (Peak 301.35M) | Time:00:00.46 | Compositing | Initializing execution
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.46 | Compositing | Tile 1-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.46 | Compositing | Tile 2-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.46 | Compositing | Tile 3-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.46 | Compositing | Tile 4-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.46 | Compositing | Tile 1-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.46 | Compositing | Tile 2-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.46 | Compositing | Tile 3-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.46 | Compositing | Tile 4-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.47 | Compositing | Tile 1-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.47 | Compositing | Tile 2-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.47 | Compositing | Tile 3-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.47 | Compositing | Tile 4-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.47 | Compositing | Tile 1-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.47 | Compositing | Tile 3-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.47 | Compositing | Tile 4-4
# Fra:29 Mem:296.59M (Peak 301.35M) | Time:00:00.47 | Compositing | Tile 2-4
# Fra:29 Mem:296.52M (Peak 301.35M) | Time:00:00.47 | Compositing | De-initializing execution
# Saved: Image0029.png
# Saved: Image0029.png
# Saved: /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0042_image_albedo0029.exr
# Saved: '/home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0042_image_envmap_for_blender.exr'
#  Time: 00:00.48 (Saving: 00:00.00)
#
# Writing: im_0049_image_envmap_for_blender
# Fra:29 Mem:273.52M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Initializing
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Waiting for render to start
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Scene
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Shaders
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Background
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Camera
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Objects
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Particle Systems
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Meshes
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Objects Flags
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Primitive Offsets
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Images
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Camera Volume
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Lookup Tables
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Lights
# Fra:29 Mem:273.51M (Peak 273.52M) | Time:00:00.00 | Mem:184.43M, Peak:184.43M | Scene, View Layer | Updating Integrator
# ...
# Fra:29 Mem:124.44M (Peak 140.43M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Objects | Copying Transformations to device
# Fra:29 Mem:124.44M (Peak 140.43M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Objects | Applying Static Transformations
# Fra:29 Mem:124.44M (Peak 140.43M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Particle Systems
# Fra:29 Mem:124.44M (Peak 140.43M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Particle Systems | Copying Particles to device
# Fra:29 Mem:124.44M (Peak 140.43M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Meshes
# Fra:29 Mem:132.55M (Peak 140.43M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Mesh | Computing attributes
# Fra:29 Mem:147.75M (Peak 147.75M) | Time:00:00.04 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Mesh | Copying Attributes to device
# Fra:29 Mem:147.75M (Peak 147.75M) | Time:00:00.04 | Mem:23.20M, Peak:23.20M | Scene, View Layer | Updating Scene BVH | Building
# Fra:29 Mem:147.75M (Peak 147.75M) | Time:00:00.04 | Mem:23.20M, Peak:23.20M | Scene, View Layer | Updating Scene BVH | Building BVH
# Fra:29 Mem:147.75M (Peak 147.75M) | Time:00:00.04 | Mem:39.42M, Peak:39.42M | Scene, View Layer | Updating Scene BVH | Building BVH 0%
# Fra:29 Mem:147.75M (Peak 147.75M) | Time:00:00.05 | Mem:58.74M, Peak:74.96M | Scene, View Layer | Updating Scene BVH | Copying BVH to device
# Fra:29 Mem:147.75M (Peak 147.75M) | Time:00:00.05 | Mem:58.74M, Peak:74.96M | Scene, View Layer | Updating Mesh | Computing normals
# Fra:29 Mem:165.99M (Peak 165.99M) | Time:00:00.05 | Mem:58.74M, Peak:74.96M | Scene, View Layer | Updating Mesh | Copying Mesh to device
# Fra:29 Mem:165.99M (Peak 165.99M) | Time:00:00.05 | Mem:76.98M, Peak:76.98M | Scene, View Layer | Updating Objects Flags
# Fra:29 Mem:165.99M (Peak 165.99M) | Time:00:00.05 | Mem:76.98M, Peak:76.98M | Scene, View Layer | Updating Primitive Offsets
# Fra:29 Mem:165.99M (Peak 165.99M) | Time:00:00.05 | Mem:76.98M, Peak:76.98M | Scene, View Layer | Updating Images
# Fra:29 Mem:157.99M (Peak 165.99M) | Time:00:00.05 | Mem:68.98M, Peak:76.98M | Scene, View Layer | Updating Images | Loading roughness.exr
# Fra:29 Mem:173.99M (Peak 173.99M) | Time:00:00.05 | Mem:68.98M, Peak:76.98M | Scene, View Layer | Updating Images | Loading diffuse.exr
# Fra:29 Mem:189.99M (Peak 189.99M) | Time:00:00.05 | Mem:68.98M, Peak:76.98M | Scene, View Layer | Updating Images | Loading teapot_scene006_0070_for_teapot_scene001.exr
# Fra:29 Mem:197.99M (Peak 197.99M) | Time:00:00.06 | Mem:108.98M, Peak:108.98M | Scene, View Layer | Updating Camera Volume
# Fra:29 Mem:197.99M (Peak 197.99M) | Time:00:00.06 | Mem:108.98M, Peak:108.98M | Scene, View Layer | Updating Lookup Tables
# Fra:29 Mem:197.99M (Peak 197.99M) | Time:00:00.06 | Mem:108.98M, Peak:108.98M | Scene, View Layer | Updating Lights
# Fra:29 Mem:197.99M (Peak 197.99M) | Time:00:00.06 | Mem:108.99M, Peak:108.99M | Scene, View Layer | Updating Lights | Importance map
# Fra:29 Mem:262.02M (Peak 549.99M) | Time:00:00.17 | Mem:173.03M, Peak:333.00M | Scene, View Layer | Updating Lights | Computing distribution
# Fra:29 Mem:262.02M (Peak 549.99M) | Time:00:00.17 | Mem:173.03M, Peak:333.00M | Scene, View Layer | Updating Integrator
# Fra:29 Mem:263.02M (Peak 549.99M) | Time:00:00.17 | Mem:174.03M, Peak:333.00M | Scene, View Layer | Updating Film
# Fra:29 Mem:263.02M (Peak 549.99M) | Time:00:00.17 | Mem:174.03M, Peak:333.00M | Scene, View Layer | Updating Lookup Tables
# Fra:29 Mem:263.02M (Peak 549.99M) | Time:00:00.17 | Mem:174.03M, Peak:333.00M | Scene, View Layer | Updating Baking
# Fra:29 Mem:263.02M (Peak 549.99M) | Time:00:00.17 | Mem:174.03M, Peak:333.00M | Scene, View Layer | Updating Device | Writing constant memory
# Fra:29 Mem:263.02M (Peak 549.99M) | Time:00:00.17 | Mem:174.03M, Peak:333.00M | Scene, View Layer | Sample 0/128
# Fra:29 Mem:281.01M (Peak 549.99M) | Time:00:00.17 | Remaining:00:00.87 | Mem:191.93M, Peak:333.00M | Scene, View Layer | Sample 1/128
# Fra:29 Mem:292.94M (Peak 549.99M) | Time:00:00.66 | Mem:191.93M, Peak:333.00M | Scene, View Layer | Sample 128/128
# Fra:29 Mem:292.94M (Peak 549.99M) | Time:00:00.66 | Mem:191.93M, Peak:333.00M | Scene, View Layer | Finished
# Fra:29 Mem:293.02M (Peak 549.99M) | Time:00:00.66 | Compositing
# Fra:29 Mem:293.02M (Peak 549.99M) | Time:00:00.67 | Compositing | Determining resolution
# Fra:29 Mem:293.02M (Peak 549.99M) | Time:00:00.67 | Compositing | Initializing execution
# Fra:29 Mem:304.09M (Peak 549.99M) | Time:00:00.67 | Compositing | Tile 1-4
# Fra:29 Mem:304.09M (Peak 549.99M) | Time:00:00.67 | Compositing | Tile 2-4
# Fra:29 Mem:304.09M (Peak 549.99M) | Time:00:00.67 | Compositing | Tile 3-4
# Fra:29 Mem:304.09M (Peak 549.99M) | Time:00:00.67 | Compositing | Tile 4-4
# Fra:29 Mem:304.09M (Peak 549.99M) | Time:00:00.67 | Compositing | Tile 1-4
# Fra:29 Mem:304.09M (Peak 549.99M) | Time:00:00.67 | Compositing | Tile 2-4
# Fra:29 Mem:304.09M (Peak 549.99M) | Time:00:00.67 | Compositing | Tile 3-4
# Fra:29 Mem:304.09M (Peak 549.99M) | Time:00:00.67 | Compositing | Tile 4-4
# Fra:29 Mem:304.09M (Peak 549.99M) | Time:00:00.67 | Compositing | Tile 1-4
# Fra:29 Mem:304.09M (Peak 549.99M) | Time:00:00.67 | Compositing | Tile 2-4
# Fra:29 Mem:304.09M (Peak 549.99M) | Time:00:00.67 | Compositing | Tile 3-4
# Fra:29 Mem:304.09M (Peak 549.99M) | Time:00:00.67 | Compositing | Tile 4-4
# Fra:29 Mem:304.09M (Peak 549.99M) | Time:00:00.67 | Compositing | Tile 1-4
# Fra:29 Mem:304.09M (Peak 549.99M) | Time:00:00.67 | Compositing | Tile 2-4
# Fra:29 Mem:304.09M (Peak 549.99M) | Time:00:00.67 | Compositing | Tile 3-4
# Fra:29 Mem:304.09M (Peak 549.99M) | Time:00:00.67 | Compositing | Tile 4-4
# Fra:29 Mem:304.02M (Peak 549.99M) | Time:00:00.67 | Compositing | De-initializing execution
# Saved: Image0029.png
# Saved: Image0029.png
# Saved: /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0070_albedo0029.exr
# Saved: '/home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0070_teapot_scene006_0070_for_teapot_scene001.exr'
#  Time: 00:00.70 (Saving: 00:00.00)
#
#
# Blender quit
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/render_geo/0000_image.zbuf.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/render_geo/0007_image.zbuf.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/render_geo/0014_image.zbuf.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/render_geo/0021_image.zbuf.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/render_geo/0028_image.zbuf.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/render_geo/0035_image.zbuf.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/render_geo/0042_image.zbuf.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/render_geo/0049_image.zbuf.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/render_geo/0056_image.zbuf.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/render_geo/0063_image.zbuf.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0000_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0007_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0014_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0021_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0028_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0035_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0042_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0049_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0056_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0063_image_envmap_for_blender.exr
# teapot_scene001     : nv=10/10 nl=20/20 mat=10/10 geo=10/10 w/ mesh
# Save to results___NPBIR____GT_g__EST_l/stanford_orb/eval_inputs_pbir.json
# INFO:__main__:Processing 1 scenes...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0000_image_envmap_for_blender.exr
# /home/ahc/miniconda3/envs/metrology_ir/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/ahc/miniconda3/envs/metrology_ir/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# /home/ahc/miniconda3/envs/metrology_ir/lib/python3.11/site-packages/lpips/lpips.py:107: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.load_state_dict(torch.load(model_path, map_location='cpu'), strict=False)
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0007_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0014_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0021_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0028_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0035_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0042_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0049_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0056_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0063_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0060_teapot_scene002_0060_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0061_teapot_scene002_0061_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0062_teapot_scene002_0062_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0063_teapot_scene002_0063_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0064_teapot_scene002_0064_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0065_teapot_scene002_0065_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0066_teapot_scene002_0066_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0067_teapot_scene002_0067_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0068_teapot_scene002_0068_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0069_teapot_scene002_0069_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0061_teapot_scene006_0061_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0062_teapot_scene006_0062_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0063_teapot_scene006_0063_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0064_teapot_scene006_0064_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0065_teapot_scene006_0065_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0066_teapot_scene006_0066_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0067_teapot_scene006_0067_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0068_teapot_scene006_0068_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0069_teapot_scene006_0069_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0070_teapot_scene006_0070_for_teapot_scene001.exr
# 100%|█████████████████████████████████████████████| 1/1 [00:09<00:00,  9.21s/it]
# INFO:__main__:Results saved to .././results___NPBIR____GT_g__EST_l/stanford_orb/eval_outputs_pbir.json
