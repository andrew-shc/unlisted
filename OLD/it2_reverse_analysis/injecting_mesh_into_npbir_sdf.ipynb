# %%
# analyze mesh alignment first
M1="/home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/neural_surface_recon/mesh_mc_raw.obj"
M2="/home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/neural_surface_recon/mesh.obj"
M3="/home/ahc/Datasets/Stanford-ORB/ground_truth/teapot_scene001/mesh_blender/mesh.obj" 
# !python compare_mesh_alignment.py {M1} {M2} {M3} --output aligned_comparison.ply
# Out:
# Loading Red mesh from: /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/neural_surface_recon/mesh_mc_raw.obj
#
# Per mesh stats [/home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/neural_surface_recon/mesh_mc_raw.obj]:
#   Total vertices: 69692
#   Total faces: 139384
#   Bounds: [[-0.26949281 -0.2144658  -0.18546875]
#  [ 0.37341145  0.235079    0.31306087]]
# Loading Green mesh from: /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/neural_surface_recon/mesh.obj
#
# Per mesh stats [/home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/neural_surface_recon/mesh.obj]:
#   Total vertices: 279142
#   Total faces: 530508
#   Bounds: [[-0.2691   -0.214431 -0.185451]
#  [ 0.373328  0.23496   0.31298 ]]
# Loading Blue mesh from: /home/ahc/Datasets/Stanford-ORB/ground_truth/teapot_scene001/mesh_blender/mesh.obj
#
# ...

# %%
# analyze mesh alignment first
M1="/home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/neural_surface_recon/mesh_mc_raw.obj"
M2="/home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/neural_surface_recon/mesh.obj"
M3="/home/ahc/Datasets/Stanford-ORB/ground_truth/teapot_scene001/mesh_blender/mesh.obj" 
# !python compare_mesh_alignment.py {M1} {M2} {M3} --output aligned_comparison_v1_v1.ply
# Out:
# Loading Red mesh from: /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/neural_surface_recon/mesh_mc_raw.obj
#
# Per mesh stats [/home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/neural_surface_recon/mesh_mc_raw.obj]:
#   Total vertices: 69778
#   Total faces: 139556
#   Bounds: [[-0.26942228 -0.21452182 -0.18606455]
#  [ 0.37362128  0.23496865  0.31337031]]
# Loading Green mesh from: /home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/neural_surface_recon/mesh.obj
#
# Per mesh stats [/home/ahc/Documents/metrology_ir/results___NPBIR____GT_g__EST_l/stanford_orb/teapot_scene001/neural_surface_recon/mesh.obj]:
#   Total vertices: 281038
#   Total faces: 531290
#   Bounds: [[-0.269143 -0.214427 -0.185962]
#  [ 0.373511  0.234882  0.313146]]
# Loading Blue mesh from: /home/ahc/Datasets/Stanford-ORB/ground_truth/teapot_scene001/mesh_blender/mesh.obj
#
# ...
