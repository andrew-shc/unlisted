# %%
ALL_METHODS = [
    "results___NPBIR___EST_g__EST_l",  # OG
    "results___NPBIR____GT_g__EST_l",
    "results___NPBIR___EST_g___GT_l",
    "results___NPBIR__VGGT_g__EST_l",
    "results___NPBIR__VGGT_g___GT_l",
    # "results_MITSUBA__VGGT_g__EST_l",
    # "results_MITSUBA____GT_g__EST_l",
    # "results_MITSUBA__VGGT_g___GT_l",
]

METHOD=ALL_METHODS[0]
NPBIR="./DigitalTwinCatalog/neural_pbir"
CHKPT=f"./{METHOD}/stanford_orb"
SORB = "/home/ahc/Datasets/Stanford-ORB"
SORB_HDR = f"{SORB}/blender_HDR"
SORB_GT = f"{SORB}/ground_truth"
SCENE = "teapot_scene001" # "baking_scene001"

# %%
# run once per new scene within the dataset itself (regardless of method, etc.)
# !python DigitalTwinCatalog/neural_pbir/scripts/preprocess/stanford_orb.py /home/ahc/Datasets/Stanford-ORB/blender_HDR/{SCENE}
# run once per Stanford-ORB (i.e., once overall for each time you download Stanford-ORB separately)
# !python {NPBIR}/scripts/stanford_orb/postproc_envmap_gt.py --gt_dir {SORB_GT} --im_dir {SORB_HDR}

# !python {NPBIR}/neural_surface_recon/run_template.py --template {NPBIR}/neural_surface_recon/configs/template_stanford_orb.py --savemem {SORB_HDR}/{SCENE}/
# !mv results {METHOD}
# !python {NPBIR}/neural_distillation/run.py {CHKPT}/{SCENE}/
# !python {NPBIR}/pbir/run.py {NPBIR}/pbir/configs/template {CHKPT}/{SCENE}/
# !python {NPBIR}/scripts/stanford_orb/render_geo.py {SORB_HDR}/{SCENE}/cameras.json {CHKPT}/{SCENE}/pbir/mesh.obj

# !python {NPBIR}/scripts/stanford_orb/postproc_envmap_our.py "{CHKPT}/{SCENE}/pbir/envmap.exr"

# NOVEL VIEW SYNTHESIS
CAM=f"{SORB_HDR}/{SCENE}/cameras.json"
CKPT_GEO=f"{CHKPT}/{SCENE}/pbir/mesh.obj"
CKPT_ALBEDO=f"{CHKPT}/{SCENE}/pbir/diffuse.exr"
CKPT_ROUGH=f"{CHKPT}/{SCENE}/pbir/roughness.exr"
CKPT_ENV=f"{CHKPT}/{SCENE}/pbir/envmap_for_blender.exr"
# !python {NPBIR}/scripts/relit/relit.py {CKPT_GEO} {CKPT_ALBEDO} {CKPT_ROUGH} {CAM} --lgt_paths {CKPT_ENV} --render_exr --with_bg

# RELIGHTING
# !python {NPBIR}/scripts/stanford_orb/relit_nl.py --ckptroot {CHKPT} --dataroot {SORB}


# !python {NPBIR}/scripts/stanford_orb/eval_preprocess.py --data_dir {SORB}/  --ckpt_dir {CHKPT}/
# !cd Stanford-ORB && PYTHONPATH=. python scripts/test.py --input-path ../{CHKPT}/eval_inputs_pbir.json --output-path ../{CHKPT}/eval_outputs_pbir.json --scenes example
# Out:
# Skipping baking_scene001 despite having cameras_novel.json in the Stanford-ORB dataset.
# Skipping baking_scene001 despite having cameras_novel.json in the Stanford-ORB dataset.
# Skipping baking_scene001 despite having cameras_novel.json in the Stanford-ORB dataset.
# Skipping baking_scene001 despite having cameras_novel.json in the Stanford-ORB dataset.
# Skipping baking_scene001 despite having cameras_novel.json in the Stanford-ORB dataset.
# Skipping baking_scene001 despite having cameras_novel.json in the Stanford-ORB dataset.
# Skipping baking_scene001 despite having cameras_novel.json in the Stanford-ORB dataset.
# Skipping baking_scene001 despite having cameras_novel.json in the Stanford-ORB dataset.
# Skipping baking_scene001 despite having cameras_novel.json in the Stanford-ORB dataset.
# Skipping baking_scene001 despite having cameras_novel.json in the Stanford-ORB dataset.
# Skipping baking_scene001 despite having cameras_novel.json in the Stanford-ORB dataset.
# Skipping baking_scene001 despite having cameras_novel.json in the Stanford-ORB dataset.
# Skipping baking_scene001 despite having cameras_novel.json in the Stanford-ORB dataset.
# Skipping baking_scene001 despite having cameras_novel.json in the Stanford-ORB dataset.
# Skipping baking_scene001 despite having cameras_novel.json in the Stanford-ORB dataset.
# Skipping baking_scene001 despite having cameras_novel.json in the Stanford-ORB dataset.
# Skipping baking_scene001 despite having cameras_novel.json in the Stanford-ORB dataset.
# Skipping baking_scene001 despite having cameras_novel.json in the Stanford-ORB dataset.
# Skipping baking_scene001 despite having cameras_novel.json in the Stanford-ORB dataset.
# Skipping baking_scene001 despite having cameras_novel.json in the Stanford-ORB dataset.
# Blender 3.6.21 (hash e7f18247b228 built 2025-02-18 08:11:48)
# Failed to open dir (No such file or directory): /run/user/1000/gvfs/
# Read blend: "/home/ahc/Documents/metrology_ir/DigitalTwinCatalog/neural_pbir/scripts/relit/relit.blend"
# Results are dumped to /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit
# Set fov: 20.298470147178936 deg
# Loading mesh: /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/mesh.obj
# (  0.0000 sec |   0.0000 sec) Importing OBJ '/home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/mesh.obj'...
#   (  0.0000 sec |   0.0000 sec) Parsing OBJ file...
#     (  2.3848 sec |   2.3847 sec) Done, loading materials and images...
#     (  2.3873 sec |   2.3872 sec) Done, building geometries (verts:265254 faces:530508 materials: 1 smoothgroups:0) ...
#     (  3.2843 sec |   3.2843 sec) Done.
#   (  3.2844 sec |   3.2844 sec) Finished importing: '/home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/mesh.obj'
# Progress: 100.00%
#
# Set albedo: /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/diffuse.exr
# Set roughenss: /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/roughness.exr
# /home/ahc/Documents/metrology_ir/DigitalTwinCatalog/neural_pbir/scripts/relit/blender_script.py:144: DeprecationWarning: Passing in context overrides is deprecated in favor of Context.temp_override(..), calling "object.delete"
#   bpy.ops.object.delete({"selected_objects": objs})
# Set environment map: /home/ahc/Datasets/Stanford-ORB/ground_truth/teapot_scene002/env_map_for_blender/teapot_scene002_0060_for_teapot_scene001.exr
# Writing: im_0060_teapot_scene002_0060_for_teapot_scene001
# Fra:29 Mem:72.26M (Peak 72.27M) | Time:00:00.00 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Synchronizing object | mesh
# Fra:29 Mem:116.27M (Peak 128.41M) | Time:00:00.02 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Initializing
# Fra:29 Mem:116.27M (Peak 128.41M) | Time:00:00.02 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Updating Images | Loading sunrise.exr
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Waiting for render to start
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Loading render kernels (may take a few minutes the first time)
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Scene
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Shaders
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Procedurals
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Background
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Camera
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Meshes Flags
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Objects
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Objects | Copying Transformations to device
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Objects | Applying Static Transformations
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Particle Systems
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Particle Systems | Copying Particles to device
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Meshes
# Fra:29 Mem:132.38M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Mesh | Computing attributes
# Fra:29 Mem:147.56M (Peak 147.56M) | Time:00:00.04 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Mesh | Copying Attributes to device
# Fra:29 Mem:147.56M (Peak 147.56M) | Time:00:00.04 | Mem:23.18M, Peak:23.18M | Scene, View Layer | Updating Scene BVH | Building
# Fra:29 Mem:147.56M (Peak 147.56M) | Time:00:00.04 | Mem:23.18M, Peak:23.18M | Scene, View Layer | Updating Scene BVH | Building BVH
# Fra:29 Mem:147.56M (Peak 147.56M) | Time:00:00.04 | Mem:39.37M, Peak:39.37M | Scene, View Layer | Updating Scene BVH | Building BVH 0%
# Fra:29 Mem:147.56M (Peak 147.56M) | Time:00:00.05 | Mem:58.67M, Peak:74.86M | Scene, View Layer | Updating Scene BVH | Copying BVH to device
# Fra:29 Mem:147.56M (Peak 147.56M) | Time:00:00.05 | Mem:58.67M, Peak:74.86M | Scene, View Layer | Updating Mesh | Computing normals
# Fra:29 Mem:165.77M (Peak 165.77M) | Time:00:00.05 | Mem:58.67M, Peak:74.86M | Scene, View Layer | Updating Mesh | Copying Mesh to device
# Fra:29 Mem:165.77M (Peak 165.77M) | Time:00:00.05 | Mem:76.88M, Peak:76.88M | Scene, View Layer | Updating Objects Flags
# Fra:29 Mem:165.77M (Peak 165.77M) | Time:00:00.05 | Mem:76.88M, Peak:76.88M | Scene, View Layer | Updating Primitive Offsets
# Fra:29 Mem:165.77M (Peak 165.77M) | Time:00:00.05 | Mem:76.88M, Peak:76.88M | Scene, View Layer | Updating Images
# Fra:29 Mem:157.77M (Peak 165.77M) | Time:00:00.05 | Mem:68.88M, Peak:76.88M | Scene, View Layer | Updating Images | Loading roughness.exr
# Fra:29 Mem:173.77M (Peak 173.77M) | Time:00:00.05 | Mem:68.88M, Peak:76.88M | Scene, View Layer | Updating Images | Loading diffuse.exr
# Fra:29 Mem:189.77M (Peak 189.77M) | Time:00:00.05 | Mem:68.88M, Peak:76.88M | Scene, View Layer | Updating Images | Loading teapot_scene002_0060_for_teapot_scene001.exr
# Fra:29 Mem:197.77M (Peak 197.77M) | Time:00:00.06 | Mem:108.88M, Peak:108.88M | Scene, View Layer | Updating Camera Volume
# Fra:29 Mem:197.77M (Peak 197.77M) | Time:00:00.06 | Mem:108.88M, Peak:108.88M | Scene, View Layer | Updating Lookup Tables
# Fra:29 Mem:197.77M (Peak 197.77M) | Time:00:00.06 | Mem:108.88M, Peak:108.88M | Scene, View Layer | Updating Lights
# Fra:29 Mem:197.77M (Peak 197.77M) | Time:00:00.06 | Mem:108.88M, Peak:108.88M | Scene, View Layer | Updating Lights | Importance map
# Fra:29 Mem:261.80M (Peak 549.77M) | Time:00:00.16 | Mem:172.92M, Peak:332.89M | Scene, View Layer | Updating Lights | Computing distribution
# Fra:29 Mem:261.80M (Peak 549.77M) | Time:00:00.16 | Mem:172.93M, Peak:332.89M | Scene, View Layer | Updating Integrator
# Fra:29 Mem:262.80M (Peak 549.77M) | Time:00:00.16 | Mem:173.93M, Peak:332.89M | Scene, View Layer | Updating Film
# Fra:29 Mem:262.81M (Peak 549.77M) | Time:00:00.16 | Mem:173.93M, Peak:332.89M | Scene, View Layer | Updating Lookup Tables
# Fra:29 Mem:262.81M (Peak 549.77M) | Time:00:00.16 | Mem:173.93M, Peak:332.89M | Scene, View Layer | Updating Baking
# Fra:29 Mem:262.81M (Peak 549.77M) | Time:00:00.16 | Mem:173.93M, Peak:332.89M | Scene, View Layer | Updating Device | Writing constant memory
# Fra:29 Mem:262.81M (Peak 549.77M) | Time:00:00.16 | Mem:173.93M, Peak:332.89M | Scene, View Layer | Sample 0/128
# Fra:29 Mem:280.80M (Peak 549.77M) | Time:00:00.17 | Remaining:00:00.74 | Mem:191.82M, Peak:332.89M | Scene, View Layer | Sample 1/128
# Fra:29 Mem:292.73M (Peak 549.77M) | Time:00:00.57 | Mem:191.82M, Peak:332.89M | Scene, View Layer | Sample 128/128
# Fra:29 Mem:292.73M (Peak 549.77M) | Time:00:00.57 | Mem:191.82M, Peak:332.89M | Scene, View Layer | Finished
# Fra:29 Mem:292.80M (Peak 549.77M) | Time:00:00.57 | Compositing
# Fra:29 Mem:292.81M (Peak 549.77M) | Time:00:00.57 | Compositing | Determining resolution
# Fra:29 Mem:292.81M (Peak 549.77M) | Time:00:00.57 | Compositing | Initializing execution
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.58 | Compositing | Tile 1-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.58 | Compositing | Tile 2-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.58 | Compositing | Tile 3-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.58 | Compositing | Tile 4-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.58 | Compositing | Tile 1-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.58 | Compositing | Tile 4-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.58 | Compositing | Tile 2-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.58 | Compositing | Tile 3-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.58 | Compositing | Tile 2-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.58 | Compositing | Tile 1-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.58 | Compositing | Tile 3-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.58 | Compositing | Tile 4-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.58 | Compositing | Tile 1-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.58 | Compositing | Tile 2-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.58 | Compositing | Tile 3-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.58 | Compositing | Tile 4-4
# Fra:29 Mem:303.81M (Peak 549.77M) | Time:00:00.58 | Compositing | De-initializing execution
# Saved: Image0029.png
# Saved: Image0029.png
# Saved: /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0060_albedo0029.exr
# Saved: '/home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0060_teapot_scene002_0060_for_teapot_scene001.exr'
#  Time: 00:00.61 (Saving: 00:00.00)
#
#
# Blender quit
# Blender 3.6.21 (hash e7f18247b228 built 2025-02-18 08:11:48)
# Failed to open dir (No such file or directory): /run/user/1000/gvfs/
# Read blend: "/home/ahc/Documents/metrology_ir/DigitalTwinCatalog/neural_pbir/scripts/relit/relit.blend"
# Results are dumped to /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit
# Set fov: 20.298470147178936 deg
# Loading mesh: /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/mesh.obj
# (  0.0000 sec |   0.0000 sec) Importing OBJ '/home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/mesh.obj'...
#   (  0.0000 sec |   0.0000 sec) Parsing OBJ file...
#     (  2.3858 sec |   2.3857 sec) Done, loading materials and images...
#     (  2.3883 sec |   2.3883 sec) Done, building geometries (verts:265254 faces:530508 materials: 1 smoothgroups:0) ...
#     (  3.2941 sec |   3.2941 sec) Done.
#   (  3.2942 sec |   3.2942 sec) Finished importing: '/home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/mesh.obj'
# Progress: 100.00%
#
# Set albedo: /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/diffuse.exr
# Set roughenss: /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/roughness.exr
# /home/ahc/Documents/metrology_ir/DigitalTwinCatalog/neural_pbir/scripts/relit/blender_script.py:144: DeprecationWarning: Passing in context overrides is deprecated in favor of Context.temp_override(..), calling "object.delete"
#   bpy.ops.object.delete({"selected_objects": objs})
# Set environment map: /home/ahc/Datasets/Stanford-ORB/ground_truth/teapot_scene002/env_map_for_blender/teapot_scene002_0061_for_teapot_scene001.exr
# Writing: im_0061_teapot_scene002_0061_for_teapot_scene001
# Fra:29 Mem:72.26M (Peak 72.27M) | Time:00:00.00 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Synchronizing object | mesh
# Fra:29 Mem:116.27M (Peak 128.41M) | Time:00:00.02 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Initializing
# Fra:29 Mem:116.27M (Peak 128.41M) | Time:00:00.02 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Updating Images | Loading sunrise.exr
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Waiting for render to start
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Loading render kernels (may take a few minutes the first time)
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Scene
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Shaders
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Procedurals
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Background
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Camera
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Meshes Flags
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Objects
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Objects | Copying Transformations to device
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Objects | Applying Static Transformations
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Particle Systems
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Particle Systems | Copying Particles to device
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Meshes
# Fra:29 Mem:132.38M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Mesh | Computing attributes
# Fra:29 Mem:147.56M (Peak 147.56M) | Time:00:00.04 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Mesh | Copying Attributes to device
# Fra:29 Mem:147.56M (Peak 147.56M) | Time:00:00.04 | Mem:23.18M, Peak:23.18M | Scene, View Layer | Updating Scene BVH | Building
# Fra:29 Mem:147.56M (Peak 147.56M) | Time:00:00.04 | Mem:23.18M, Peak:23.18M | Scene, View Layer | Updating Scene BVH | Building BVH
# Fra:29 Mem:147.56M (Peak 147.56M) | Time:00:00.04 | Mem:39.37M, Peak:39.37M | Scene, View Layer | Updating Scene BVH | Building BVH 0%
# Fra:29 Mem:147.56M (Peak 147.56M) | Time:00:00.05 | Mem:58.67M, Peak:74.86M | Scene, View Layer | Updating Scene BVH | Copying BVH to device
# Fra:29 Mem:147.56M (Peak 147.56M) | Time:00:00.05 | Mem:58.67M, Peak:74.86M | Scene, View Layer | Updating Mesh | Computing normals
# Fra:29 Mem:165.77M (Peak 165.77M) | Time:00:00.05 | Mem:58.67M, Peak:74.86M | Scene, View Layer | Updating Mesh | Copying Mesh to device
# Fra:29 Mem:165.77M (Peak 165.77M) | Time:00:00.05 | Mem:76.88M, Peak:76.88M | Scene, View Layer | Updating Objects Flags
# Fra:29 Mem:165.77M (Peak 165.77M) | Time:00:00.05 | Mem:76.88M, Peak:76.88M | Scene, View Layer | Updating Primitive Offsets
# Fra:29 Mem:165.77M (Peak 165.77M) | Time:00:00.05 | Mem:76.88M, Peak:76.88M | Scene, View Layer | Updating Images
# Fra:29 Mem:157.77M (Peak 165.77M) | Time:00:00.05 | Mem:68.88M, Peak:76.88M | Scene, View Layer | Updating Images | Loading roughness.exr
# Fra:29 Mem:173.77M (Peak 173.77M) | Time:00:00.05 | Mem:68.88M, Peak:76.88M | Scene, View Layer | Updating Images | Loading diffuse.exr
# Fra:29 Mem:189.77M (Peak 189.77M) | Time:00:00.05 | Mem:68.88M, Peak:76.88M | Scene, View Layer | Updating Images | Loading teapot_scene002_0061_for_teapot_scene001.exr
# Fra:29 Mem:197.77M (Peak 197.77M) | Time:00:00.06 | Mem:108.88M, Peak:108.88M | Scene, View Layer | Updating Camera Volume
# Fra:29 Mem:197.77M (Peak 197.77M) | Time:00:00.06 | Mem:108.88M, Peak:108.88M | Scene, View Layer | Updating Lookup Tables
# Fra:29 Mem:197.77M (Peak 197.77M) | Time:00:00.06 | Mem:108.88M, Peak:108.88M | Scene, View Layer | Updating Lights
# Fra:29 Mem:197.77M (Peak 197.77M) | Time:00:00.06 | Mem:108.88M, Peak:108.88M | Scene, View Layer | Updating Lights | Importance map
# Fra:29 Mem:261.80M (Peak 549.77M) | Time:00:00.17 | Mem:172.92M, Peak:332.89M | Scene, View Layer | Updating Lights | Computing distribution
# Fra:29 Mem:261.80M (Peak 549.77M) | Time:00:00.17 | Mem:172.93M, Peak:332.89M | Scene, View Layer | Updating Integrator
# Fra:29 Mem:262.80M (Peak 549.77M) | Time:00:00.17 | Mem:173.93M, Peak:332.89M | Scene, View Layer | Updating Film
# Fra:29 Mem:262.81M (Peak 549.77M) | Time:00:00.17 | Mem:173.93M, Peak:332.89M | Scene, View Layer | Updating Lookup Tables
# Fra:29 Mem:262.81M (Peak 549.77M) | Time:00:00.17 | Mem:173.93M, Peak:332.89M | Scene, View Layer | Updating Baking
# Fra:29 Mem:262.81M (Peak 549.77M) | Time:00:00.17 | Mem:173.93M, Peak:332.89M | Scene, View Layer | Updating Device | Writing constant memory
# Fra:29 Mem:262.81M (Peak 549.77M) | Time:00:00.17 | Mem:173.93M, Peak:332.89M | Scene, View Layer | Sample 0/128
# Fra:29 Mem:280.80M (Peak 549.77M) | Time:00:00.17 | Remaining:00:00.73 | Mem:191.82M, Peak:332.89M | Scene, View Layer | Sample 1/128
# Fra:29 Mem:292.73M (Peak 549.77M) | Time:00:00.57 | Mem:191.82M, Peak:332.89M | Scene, View Layer | Sample 128/128
# Fra:29 Mem:292.73M (Peak 549.77M) | Time:00:00.57 | Mem:191.82M, Peak:332.89M | Scene, View Layer | Finished
# Fra:29 Mem:292.80M (Peak 549.77M) | Time:00:00.57 | Compositing
# Fra:29 Mem:292.81M (Peak 549.77M) | Time:00:00.57 | Compositing | Determining resolution
# Fra:29 Mem:292.81M (Peak 549.77M) | Time:00:00.57 | Compositing | Initializing execution
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.58 | Compositing | Tile 2-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.58 | Compositing | Tile 1-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.58 | Compositing | Tile 4-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.58 | Compositing | Tile 4-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.58 | Compositing | Tile 1-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.58 | Compositing | Tile 2-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.58 | Compositing | Tile 3-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.58 | Compositing | Tile 4-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.58 | Compositing | Tile 1-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.58 | Compositing | Tile 2-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.58 | Compositing | Tile 3-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.58 | Compositing | Tile 4-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.58 | Compositing | Tile 1-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.58 | Compositing | Tile 2-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.58 | Compositing | Tile 3-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.58 | Compositing | Tile 4-4
# Fra:29 Mem:303.81M (Peak 549.77M) | Time:00:00.58 | Compositing | De-initializing execution
# Saved: Image0029.png
# Saved: Image0029.png
# Saved: /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0061_albedo0029.exr
# Saved: '/home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0061_teapot_scene002_0061_for_teapot_scene001.exr'
#  Time: 00:00.61 (Saving: 00:00.00)
#
#
# Blender quit
# Blender 3.6.21 (hash e7f18247b228 built 2025-02-18 08:11:48)
# Failed to open dir (No such file or directory): /run/user/1000/gvfs/
# Read blend: "/home/ahc/Documents/metrology_ir/DigitalTwinCatalog/neural_pbir/scripts/relit/relit.blend"
# Results are dumped to /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit
# Set fov: 20.298470147178936 deg
# Loading mesh: /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/mesh.obj
# (  0.0000 sec |   0.0000 sec) Importing OBJ '/home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/mesh.obj'...
#   (  0.0000 sec |   0.0000 sec) Parsing OBJ file...
#     (  2.4174 sec |   2.4173 sec) Done, loading materials and images...
#     (  2.4199 sec |   2.4199 sec) Done, building geometries (verts:265254 faces:530508 materials: 1 smoothgroups:0) ...
#     (  3.3183 sec |   3.3182 sec) Done.
#   (  3.3183 sec |   3.3183 sec) Finished importing: '/home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/mesh.obj'
# Progress: 100.00%
#
# Set albedo: /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/diffuse.exr
# Set roughenss: /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/roughness.exr
# /home/ahc/Documents/metrology_ir/DigitalTwinCatalog/neural_pbir/scripts/relit/blender_script.py:144: DeprecationWarning: Passing in context overrides is deprecated in favor of Context.temp_override(..), calling "object.delete"
#   bpy.ops.object.delete({"selected_objects": objs})
# Set environment map: /home/ahc/Datasets/Stanford-ORB/ground_truth/teapot_scene002/env_map_for_blender/teapot_scene002_0062_for_teapot_scene001.exr
# Writing: im_0062_teapot_scene002_0062_for_teapot_scene001
# Fra:29 Mem:72.26M (Peak 72.27M) | Time:00:00.00 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Synchronizing object | mesh
# Fra:29 Mem:116.27M (Peak 128.41M) | Time:00:00.02 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Initializing
# Fra:29 Mem:116.27M (Peak 128.41M) | Time:00:00.02 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Updating Images | Loading sunrise.exr
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Waiting for render to start
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Loading render kernels (may take a few minutes the first time)
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Scene
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Shaders
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Procedurals
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Background
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Camera
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Meshes Flags
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Objects
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Objects | Copying Transformations to device
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Objects | Applying Static Transformations
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Particle Systems
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Particle Systems | Copying Particles to device
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Meshes
# Fra:29 Mem:132.38M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Mesh | Computing attributes
# Fra:29 Mem:147.56M (Peak 147.56M) | Time:00:00.04 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Mesh | Copying Attributes to device
# Fra:29 Mem:147.56M (Peak 147.56M) | Time:00:00.04 | Mem:23.18M, Peak:23.18M | Scene, View Layer | Updating Scene BVH | Building
# Fra:29 Mem:147.56M (Peak 147.56M) | Time:00:00.04 | Mem:23.18M, Peak:23.18M | Scene, View Layer | Updating Scene BVH | Building BVH
# Fra:29 Mem:147.56M (Peak 147.56M) | Time:00:00.04 | Mem:39.37M, Peak:39.37M | Scene, View Layer | Updating Scene BVH | Building BVH 0%
# Fra:29 Mem:147.56M (Peak 147.56M) | Time:00:00.05 | Mem:58.67M, Peak:74.86M | Scene, View Layer | Updating Scene BVH | Copying BVH to device
# Fra:29 Mem:147.56M (Peak 147.56M) | Time:00:00.05 | Mem:58.67M, Peak:74.86M | Scene, View Layer | Updating Mesh | Computing normals
# Fra:29 Mem:165.77M (Peak 165.77M) | Time:00:00.05 | Mem:58.67M, Peak:74.86M | Scene, View Layer | Updating Mesh | Copying Mesh to device
# Fra:29 Mem:165.77M (Peak 165.77M) | Time:00:00.05 | Mem:76.88M, Peak:76.88M | Scene, View Layer | Updating Objects Flags
# Fra:29 Mem:165.77M (Peak 165.77M) | Time:00:00.05 | Mem:76.88M, Peak:76.88M | Scene, View Layer | Updating Primitive Offsets
# Fra:29 Mem:165.77M (Peak 165.77M) | Time:00:00.05 | Mem:76.88M, Peak:76.88M | Scene, View Layer | Updating Images
# Fra:29 Mem:157.77M (Peak 165.77M) | Time:00:00.05 | Mem:68.88M, Peak:76.88M | Scene, View Layer | Updating Images | Loading roughness.exr
# Fra:29 Mem:173.77M (Peak 173.77M) | Time:00:00.05 | Mem:68.88M, Peak:76.88M | Scene, View Layer | Updating Images | Loading diffuse.exr
# Fra:29 Mem:189.77M (Peak 189.77M) | Time:00:00.05 | Mem:68.88M, Peak:76.88M | Scene, View Layer | Updating Images | Loading teapot_scene002_0062_for_teapot_scene001.exr
# Fra:29 Mem:197.77M (Peak 197.77M) | Time:00:00.06 | Mem:108.88M, Peak:108.88M | Scene, View Layer | Updating Camera Volume
# Fra:29 Mem:197.77M (Peak 197.77M) | Time:00:00.06 | Mem:108.88M, Peak:108.88M | Scene, View Layer | Updating Lookup Tables
# Fra:29 Mem:197.77M (Peak 197.77M) | Time:00:00.06 | Mem:108.88M, Peak:108.88M | Scene, View Layer | Updating Lights
# Fra:29 Mem:197.77M (Peak 197.77M) | Time:00:00.06 | Mem:108.88M, Peak:108.88M | Scene, View Layer | Updating Lights | Importance map
# Fra:29 Mem:261.80M (Peak 549.77M) | Time:00:00.17 | Mem:172.92M, Peak:332.89M | Scene, View Layer | Updating Lights | Computing distribution
# Fra:29 Mem:261.80M (Peak 549.77M) | Time:00:00.17 | Mem:172.93M, Peak:332.89M | Scene, View Layer | Updating Integrator
# Fra:29 Mem:262.80M (Peak 549.77M) | Time:00:00.17 | Mem:173.93M, Peak:332.89M | Scene, View Layer | Updating Film
# Fra:29 Mem:262.81M (Peak 549.77M) | Time:00:00.17 | Mem:173.93M, Peak:332.89M | Scene, View Layer | Updating Lookup Tables
# Fra:29 Mem:262.81M (Peak 549.77M) | Time:00:00.17 | Mem:173.93M, Peak:332.89M | Scene, View Layer | Updating Baking
# Fra:29 Mem:262.81M (Peak 549.77M) | Time:00:00.17 | Mem:173.93M, Peak:332.89M | Scene, View Layer | Updating Device | Writing constant memory
# Fra:29 Mem:262.81M (Peak 549.77M) | Time:00:00.17 | Mem:173.93M, Peak:332.89M | Scene, View Layer | Sample 0/128
# Fra:29 Mem:280.80M (Peak 549.77M) | Time:00:00.18 | Remaining:00:00.90 | Mem:191.82M, Peak:332.89M | Scene, View Layer | Sample 1/128
# Fra:29 Mem:292.73M (Peak 549.77M) | Time:00:00.59 | Mem:191.82M, Peak:332.89M | Scene, View Layer | Sample 128/128
# Fra:29 Mem:292.73M (Peak 549.77M) | Time:00:00.59 | Mem:191.82M, Peak:332.89M | Scene, View Layer | Finished
# Fra:29 Mem:292.80M (Peak 549.77M) | Time:00:00.59 | Compositing
# Fra:29 Mem:292.81M (Peak 549.77M) | Time:00:00.59 | Compositing | Determining resolution
# Fra:29 Mem:292.81M (Peak 549.77M) | Time:00:00.59 | Compositing | Initializing execution
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.60 | Compositing | Tile 2-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.60 | Compositing | Tile 1-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.60 | Compositing | Tile 3-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.60 | Compositing | Tile 4-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.60 | Compositing | Tile 2-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.60 | Compositing | Tile 1-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.60 | Compositing | Tile 3-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.60 | Compositing | Tile 4-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.60 | Compositing | Tile 1-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.60 | Compositing | Tile 2-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.60 | Compositing | Tile 3-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.60 | Compositing | Tile 4-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.60 | Compositing | Tile 1-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.60 | Compositing | Tile 2-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.60 | Compositing | Tile 3-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.60 | Compositing | Tile 4-4
# Fra:29 Mem:303.81M (Peak 549.77M) | Time:00:00.60 | Compositing | De-initializing execution
# Saved: Image0029.png
# Saved: Image0029.png
# Saved: /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0062_albedo0029.exr
# Saved: '/home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0062_teapot_scene002_0062_for_teapot_scene001.exr'
#  Time: 00:00.63 (Saving: 00:00.00)
#
#
# Blender quit
# Blender 3.6.21 (hash e7f18247b228 built 2025-02-18 08:11:48)
# Failed to open dir (No such file or directory): /run/user/1000/gvfs/
# Read blend: "/home/ahc/Documents/metrology_ir/DigitalTwinCatalog/neural_pbir/scripts/relit/relit.blend"
# Results are dumped to /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit
# Set fov: 20.298470147178936 deg
# Loading mesh: /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/mesh.obj
# (  0.0000 sec |   0.0000 sec) Importing OBJ '/home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/mesh.obj'...
#   (  0.0000 sec |   0.0000 sec) Parsing OBJ file...
#     (  2.3620 sec |   2.3619 sec) Done, loading materials and images...
#     (  2.3645 sec |   2.3644 sec) Done, building geometries (verts:265254 faces:530508 materials: 1 smoothgroups:0) ...
#     (  3.2502 sec |   3.2502 sec) Done.
#   (  3.2503 sec |   3.2502 sec) Finished importing: '/home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/mesh.obj'
# Progress: 100.00%
#
# Set albedo: /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/diffuse.exr
# Set roughenss: /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/roughness.exr
# /home/ahc/Documents/metrology_ir/DigitalTwinCatalog/neural_pbir/scripts/relit/blender_script.py:144: DeprecationWarning: Passing in context overrides is deprecated in favor of Context.temp_override(..), calling "object.delete"
#   bpy.ops.object.delete({"selected_objects": objs})
# Set environment map: /home/ahc/Datasets/Stanford-ORB/ground_truth/teapot_scene002/env_map_for_blender/teapot_scene002_0063_for_teapot_scene001.exr
# Writing: im_0063_teapot_scene002_0063_for_teapot_scene001
# Fra:29 Mem:72.26M (Peak 72.27M) | Time:00:00.00 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Synchronizing object | mesh
# Fra:29 Mem:116.27M (Peak 128.41M) | Time:00:00.02 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Initializing
# Fra:29 Mem:116.27M (Peak 128.41M) | Time:00:00.02 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Updating Images | Loading sunrise.exr
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Waiting for render to start
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Loading render kernels (may take a few minutes the first time)
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Scene
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Shaders
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Procedurals
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Background
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Camera
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Meshes Flags
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Objects
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Objects | Copying Transformations to device
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Objects | Applying Static Transformations
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Particle Systems
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Particle Systems | Copying Particles to device
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Meshes
# Fra:29 Mem:132.38M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Mesh | Computing attributes
# Fra:29 Mem:147.56M (Peak 147.56M) | Time:00:00.04 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Mesh | Copying Attributes to device
# Fra:29 Mem:147.56M (Peak 147.56M) | Time:00:00.04 | Mem:23.18M, Peak:23.18M | Scene, View Layer | Updating Scene BVH | Building
# Fra:29 Mem:147.56M (Peak 147.56M) | Time:00:00.04 | Mem:23.18M, Peak:23.18M | Scene, View Layer | Updating Scene BVH | Building BVH
# Fra:29 Mem:147.56M (Peak 147.56M) | Time:00:00.04 | Mem:39.37M, Peak:39.37M | Scene, View Layer | Updating Scene BVH | Building BVH 0%
# Fra:29 Mem:147.56M (Peak 147.56M) | Time:00:00.05 | Mem:58.67M, Peak:74.86M | Scene, View Layer | Updating Scene BVH | Copying BVH to device
# Fra:29 Mem:147.56M (Peak 147.56M) | Time:00:00.05 | Mem:58.67M, Peak:74.86M | Scene, View Layer | Updating Mesh | Computing normals
# Fra:29 Mem:165.77M (Peak 165.77M) | Time:00:00.05 | Mem:58.67M, Peak:74.86M | Scene, View Layer | Updating Mesh | Copying Mesh to device
# Fra:29 Mem:165.77M (Peak 165.77M) | Time:00:00.05 | Mem:76.88M, Peak:76.88M | Scene, View Layer | Updating Objects Flags
# Fra:29 Mem:165.77M (Peak 165.77M) | Time:00:00.05 | Mem:76.88M, Peak:76.88M | Scene, View Layer | Updating Primitive Offsets
# Fra:29 Mem:165.77M (Peak 165.77M) | Time:00:00.05 | Mem:76.88M, Peak:76.88M | Scene, View Layer | Updating Images
# Fra:29 Mem:157.77M (Peak 165.77M) | Time:00:00.05 | Mem:68.88M, Peak:76.88M | Scene, View Layer | Updating Images | Loading roughness.exr
# Fra:29 Mem:173.77M (Peak 173.77M) | Time:00:00.05 | Mem:68.88M, Peak:76.88M | Scene, View Layer | Updating Images | Loading diffuse.exr
# Fra:29 Mem:189.77M (Peak 189.77M) | Time:00:00.05 | Mem:68.88M, Peak:76.88M | Scene, View Layer | Updating Images | Loading teapot_scene002_0063_for_teapot_scene001.exr
# Fra:29 Mem:197.77M (Peak 197.77M) | Time:00:00.06 | Mem:108.88M, Peak:108.88M | Scene, View Layer | Updating Camera Volume
# Fra:29 Mem:197.77M (Peak 197.77M) | Time:00:00.06 | Mem:108.88M, Peak:108.88M | Scene, View Layer | Updating Lookup Tables
# Fra:29 Mem:197.77M (Peak 197.77M) | Time:00:00.06 | Mem:108.88M, Peak:108.88M | Scene, View Layer | Updating Lights
# Fra:29 Mem:197.77M (Peak 197.77M) | Time:00:00.06 | Mem:108.88M, Peak:108.88M | Scene, View Layer | Updating Lights | Importance map
# Fra:29 Mem:261.80M (Peak 549.77M) | Time:00:00.16 | Mem:172.92M, Peak:332.89M | Scene, View Layer | Updating Lights | Computing distribution
# Fra:29 Mem:261.80M (Peak 549.77M) | Time:00:00.16 | Mem:172.93M, Peak:332.89M | Scene, View Layer | Updating Integrator
# Fra:29 Mem:262.80M (Peak 549.77M) | Time:00:00.16 | Mem:173.93M, Peak:332.89M | Scene, View Layer | Updating Film
# Fra:29 Mem:262.81M (Peak 549.77M) | Time:00:00.16 | Mem:173.93M, Peak:332.89M | Scene, View Layer | Updating Lookup Tables
# Fra:29 Mem:262.81M (Peak 549.77M) | Time:00:00.16 | Mem:173.93M, Peak:332.89M | Scene, View Layer | Updating Baking
# Fra:29 Mem:262.81M (Peak 549.77M) | Time:00:00.16 | Mem:173.93M, Peak:332.89M | Scene, View Layer | Updating Device | Writing constant memory
# Fra:29 Mem:262.81M (Peak 549.77M) | Time:00:00.16 | Mem:173.93M, Peak:332.89M | Scene, View Layer | Sample 0/128
# Fra:29 Mem:280.80M (Peak 549.77M) | Time:00:00.17 | Remaining:00:00.76 | Mem:191.82M, Peak:332.89M | Scene, View Layer | Sample 1/128
# Fra:29 Mem:292.73M (Peak 549.77M) | Time:00:00.61 | Mem:191.82M, Peak:332.89M | Scene, View Layer | Sample 128/128
# Fra:29 Mem:292.73M (Peak 549.77M) | Time:00:00.61 | Mem:191.82M, Peak:332.89M | Scene, View Layer | Finished
# Fra:29 Mem:292.80M (Peak 549.77M) | Time:00:00.61 | Compositing
# Fra:29 Mem:292.81M (Peak 549.77M) | Time:00:00.61 | Compositing | Determining resolution
# Fra:29 Mem:292.81M (Peak 549.77M) | Time:00:00.61 | Compositing | Initializing execution
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.61 | Compositing | Tile 1-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.61 | Compositing | Tile 2-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.61 | Compositing | Tile 3-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.61 | Compositing | Tile 4-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.61 | Compositing | Tile 1-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.61 | Compositing | Tile 2-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.61 | Compositing | Tile 3-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.61 | Compositing | Tile 4-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.61 | Compositing | Tile 1-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.61 | Compositing | Tile 2-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.61 | Compositing | Tile 3-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.61 | Compositing | Tile 4-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.61 | Compositing | Tile 1-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.61 | Compositing | Tile 2-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.61 | Compositing | Tile 3-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.61 | Compositing | Tile 4-4
# Fra:29 Mem:303.81M (Peak 549.77M) | Time:00:00.61 | Compositing | De-initializing execution
# Saved: Image0029.png
# Saved: Image0029.png
# Saved: /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0063_albedo0029.exr
# Saved: '/home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0063_teapot_scene002_0063_for_teapot_scene001.exr'
#  Time: 00:00.65 (Saving: 00:00.00)
#
#
# Blender quit
# Blender 3.6.21 (hash e7f18247b228 built 2025-02-18 08:11:48)
# Failed to open dir (No such file or directory): /run/user/1000/gvfs/
# Read blend: "/home/ahc/Documents/metrology_ir/DigitalTwinCatalog/neural_pbir/scripts/relit/relit.blend"
# Results are dumped to /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit
# Set fov: 20.298470147178936 deg
# Loading mesh: /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/mesh.obj
# (  0.0000 sec |   0.0000 sec) Importing OBJ '/home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/mesh.obj'...
#   (  0.0000 sec |   0.0000 sec) Parsing OBJ file...
#     (  2.3927 sec |   2.3927 sec) Done, loading materials and images...
#     (  2.3954 sec |   2.3953 sec) Done, building geometries (verts:265254 faces:530508 materials: 1 smoothgroups:0) ...
#     (  3.2878 sec |   3.2877 sec) Done.
#   (  3.2878 sec |   3.2878 sec) Finished importing: '/home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/mesh.obj'
# Progress: 100.00%
#
# Set albedo: /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/diffuse.exr
# Set roughenss: /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/roughness.exr
# /home/ahc/Documents/metrology_ir/DigitalTwinCatalog/neural_pbir/scripts/relit/blender_script.py:144: DeprecationWarning: Passing in context overrides is deprecated in favor of Context.temp_override(..), calling "object.delete"
#   bpy.ops.object.delete({"selected_objects": objs})
# Set environment map: /home/ahc/Datasets/Stanford-ORB/ground_truth/teapot_scene002/env_map_for_blender/teapot_scene002_0064_for_teapot_scene001.exr
# Writing: im_0064_teapot_scene002_0064_for_teapot_scene001
# Fra:29 Mem:72.26M (Peak 72.27M) | Time:00:00.00 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Synchronizing object | mesh
# Fra:29 Mem:116.27M (Peak 128.41M) | Time:00:00.02 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Initializing
# Fra:29 Mem:116.27M (Peak 128.41M) | Time:00:00.02 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Updating Images | Loading sunrise.exr
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Waiting for render to start
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Loading render kernels (may take a few minutes the first time)
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Scene
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Shaders
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Procedurals
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Background
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Camera
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Meshes Flags
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Objects
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Objects | Copying Transformations to device
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Objects | Applying Static Transformations
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Particle Systems
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Particle Systems | Copying Particles to device
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Meshes
# Fra:29 Mem:132.38M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Mesh | Computing attributes
# Fra:29 Mem:147.56M (Peak 147.56M) | Time:00:00.04 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Mesh | Copying Attributes to device
# Fra:29 Mem:147.56M (Peak 147.56M) | Time:00:00.04 | Mem:23.18M, Peak:23.18M | Scene, View Layer | Updating Scene BVH | Building
# Fra:29 Mem:147.56M (Peak 147.56M) | Time:00:00.04 | Mem:23.18M, Peak:23.18M | Scene, View Layer | Updating Scene BVH | Building BVH
# Fra:29 Mem:147.56M (Peak 147.56M) | Time:00:00.04 | Mem:39.37M, Peak:39.37M | Scene, View Layer | Updating Scene BVH | Building BVH 0%
# Fra:29 Mem:147.56M (Peak 147.56M) | Time:00:00.04 | Mem:58.67M, Peak:74.86M | Scene, View Layer | Updating Scene BVH | Copying BVH to device
# Fra:29 Mem:147.56M (Peak 147.56M) | Time:00:00.04 | Mem:58.67M, Peak:74.86M | Scene, View Layer | Updating Mesh | Computing normals
# Fra:29 Mem:165.77M (Peak 165.77M) | Time:00:00.05 | Mem:58.67M, Peak:74.86M | Scene, View Layer | Updating Mesh | Copying Mesh to device
# Fra:29 Mem:165.77M (Peak 165.77M) | Time:00:00.05 | Mem:76.88M, Peak:76.88M | Scene, View Layer | Updating Objects Flags
# Fra:29 Mem:165.77M (Peak 165.77M) | Time:00:00.05 | Mem:76.88M, Peak:76.88M | Scene, View Layer | Updating Primitive Offsets
# Fra:29 Mem:165.77M (Peak 165.77M) | Time:00:00.05 | Mem:76.88M, Peak:76.88M | Scene, View Layer | Updating Images
# Fra:29 Mem:157.77M (Peak 165.77M) | Time:00:00.05 | Mem:68.88M, Peak:76.88M | Scene, View Layer | Updating Images | Loading roughness.exr
# Fra:29 Mem:173.77M (Peak 173.77M) | Time:00:00.05 | Mem:68.88M, Peak:76.88M | Scene, View Layer | Updating Images | Loading diffuse.exr
# Fra:29 Mem:189.77M (Peak 189.77M) | Time:00:00.05 | Mem:68.88M, Peak:76.88M | Scene, View Layer | Updating Images | Loading teapot_scene002_0064_for_teapot_scene001.exr
# Fra:29 Mem:197.77M (Peak 197.77M) | Time:00:00.06 | Mem:108.88M, Peak:108.88M | Scene, View Layer | Updating Camera Volume
# Fra:29 Mem:197.77M (Peak 197.77M) | Time:00:00.06 | Mem:108.88M, Peak:108.88M | Scene, View Layer | Updating Lookup Tables
# Fra:29 Mem:197.77M (Peak 197.77M) | Time:00:00.06 | Mem:108.88M, Peak:108.88M | Scene, View Layer | Updating Lights
# Fra:29 Mem:197.77M (Peak 197.77M) | Time:00:00.06 | Mem:108.88M, Peak:108.88M | Scene, View Layer | Updating Lights | Importance map
# Fra:29 Mem:261.80M (Peak 549.77M) | Time:00:00.17 | Mem:172.92M, Peak:332.89M | Scene, View Layer | Updating Lights | Computing distribution
# Fra:29 Mem:261.80M (Peak 549.77M) | Time:00:00.17 | Mem:172.93M, Peak:332.89M | Scene, View Layer | Updating Integrator
# Fra:29 Mem:262.80M (Peak 549.77M) | Time:00:00.17 | Mem:173.93M, Peak:332.89M | Scene, View Layer | Updating Film
# Fra:29 Mem:262.81M (Peak 549.77M) | Time:00:00.17 | Mem:173.93M, Peak:332.89M | Scene, View Layer | Updating Lookup Tables
# Fra:29 Mem:262.81M (Peak 549.77M) | Time:00:00.17 | Mem:173.93M, Peak:332.89M | Scene, View Layer | Updating Baking
# Fra:29 Mem:262.81M (Peak 549.77M) | Time:00:00.17 | Mem:173.93M, Peak:332.89M | Scene, View Layer | Updating Device | Writing constant memory
# Fra:29 Mem:262.81M (Peak 549.77M) | Time:00:00.17 | Mem:173.93M, Peak:332.89M | Scene, View Layer | Sample 0/128
# Fra:29 Mem:280.80M (Peak 549.77M) | Time:00:00.17 | Remaining:00:00.76 | Mem:191.82M, Peak:332.89M | Scene, View Layer | Sample 1/128
# Fra:29 Mem:292.73M (Peak 549.77M) | Time:00:00.59 | Mem:191.82M, Peak:332.89M | Scene, View Layer | Sample 128/128
# Fra:29 Mem:292.73M (Peak 549.77M) | Time:00:00.59 | Mem:191.82M, Peak:332.89M | Scene, View Layer | Finished
# Fra:29 Mem:292.80M (Peak 549.77M) | Time:00:00.60 | Compositing
# Fra:29 Mem:292.81M (Peak 549.77M) | Time:00:00.60 | Compositing | Determining resolution
# Fra:29 Mem:292.81M (Peak 549.77M) | Time:00:00.60 | Compositing | Initializing execution
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.60 | Compositing | Tile 1-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.60 | Compositing | Tile 2-4
# ...
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Objects | Copying Transformations to device
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Objects | Applying Static Transformations
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Particle Systems
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Particle Systems | Copying Particles to device
# Fra:29 Mem:124.28M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Meshes
# Fra:29 Mem:132.38M (Peak 140.28M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Mesh | Computing attributes
# Fra:29 Mem:147.56M (Peak 147.56M) | Time:00:00.04 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Mesh | Copying Attributes to device
# Fra:29 Mem:147.56M (Peak 147.56M) | Time:00:00.04 | Mem:23.18M, Peak:23.18M | Scene, View Layer | Updating Scene BVH | Building
# Fra:29 Mem:147.56M (Peak 147.56M) | Time:00:00.04 | Mem:23.18M, Peak:23.18M | Scene, View Layer | Updating Scene BVH | Building BVH
# Fra:29 Mem:147.56M (Peak 147.56M) | Time:00:00.04 | Mem:39.37M, Peak:39.37M | Scene, View Layer | Updating Scene BVH | Building BVH 0%
# Fra:29 Mem:147.56M (Peak 147.56M) | Time:00:00.04 | Mem:58.67M, Peak:74.86M | Scene, View Layer | Updating Scene BVH | Copying BVH to device
# Fra:29 Mem:147.56M (Peak 147.56M) | Time:00:00.04 | Mem:58.67M, Peak:74.86M | Scene, View Layer | Updating Mesh | Computing normals
# Fra:29 Mem:165.77M (Peak 165.77M) | Time:00:00.05 | Mem:58.67M, Peak:74.86M | Scene, View Layer | Updating Mesh | Copying Mesh to device
# Fra:29 Mem:165.77M (Peak 165.77M) | Time:00:00.05 | Mem:76.88M, Peak:76.88M | Scene, View Layer | Updating Objects Flags
# Fra:29 Mem:165.77M (Peak 165.77M) | Time:00:00.05 | Mem:76.88M, Peak:76.88M | Scene, View Layer | Updating Primitive Offsets
# Fra:29 Mem:165.77M (Peak 165.77M) | Time:00:00.05 | Mem:76.88M, Peak:76.88M | Scene, View Layer | Updating Images
# Fra:29 Mem:157.77M (Peak 165.77M) | Time:00:00.05 | Mem:68.88M, Peak:76.88M | Scene, View Layer | Updating Images | Loading roughness.exr
# Fra:29 Mem:173.77M (Peak 173.77M) | Time:00:00.05 | Mem:68.88M, Peak:76.88M | Scene, View Layer | Updating Images | Loading diffuse.exr
# Fra:29 Mem:189.77M (Peak 189.77M) | Time:00:00.05 | Mem:68.88M, Peak:76.88M | Scene, View Layer | Updating Images | Loading teapot_scene006_0070_for_teapot_scene001.exr
# Fra:29 Mem:197.77M (Peak 197.77M) | Time:00:00.06 | Mem:108.88M, Peak:108.88M | Scene, View Layer | Updating Camera Volume
# Fra:29 Mem:197.77M (Peak 197.77M) | Time:00:00.06 | Mem:108.88M, Peak:108.88M | Scene, View Layer | Updating Lookup Tables
# Fra:29 Mem:197.77M (Peak 197.77M) | Time:00:00.06 | Mem:108.88M, Peak:108.88M | Scene, View Layer | Updating Lights
# Fra:29 Mem:197.77M (Peak 197.77M) | Time:00:00.06 | Mem:108.88M, Peak:108.88M | Scene, View Layer | Updating Lights | Importance map
# Fra:29 Mem:261.80M (Peak 549.77M) | Time:00:00.17 | Mem:172.92M, Peak:332.89M | Scene, View Layer | Updating Lights | Computing distribution
# Fra:29 Mem:261.80M (Peak 549.77M) | Time:00:00.17 | Mem:172.93M, Peak:332.89M | Scene, View Layer | Updating Integrator
# Fra:29 Mem:262.80M (Peak 549.77M) | Time:00:00.17 | Mem:173.93M, Peak:332.89M | Scene, View Layer | Updating Film
# Fra:29 Mem:262.81M (Peak 549.77M) | Time:00:00.17 | Mem:173.93M, Peak:332.89M | Scene, View Layer | Updating Lookup Tables
# Fra:29 Mem:262.81M (Peak 549.77M) | Time:00:00.17 | Mem:173.93M, Peak:332.89M | Scene, View Layer | Updating Baking
# Fra:29 Mem:262.81M (Peak 549.77M) | Time:00:00.17 | Mem:173.93M, Peak:332.89M | Scene, View Layer | Updating Device | Writing constant memory
# Fra:29 Mem:262.81M (Peak 549.77M) | Time:00:00.17 | Mem:173.93M, Peak:332.89M | Scene, View Layer | Sample 0/128
# Fra:29 Mem:280.80M (Peak 549.77M) | Time:00:00.17 | Remaining:00:00.88 | Mem:191.82M, Peak:332.89M | Scene, View Layer | Sample 1/128
# Fra:29 Mem:292.73M (Peak 549.77M) | Time:00:00.65 | Mem:191.82M, Peak:332.89M | Scene, View Layer | Sample 128/128
# Fra:29 Mem:292.73M (Peak 549.77M) | Time:00:00.65 | Mem:191.82M, Peak:332.89M | Scene, View Layer | Finished
# Fra:29 Mem:292.80M (Peak 549.77M) | Time:00:00.66 | Compositing
# Fra:29 Mem:292.81M (Peak 549.77M) | Time:00:00.66 | Compositing | Determining resolution
# Fra:29 Mem:292.81M (Peak 549.77M) | Time:00:00.66 | Compositing | Initializing execution
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.66 | Compositing | Tile 1-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.66 | Compositing | Tile 2-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.66 | Compositing | Tile 3-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.66 | Compositing | Tile 4-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.66 | Compositing | Tile 1-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.66 | Compositing | Tile 2-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.66 | Compositing | Tile 3-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.66 | Compositing | Tile 4-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.66 | Compositing | Tile 1-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.66 | Compositing | Tile 2-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.66 | Compositing | Tile 3-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.66 | Compositing | Tile 4-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.66 | Compositing | Tile 1-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.66 | Compositing | Tile 2-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.66 | Compositing | Tile 3-4
# Fra:29 Mem:303.87M (Peak 549.77M) | Time:00:00.66 | Compositing | Tile 4-4
# Fra:29 Mem:303.81M (Peak 549.77M) | Time:00:00.66 | Compositing | De-initializing execution
# Saved: Image0029.png
# Saved: Image0029.png
# Saved: /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0070_albedo0029.exr
# Saved: '/home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0070_teapot_scene006_0070_for_teapot_scene001.exr'
#  Time: 00:00.70 (Saving: 00:00.00)
#
#
# Blender quit
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/render_geo/0000_image.zbuf.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/render_geo/0007_image.zbuf.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/render_geo/0014_image.zbuf.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/render_geo/0021_image.zbuf.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/render_geo/0028_image.zbuf.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/render_geo/0035_image.zbuf.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/render_geo/0042_image.zbuf.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/render_geo/0049_image.zbuf.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/render_geo/0056_image.zbuf.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/render_geo/0063_image.zbuf.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0000_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0007_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0014_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0021_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0028_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0035_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0042_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0049_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0056_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0063_image_envmap_for_blender.exr
# teapot_scene001     : nv=10/10 nl=20/20 mat=10/10 geo=10/10 w/ mesh
# Save to results___NPBIR___EST_g__EST_l/stanford_orb/eval_inputs_pbir.json
# INFO:__main__:Processing 1 scenes...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0000_image_envmap_for_blender.exr
# /home/ahc/miniconda3/envs/metrology_ir/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/ahc/miniconda3/envs/metrology_ir/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# /home/ahc/miniconda3/envs/metrology_ir/lib/python3.11/site-packages/lpips/lpips.py:107: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.load_state_dict(torch.load(model_path, map_location='cpu'), strict=False)
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0007_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0014_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0021_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0028_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0035_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0042_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0049_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0056_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0063_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0060_teapot_scene002_0060_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0061_teapot_scene002_0061_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0062_teapot_scene002_0062_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0063_teapot_scene002_0063_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0064_teapot_scene002_0064_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0065_teapot_scene002_0065_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0066_teapot_scene002_0066_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0067_teapot_scene002_0067_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0068_teapot_scene002_0068_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0069_teapot_scene002_0069_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0061_teapot_scene006_0061_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0062_teapot_scene006_0062_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0063_teapot_scene006_0063_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0064_teapot_scene006_0064_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0065_teapot_scene006_0065_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0066_teapot_scene006_0066_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0067_teapot_scene006_0067_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0068_teapot_scene006_0068_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0069_teapot_scene006_0069_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR___EST_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0070_teapot_scene006_0070_for_teapot_scene001.exr
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.05s/it]
# INFO:__main__:Results saved to .././results___NPBIR___EST_g__EST_l/stanford_orb/eval_outputs_pbir.json
