# %%
ALL_METHODS = [
    "results___NPBIR___EST_g__EST_l",  # OG
    "results___NPBIR____GT_g__EST_l",
    "results___NPBIR___EST_g___GT_l",
    "results___NPBIR__VGGT_g__EST_l",
    "results___NPBIR__VGGT_g___GT_l",
]


METHOD=ALL_METHODS[3]
NPBIR="./DigitalTwinCatalog/neural_pbir"
CHKPT=f"./{METHOD}/stanford_orb"
SORB = "/home/ahc/Datasets/Stanford-ORB"
SORB_HDR = f"{SORB}/blender_HDR"
SORB_GT = f"{SORB}/ground_truth"
SCENE = "teapot_scene001" # "baking_scene001"

# %%
# analyze mesh alignment first
M1="/home/ahc/Datasets/Stanford-ORB/ground_truth/teapot_scene001/mesh_vggt.obj"
M2="/home/ahc/Datasets/Stanford-ORB/ground_truth/teapot_scene001/mesh_vggt.obj"
M3="/home/ahc/Datasets/Stanford-ORB/ground_truth/teapot_scene001/mesh_blender/mesh.obj" 
# !python compare_mesh_alignment.py {M1} {M2} {M3} --output aligned_comparison_vggt.ply
# Out:
# Loading Red mesh from: /home/ahc/Datasets/Stanford-ORB/ground_truth/teapot_scene001/mesh_vggt.obj
#
# Per mesh stats [/home/ahc/Datasets/Stanford-ORB/ground_truth/teapot_scene001/mesh_vggt.obj]:
#   Total vertices: 32592
#   Total faces: 64592
#   Bounds: [[-0.306375 -0.236633 -0.182005]
#  [ 0.242847  0.277442  0.320402]]
# Loading Green mesh from: /home/ahc/Datasets/Stanford-ORB/ground_truth/teapot_scene001/mesh_vggt.obj
#
# Per mesh stats [/home/ahc/Datasets/Stanford-ORB/ground_truth/teapot_scene001/mesh_vggt.obj]:
#   Total vertices: 32592
#   Total faces: 64592
#   Bounds: [[-0.306375 -0.236633 -0.182005]
#  [ 0.242847  0.277442  0.320402]]
# Loading Blue mesh from: /home/ahc/Datasets/Stanford-ORB/ground_truth/teapot_scene001/mesh_blender/mesh.obj
#
# Per mesh stats [/home/ahc/Datasets/Stanford-ORB/ground_truth/teapot_scene001/mesh_blender/mesh.obj]:
#   Total vertices: 118976
#   Total faces: 200000
#   Bounds: [[-0.27192304 -0.21533936 -0.18616989]
#  [ 0.37355959  0.23565942  0.31300035]]
#
# Combined mesh stats:
#   Total vertices: 184160
#   Total faces: 329184
#   Bounds: [[-0.306375   -0.236633   -0.18616989]
#  [ 0.37355959  0.277442    0.320402  ]]
#
# Saved to: aligned_comparison_vggt.ply

# %%
# !python ~/Documents/metrology_ir/vggt_geometry.py {SORB_HDR}/{SCENE} --max_images 18 --wnnc_width_config l5 --hdr --output {SORB_GT}/{SCENE}/mesh_vggt.obj --align_voxel_fraction 0.01 --align_to {SORB_GT}/{SCENE}/mesh_blender/mesh.obj
# Out:
# Using 18 image/mask pairs from 'train' split
# Loading VGGT-1B...
# Preprocessing images...
# Running VGGT forward pass...
# /home/ahc/Documents/metrology_ir/vggt_geometry.py:312: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(dtype=dtype):
# /home/ahc/Documents/metrology_ir/vggt/vggt/models/vggt.py:65: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=False):
# Filtering points by mask and confidence...
#   325,258 points before downsampling
#   36,792 points after downsampling/outlier removal
#   Saved -> /home/ahc/Datasets/Stanford-ORB/ground_truth/teapot_scene001/pointcloud_vggt.ply
# Running WNNC (width_config=l5)...
# num_nodes: 51433, num_leaves: 36792, tree depth: 10
# tree_depth*num_points: 367920, stdvec_node2point_index.size(): 299557
#   Normals -> /home/ahc/Datasets/Stanford-ORB/ground_truth/teapot_scene001/pointcloud_vggt.xyz
# Building mesh...
#   Poisson reconstruction (depth=9)...
# Aligning mesh -> ref | diag(src)=0.2594, diag(ref)=0.9322, voxel=0.009322
# [Open3D WARNING] Too few correspondences (810) after mutual filter, fall back to original correspondences.
# Alignment done | pre_scale=3.593475, RANSAC(fit=0.9692, rmse=0.0249), ICP(fit=0.7811, rmse=0.0083)
# Saved transform -> /home/ahc/Datasets/Stanford-ORB/ground_truth/teapot_scene001/vggt_to_ref_transform.txt
# Saved mesh (32,592 verts, 64,592 tris) -> /home/ahc/Datasets/Stanford-ORB/ground_truth/teapot_scene001/mesh_vggt.obj

# %%
# run once per new scene within the dataset itself (regardless of method, etc.)
# !python DigitalTwinCatalog/neural_pbir/scripts/preprocess/stanford_orb.py /home/ahc/Datasets/Stanford-ORB/blender_HDR/{SCENE}

# !python {NPBIR}/neural_surface_recon/run_template.py --template {NPBIR}/neural_surface_recon/configs/template_stanford_orb.py --savemem {SORB_HDR}/{SCENE}/ --mesh_init_path={SORB_GT}/{SCENE}/mesh_vggt.obj
# !mv results {METHOD}

# !python {NPBIR}/neural_distillation/run.py {CHKPT}/{SCENE}/
# !python {NPBIR}/pbir/run.py {NPBIR}/pbir/configs/template {CHKPT}/{SCENE}/
# !python {NPBIR}/scripts/stanford_orb/render_geo.py {SORB_HDR}/{SCENE}/cameras.json {CHKPT}/{SCENE}/pbir/mesh.obj

# !python {NPBIR}/scripts/stanford_orb/postproc_envmap_our.py "{CHKPT}/{SCENE}/pbir/envmap.exr"

# NOVEL VIEW SYNTHESIS
CAM=f"{SORB_HDR}/{SCENE}/cameras.json"
CKPT_GEO=f"{CHKPT}/{SCENE}/pbir/mesh.obj"
CKPT_ALBEDO=f"{CHKPT}/{SCENE}/pbir/diffuse.exr"
CKPT_ROUGH=f"{CHKPT}/{SCENE}/pbir/roughness.exr"
CKPT_ENV=f"{CHKPT}/{SCENE}/pbir/envmap_for_blender.exr"
# !python {NPBIR}/scripts/relit/relit.py {CKPT_GEO} {CKPT_ALBEDO} {CKPT_ROUGH} {CAM} --lgt_paths {CKPT_ENV} --render_exr --with_bg

# RELIGHTING
# !python {NPBIR}/scripts/stanford_orb/relit_nl.py --ckptroot {CHKPT} --dataroot {SORB}


# !python {NPBIR}/scripts/stanford_orb/eval_preprocess.py --data_dir {SORB}/  --ckpt_dir {CHKPT}/
# !cd Stanford-ORB && PYTHONPATH=. python scripts/test.py --input-path ../{CHKPT}/eval_inputs_pbir.json --output-path ../{CHKPT}/eval_outputs_pbir.json --scenes example
# Out:
# /home/ahc/miniconda3/envs/metrology_ir/lib/python3.11/site-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# ==> disable pre-load all training data to save GPU memory
# ==> using mesh prior for SDF init: /home/ahc/Datasets/Stanford-ORB/ground_truth/teapot_scene001/mesh_vggt.obj
# /home/ahc/miniconda3/envs/metrology_ir/lib/python3.11/site-packages/torch/__init__.py:955: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:432.)
#   _C._set_default_tensor_type(t)
# Start loading dataset...
# 100%|██████████████████████████████████████████| 70/70 [00:00<00:00, 271.66it/s]
# Finish loading dataset in 0.4 sec.
# Loaded dataset: (70, 512, 512, 3) /home/ahc/Datasets/Stanford-ORB/blender_HDR/teapot_scene001
# # train: 60
# # test: 10 [60 61 62 63 64 65 66 67 68 69]
# train: start
# compute_bbox: start
# compute_bbox: xyz_min tensor([-0.6000, -0.6000, -0.6000])
# compute_bbox: xyz_max tensor([0.6000, 0.6000, 0.6000])
# compute_bbox: finish
# train: skip coarse geometry searching
# scene_rep_reconstruction (fine): train from scratch
# VolRepr-fg: voxel_size       tensor(0.0320)
# VolRepr-fg: world_size       tensor([37, 37, 37])
# VolRepr-fg: world_size_k0    tensor([37, 37, 37])
# VolRepr-fg: voxel_size_base  tensor(0.0075)
# VolRepr-fg: voxel_size_ratio tensor(4.2667)
# VolRepr-fg: geometry grid DenseGrid(channels=1, world_size=[37, 37, 37])
# VolRepr-fg: feature voxel grid DenseGrid(channels=12, world_size=[37, 37, 37])
# VolRepr-fg: mlp MLP_torch(
#   (mlp): Sequential(
#     (0): Linear(in_features=39, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Sequential(
#       (0): Linear(in_features=128, out_features=128, bias=True)
#       (1): ReLU(inplace=True)
#     )
#     (3): Linear(in_features=128, out_features=3, bias=True)
#   )
# )
# VolRepr-bg: set density bias shift to tensor([-4.5951], device='cpu')
# VolRepr-bg: voxel_size       tensor(0.5120)
# VolRepr-bg: world_size       tensor([37, 37, 37])
# VolRepr-bg: world_size_k0    tensor([37, 37, 37])
# VolRepr-bg: voxel_size_base  tensor(0.1200)
# VolRepr-bg: voxel_size_ratio tensor(4.2667)
# VolRepr-bg: geometry grid DenseGrid(channels=1, world_size=[37, 37, 37])
# VolRepr-bg: feature voxel grid DenseGrid(channels=8, world_size=[37, 37, 37])
# VolRepr-bg: mlp MLP_tcnn(
#   (mlp): Network(n_input_dims=35, n_output_dims=3, seed=1337, dtype=torch.float16, hyperparams={'encoding': {'offset': 0.0, 'otype': 'Identity', 'scale': 1.0}, 'network': {'activation': 'ReLU', 'n_hidden_layers': 2, 'n_neurons': 64, 'otype': 'FullyFusedMLP', 'output_activation': 'None'}, 'otype': 'NetworkWithInputEncoding'})
# )
# create_optimizer_or_freeze_model: param density lr 0.003
# create_optimizer_or_freeze_model: param k0 lr 0.1
# create_optimizer_or_freeze_model: param sdf_scale freeze
# create_optimizer_or_freeze_model: param rgbnet lr 0.001
# create_optimizer_or_freeze_model: param bg_model.density lr 0.1
# create_optimizer_or_freeze_model: param bg_model.k0 lr 0.1
# create_optimizer_or_freeze_model: param bg_model.rgbnet lr 0.001
# get_training_rays_offline_sampler: start
# get_training_rays_offline_sampler: ratio tensor(0.9147)
# get_training_rays_offline_sampler: finish (eps time: 0.14811468124389648 sec)
# loss weight_main 1.0
# loss weight_rgbper 0.001
# loss weight_entropy_last 0
# loss weight_mask 0.001
# loss weight_laplace 1e-08
#   0%|▏                                       | 93/25000 [00:01<05:58, 69.49it/s]geo grid grad stat: %=0.6697 mu=-1.19e-08 mu=5.23e-08 std=1.26e-07 min=-2.79e-06 max=2.44e-06
#   1%|▎                                      | 198/25000 [00:03<06:02, 68.45it/s]geo grid grad stat: %=0.7242 mu=3.10e-09 mu=3.15e-08 std=8.86e-08 min=-1.76e-06 max=2.70e-06
#   1%|▍                                      | 292/25000 [00:04<05:43, 71.97it/s]geo grid grad stat: %=0.7410 mu=9.80e-10 mu=1.92e-08 std=5.67e-08 min=-1.28e-06 max=1.58e-06
#   2%|▌                                      | 396/25000 [00:05<05:27, 75.23it/s]geo grid grad stat: %=0.7459 mu=7.36e-10 mu=1.24e-08 std=3.94e-08 min=-9.26e-07 max=1.18e-06
#   2%|▊                                      | 494/25000 [00:06<05:06, 79.87it/s]VolRepr-fg: sharpness 44.95
# VolRepr-fg: occupancy mask activated ratio 1.0000 => 0.9134
# VolRepr-bg: occupancy mask activated ratio 1.0000 => 1.0000
# geo grid grad stat: %=0.7416 mu=7.90e-10 mu=9.82e-09 std=3.33e-08 min=-9.32e-07 max=7.72e-07
# scene_rep_reconstruction (fine): iter    500 / Loss: 0.002408000 / PSNR: 19.63 / Eps: 00:00:07
#   2%|▉                                      | 591/25000 [00:08<04:52, 83.37it/s]geo grid grad stat: %=0.7308 mu=6.58e-10 mu=8.76e-09 std=3.14e-08 min=-9.76e-07 max=6.58e-07
#   3%|█                                      | 699/25000 [00:09<04:42, 86.10it/s]geo grid grad stat: %=0.7156 mu=2.18e-10 mu=8.26e-09 std=2.92e-08 min=-7.46e-07 max=1.02e-06
#   3%|█▏                                     | 798/25000 [00:10<04:32, 88.82it/s]geo grid grad stat: %=0.7051 mu=-5.76e-10 mu=7.92e-09 std=3.05e-08 min=-1.35e-06 max=8.13e-07
#   4%|█▍                                     | 894/25000 [00:11<04:30, 89.10it/s]geo grid grad stat: %=0.6970 mu=4.72e-10 mu=8.02e-09 std=2.99e-08 min=-1.47e-06 max=5.35e-07
#   4%|█▌                                     | 992/25000 [00:12<04:27, 89.88it/s]VolRepr-fg: scale_volume_grid start
# VolRepr-fg: voxel_size       tensor(0.0254)
# VolRepr-fg: world_size       tensor([47, 47, 47])
# VolRepr-fg: world_size_k0    tensor([47, 47, 47])
# VolRepr-fg: voxel_size_base  tensor(0.0075)
# VolRepr-fg: voxel_size_ratio tensor(3.3865)
# VolRepr-fg: scale_volume_grid scale world_size from [37, 37, 37] to [47, 47, 47]
# VolRepr-fg: scale_volume_grid finish
# VolRepr-bg: scale_volume_grid start
# VolRepr-bg: voxel_size       tensor(0.4064)
# VolRepr-bg: world_size       tensor([47, 47, 47])
# VolRepr-bg: world_size_k0    tensor([47, 47, 47])
# VolRepr-bg: voxel_size_base  tensor(0.1200)
# VolRepr-bg: voxel_size_ratio tensor(3.3865)
# VolRepr-bg: scale_volume_grid scale world_size from [37, 37, 37] to [47, 47, 47]
# VolRepr-bg: scale_volume_grid finish
# create_optimizer_or_freeze_model: param density lr 0.002495291313308013
# create_optimizer_or_freeze_model: param k0 lr 0.09120108393559098
# create_optimizer_or_freeze_model: param sdf_scale freeze
# create_optimizer_or_freeze_model: param rgbnet lr 0.0009120108393559097
# create_optimizer_or_freeze_model: param bg_model.density lr 0.09120108393559098
# create_optimizer_or_freeze_model: param bg_model.k0 lr 0.09120108393559098
# create_optimizer_or_freeze_model: param bg_model.rgbnet lr 0.0009120108393559097
# scene_rep_reconstruction (fine): iter   1000 / Loss: 0.003547264 / PSNR: 22.23 / Eps: 00:00:13
#   6%|██▏                                  | 1490/25000 [00:16<02:55, 133.68it/s]VolRepr-fg: sharpness 94.95
# VolRepr-fg: occupancy mask activated ratio 0.3319 => 0.2230
# VolRepr-bg: occupancy mask activated ratio 1.0000 => 1.0000
# scene_rep_reconstruction (fine): iter   1500 / Loss: 0.002149832 / PSNR: 21.42 / Eps: 00:00:17
#   8%|██▉                                  | 1999/25000 [00:20<02:29, 153.69it/s]VolRepr-fg: scale_volume_grid start
# VolRepr-fg: voxel_size       tensor(0.0202)
# VolRepr-fg: world_size       tensor([59, 59, 59])
# VolRepr-fg: world_size_k0    tensor([59, 59, 59])
# VolRepr-fg: voxel_size_base  tensor(0.0075)
# VolRepr-fg: voxel_size_ratio tensor(2.6878)
# VolRepr-fg: scale_volume_grid scale world_size from [47, 47, 47] to [59, 59, 59]
# VolRepr-fg: scale_volume_grid finish
# VolRepr-bg: scale_volume_grid start
# VolRepr-bg: voxel_size       tensor(0.3225)
# VolRepr-bg: world_size       tensor([59, 59, 59])
# VolRepr-bg: world_size_k0    tensor([59, 59, 59])
# VolRepr-bg: voxel_size_base  tensor(0.1200)
# VolRepr-bg: voxel_size_ratio tensor(2.6878)
# VolRepr-bg: scale_volume_grid scale world_size from [47, 47, 47] to [59, 59, 59]
# VolRepr-bg: scale_volume_grid finish
# create_optimizer_or_freeze_model: param density lr 0.0020754929127568098
# create_optimizer_or_freeze_model: param k0 lr 0.0831763771102671
# create_optimizer_or_freeze_model: param sdf_scale freeze
# create_optimizer_or_freeze_model: param rgbnet lr 0.000831763771102671
# create_optimizer_or_freeze_model: param bg_model.density lr 0.0831763771102671
# create_optimizer_or_freeze_model: param bg_model.k0 lr 0.0831763771102671
# create_optimizer_or_freeze_model: param bg_model.rgbnet lr 0.000831763771102671
# scene_rep_reconstruction (fine): iter   2000 / Loss: 0.003347334 / PSNR: 23.03 / Eps: 00:00:20
#  10%|███▋                                 | 2493/25000 [00:24<02:48, 133.48it/s]VolRepr-fg: sharpness 144.95
# VolRepr-fg: occupancy mask activated ratio 0.1635 => 0.1348
# VolRepr-bg: occupancy mask activated ratio 1.0000 => 1.0000
# scene_rep_reconstruction (fine): iter   2500 / Loss: 0.001482583 / PSNR: 22.97 / Eps: 00:00:24
#  12%|████▍                                | 2996/25000 [00:27<02:29, 147.22it/s]VolRepr-fg: scale_volume_grid start
# VolRepr-fg: voxel_size       tensor(0.0160)
# VolRepr-fg: world_size       tensor([75, 75, 75])
# VolRepr-fg: world_size_k0    tensor([75, 75, 75])
# VolRepr-fg: voxel_size_base  tensor(0.0075)
# VolRepr-fg: voxel_size_ratio tensor(2.1333)
# VolRepr-fg: scale_volume_grid scale world_size from [59, 59, 59] to [75, 75, 75]
# VolRepr-fg: scale_volume_grid finish
# VolRepr-bg: scale_volume_grid start
# VolRepr-bg: voxel_size       tensor(0.2560)
# VolRepr-bg: world_size       tensor([75, 75, 75])
# VolRepr-bg: world_size_k0    tensor([75, 75, 75])
# VolRepr-bg: voxel_size_base  tensor(0.1200)
# VolRepr-bg: voxel_size_ratio tensor(2.1333)
# VolRepr-bg: scale_volume_grid scale world_size from [59, 59, 59] to [75, 75, 75]
# VolRepr-bg: scale_volume_grid finish
# create_optimizer_or_freeze_model: param density lr 0.001726319812011471
# create_optimizer_or_freeze_model: param k0 lr 0.07585775750291839
# create_optimizer_or_freeze_model: param sdf_scale freeze
# create_optimizer_or_freeze_model: param rgbnet lr 0.0007585775750291837
# create_optimizer_or_freeze_model: param bg_model.density lr 0.07585775750291839
# create_optimizer_or_freeze_model: param bg_model.k0 lr 0.07585775750291839
# create_optimizer_or_freeze_model: param bg_model.rgbnet lr 0.0007585775750291837
# scene_rep_reconstruction (fine): iter   3000 / Loss: 0.002569610 / PSNR: 24.40 / Eps: 00:00:28
#  14%|█████▏                               | 3487/25000 [00:31<02:53, 124.14it/s]VolRepr-fg: sharpness 194.96
# VolRepr-fg: occupancy mask activated ratio 0.1114 => 0.0992
# VolRepr-bg: occupancy mask activated ratio 0.4476 => 0.4476
# scene_rep_reconstruction (fine): iter   3500 / Loss: 0.001208537 / PSNR: 24.13 / Eps: 00:00:32
#  16%|█████▉                               | 3994/25000 [00:35<02:45, 127.31it/s]VolRepr-fg: scale_volume_grid start
# VolRepr-fg: voxel_size       tensor(0.0127)
# VolRepr-fg: world_size       tensor([94, 94, 94])
# VolRepr-fg: world_size_k0    tensor([94, 94, 94])
# VolRepr-fg: voxel_size_base  tensor(0.0075)
# VolRepr-fg: voxel_size_ratio tensor(1.6932)
# VolRepr-fg: scale_volume_grid scale world_size from [75, 75, 75] to [94, 94, 94]
# VolRepr-fg: scale_volume_grid finish
# VolRepr-bg: scale_volume_grid start
# VolRepr-bg: voxel_size       tensor(0.2032)
# VolRepr-bg: world_size       tensor([94, 94, 94])
# VolRepr-bg: world_size_k0    tensor([94, 94, 94])
# VolRepr-bg: voxel_size_base  tensor(0.1200)
# VolRepr-bg: voxel_size_ratio tensor(1.6932)
# VolRepr-bg: scale_volume_grid scale world_size from [75, 75, 75] to [94, 94, 94]
# VolRepr-bg: scale_volume_grid finish
# create_optimizer_or_freeze_model: param density lr 0.001435890276967915
# create_optimizer_or_freeze_model: param k0 lr 0.06918309709189366
# create_optimizer_or_freeze_model: param sdf_scale freeze
# create_optimizer_or_freeze_model: param rgbnet lr 0.0006918309709189366
# create_optimizer_or_freeze_model: param bg_model.density lr 0.06918309709189366
# create_optimizer_or_freeze_model: param bg_model.k0 lr 0.06918309709189366
# create_optimizer_or_freeze_model: param bg_model.rgbnet lr 0.0006918309709189366
# scene_rep_reconstruction (fine): iter   4000 / Loss: 0.001937456 / PSNR: 25.48 / Eps: 00:00:36
#  18%|██████▋                              | 4493/25000 [00:40<03:18, 103.10it/s]VolRepr-fg: sharpness 244.96
# VolRepr-fg: occupancy mask activated ratio 0.0869 => 0.0804
# VolRepr-bg: occupancy mask activated ratio 0.4084 => 0.4084
# scene_rep_reconstruction (fine): iter   4500 / Loss: 0.001016785 / PSNR: 25.06 / Eps: 00:00:41
#  20%|███████▍                             | 4989/25000 [00:45<03:03, 108.76it/s]VolRepr-fg: scale_volume_grid start
# VolRepr-fg: voxel_size       tensor(0.0101)
# VolRepr-fg: world_size       tensor([119, 119, 119])
# VolRepr-fg: world_size_k0    tensor([119, 119, 119])
# VolRepr-fg: voxel_size_base  tensor(0.0075)
# VolRepr-fg: voxel_size_ratio tensor(1.3439)
# VolRepr-fg: scale_volume_grid scale world_size from [94, 94, 94] to [119, 119, 119]
# VolRepr-fg: scale_volume_grid finish
# VolRepr-bg: scale_volume_grid start
# VolRepr-bg: voxel_size       tensor(0.1613)
# VolRepr-bg: world_size       tensor([119, 119, 119])
# VolRepr-bg: world_size_k0    tensor([119, 119, 119])
# VolRepr-bg: voxel_size_base  tensor(0.1200)
# VolRepr-bg: voxel_size_ratio tensor(1.3439)
# VolRepr-bg: scale_volume_grid scale world_size from [94, 94, 94] to [119, 119, 119]
# VolRepr-bg: scale_volume_grid finish
# create_optimizer_or_freeze_model: param density lr 0.001194321511660492
# create_optimizer_or_freeze_model: param k0 lr 0.06309573444801933
# create_optimizer_or_freeze_model: param sdf_scale freeze
# create_optimizer_or_freeze_model: param rgbnet lr 0.0006309573444801933
# create_optimizer_or_freeze_model: param bg_model.density lr 0.06309573444801933
# create_optimizer_or_freeze_model: param bg_model.k0 lr 0.06309573444801933
# create_optimizer_or_freeze_model: param bg_model.rgbnet lr 0.0006309573444801933
# scene_rep_reconstruction (fine): iter   5000 / Loss: 0.001701582 / PSNR: 26.32 / Eps: 00:00:46
#  22%|████████▎                             | 5491/25000 [00:51<03:45, 86.39it/s]VolRepr-fg: sharpness 294.95
# VolRepr-fg: occupancy mask activated ratio 0.0726 => 0.0686
# VolRepr-bg: occupancy mask activated ratio 0.3810 => 0.3809
# scene_rep_reconstruction (fine): iter   5500 / Loss: 0.000888322 / PSNR: 25.90 / Eps: 00:00:51
#  24%|█████████                             | 5996/25000 [00:57<03:33, 88.91it/s]VolRepr-fg: scale_volume_grid start
# VolRepr-fg: voxel_size       tensor(0.0080)
# VolRepr-fg: world_size       tensor([150, 150, 150])
# VolRepr-fg: world_size_k0    tensor([150, 150, 150])
# VolRepr-fg: voxel_size_base  tensor(0.0075)
# VolRepr-fg: voxel_size_ratio tensor(1.0667)
# VolRepr-fg: scale_volume_grid scale world_size from [119, 119, 119] to [150, 150, 150]
# VolRepr-fg: scale_volume_grid finish
# VolRepr-bg: scale_volume_grid start
# VolRepr-bg: voxel_size       tensor(0.1280)
# VolRepr-bg: world_size       tensor([150, 150, 150])
# VolRepr-bg: world_size_k0    tensor([150, 150, 150])
# VolRepr-bg: voxel_size_base  tensor(0.1200)
# VolRepr-bg: voxel_size_ratio tensor(1.0667)
# VolRepr-bg: scale_volume_grid scale world_size from [119, 119, 119] to [150, 150, 150]
# VolRepr-bg: scale_volume_grid finish
# create_optimizer_or_freeze_model: param density lr 0.0009933933644477734
# create_optimizer_or_freeze_model: param k0 lr 0.057543993733715694
# create_optimizer_or_freeze_model: param sdf_scale freeze
# create_optimizer_or_freeze_model: param rgbnet lr 0.000575439937337157
# create_optimizer_or_freeze_model: param bg_model.density lr 0.057543993733715694
# create_optimizer_or_freeze_model: param bg_model.k0 lr 0.057543993733715694
# create_optimizer_or_freeze_model: param bg_model.rgbnet lr 0.000575439937337157
# scene_rep_reconstruction (fine): iter   6000 / Loss: 0.001356984 / PSNR: 27.03 / Eps: 00:00:57
#  26%|█████████▊                            | 6494/25000 [01:04<04:25, 69.68it/s]VolRepr-fg: sharpness 344.94
# VolRepr-fg: occupancy mask activated ratio 0.0633 => 0.0606
# VolRepr-bg: occupancy mask activated ratio 0.3591 => 0.3590
# scene_rep_reconstruction (fine): iter   6500 / Loss: 0.000826272 / PSNR: 26.78 / Eps: 00:01:05
#  28%|██████████▋                           | 6992/25000 [01:11<04:18, 69.68it/s]VolRepr-fg: scale_volume_grid start
# VolRepr-fg: voxel_size       tensor(0.0063)
# VolRepr-fg: world_size       tensor([188, 188, 188])
# VolRepr-fg: world_size_k0    tensor([188, 188, 188])
# VolRepr-fg: voxel_size_base  tensor(0.0075)
# VolRepr-fg: voxel_size_ratio tensor(0.8466)
# VolRepr-fg: scale_volume_grid scale world_size from [150, 150, 150] to [188, 188, 188]
# VolRepr-fg: scale_volume_grid finish
# VolRepr-bg: scale_volume_grid start
# VolRepr-bg: voxel_size       tensor(0.1200)
# VolRepr-bg: world_size       tensor([160, 160, 160])
# VolRepr-bg: world_size_k0    tensor([160, 160, 160])
# VolRepr-bg: voxel_size_base  tensor(0.1200)
# VolRepr-bg: voxel_size_ratio tensor(1.)
# VolRepr-bg: scale_volume_grid scale world_size from [150, 150, 150] to [160, 160, 160]
# VolRepr-bg: scale_volume_grid finish
# create_optimizer_or_freeze_model: param density lr 0.0008262686110014499
# create_optimizer_or_freeze_model: param k0 lr 0.05248074602497726
# create_optimizer_or_freeze_model: param sdf_scale freeze
# create_optimizer_or_freeze_model: param rgbnet lr 0.0005248074602497725
# create_optimizer_or_freeze_model: param bg_model.density lr 0.05248074602497726
# create_optimizer_or_freeze_model: param bg_model.k0 lr 0.05248074602497726
# create_optimizer_or_freeze_model: param bg_model.rgbnet lr 0.0005248074602497725
# scene_rep_reconstruction (fine): iter   7000 / Loss: 0.001301778 / PSNR: 27.71 / Eps: 00:01:12
#  30%|███████████▍                          | 7494/25000 [01:20<04:49, 60.43it/s]VolRepr-fg: sharpness 394.93
# VolRepr-fg: occupancy mask activated ratio 0.0568 => 0.0549
# VolRepr-bg: occupancy mask activated ratio 0.3439 => 0.3439
# scene_rep_reconstruction (fine): iter   7500 / Loss: 0.000719655 / PSNR: 27.14 / Eps: 00:01:20
#  32%|████████████▏                         | 7998/25000 [01:28<04:31, 62.63it/s]VolRepr-fg: scale_volume_grid start
# VolRepr-fg: voxel_size       tensor(0.0050)
# VolRepr-fg: world_size       tensor([238, 238, 238])
# VolRepr-fg: world_size_k0    tensor([238, 238, 238])
# VolRepr-fg: voxel_size_base  tensor(0.0075)
# VolRepr-fg: voxel_size_ratio tensor(0.6720)
# VolRepr-fg: scale_volume_grid scale world_size from [188, 188, 188] to [238, 238, 238]
# VolRepr-fg: scale_volume_grid finish
# create_optimizer_or_freeze_model: param density lr 0.0006872602958303319
# create_optimizer_or_freeze_model: param k0 lr 0.04786300923226384
# create_optimizer_or_freeze_model: param sdf_scale freeze
# create_optimizer_or_freeze_model: param rgbnet lr 0.0004786300923226384
# create_optimizer_or_freeze_model: param bg_model.density lr 0.04786300923226384
# create_optimizer_or_freeze_model: param bg_model.k0 lr 0.04786300923226384
# create_optimizer_or_freeze_model: param bg_model.rgbnet lr 0.0004786300923226384
# scene_rep_reconstruction (fine): iter   8000 / Loss: 0.000699344 / PSNR: 28.05 / Eps: 00:01:28
#  34%|████████████▉                         | 8497/25000 [01:36<04:41, 58.66it/s]VolRepr-fg: sharpness 444.91
# VolRepr-fg: occupancy mask activated ratio 0.0521 => 0.0507
# VolRepr-bg: occupancy mask activated ratio 0.3439 => 0.3335
# scene_rep_reconstruction (fine): iter   8500 / Loss: 0.000686243 / PSNR: 28.43 / Eps: 00:01:37
#  36%|█████████████▋                        | 8995/25000 [01:45<04:26, 59.98it/s]VolRepr-fg: scale_volume_grid start
# VolRepr-fg: voxel_size       tensor(0.0040)
# VolRepr-fg: world_size       tensor([300, 300, 300])
# VolRepr-fg: world_size_k0    tensor([300, 300, 300])
# VolRepr-fg: voxel_size_base  tensor(0.0075)
# VolRepr-fg: voxel_size_ratio tensor(0.5333)
# VolRepr-fg: scale_volume_grid scale world_size from [238, 238, 238] to [300, 300, 300]
# VolRepr-fg: scale_volume_grid finish
# create_optimizer_or_freeze_model: param density lr 0.0005716382153889742
# create_optimizer_or_freeze_model: param k0 lr 0.043651583224016605
# create_optimizer_or_freeze_model: param sdf_scale freeze
# create_optimizer_or_freeze_model: param rgbnet lr 0.000436515832240166
# create_optimizer_or_freeze_model: param bg_model.density lr 0.043651583224016605
# create_optimizer_or_freeze_model: param bg_model.k0 lr 0.043651583224016605
# create_optimizer_or_freeze_model: param bg_model.rgbnet lr 0.000436515832240166
# scene_rep_reconstruction (fine): iter   9000 / Loss: 0.000698858 / PSNR: 28.61 / Eps: 00:01:45
#  38%|██████████████▍                       | 9499/25000 [01:54<04:49, 53.50it/s]VolRepr-fg: sharpness 494.90
# VolRepr-fg: occupancy mask activated ratio 0.0507 => 0.0483
# VolRepr-bg: occupancy mask activated ratio 0.3335 => 0.3279
# scene_rep_reconstruction (fine): iter   9500 / Loss: 0.000654424 / PSNR: 28.86 / Eps: 00:01:55
# scene_rep_reconstruction (fine): iter  10000 / Loss: 0.000696317 / PSNR: 28.98 / Eps: 00:02:04
#  42%|███████████████▌                     | 10495/25000 [02:13<04:25, 54.64it/s]VolRepr-fg: sharpness 544.89
# VolRepr-fg: occupancy mask activated ratio 0.0483 => 0.0464
# VolRepr-bg: occupancy mask activated ratio 0.3279 => 0.3278
# scene_rep_reconstruction (fine): iter  10500 / Loss: 0.000661318 / PSNR: 29.10 / Eps: 00:02:14
# scene_rep_reconstruction (fine): iter  11000 / Loss: 0.000623258 / PSNR: 29.23 / Eps: 00:02:23
#  46%|█████████████████                    | 11497/25000 [02:31<04:05, 54.90it/s]VolRepr-fg: sharpness 594.88
# VolRepr-fg: occupancy mask activated ratio 0.0464 => 0.0449
# VolRepr-bg: occupancy mask activated ratio 0.3278 => 0.3277
# scene_rep_reconstruction (fine): iter  11500 / Loss: 0.000648258 / PSNR: 29.36 / Eps: 00:02:32
# scene_rep_reconstruction (fine): iter  12000 / Loss: 0.000679158 / PSNR: 29.45 / Eps: 00:02:41
#  50%|██████████████████▍                  | 12499/25000 [02:50<03:49, 54.56it/s]VolRepr-fg: sharpness 644.87
# VolRepr-fg: occupancy mask activated ratio 0.0449 => 0.0437
# VolRepr-bg: occupancy mask activated ratio 0.3277 => 0.3277
# scene_rep_reconstruction (fine): iter  12500 / Loss: 0.000611397 / PSNR: 29.52 / Eps: 00:02:50
# scene_rep_reconstruction (fine): iter  13000 / Loss: 0.000622908 / PSNR: 29.61 / Eps: 00:02:59
#  54%|███████████████████▉                 | 13495/25000 [03:08<03:25, 56.08it/s]VolRepr-fg: sharpness 694.85
# VolRepr-fg: occupancy mask activated ratio 0.0437 => 0.0426
# VolRepr-bg: occupancy mask activated ratio 0.3277 => 0.3276
# scene_rep_reconstruction (fine): iter  13500 / Loss: 0.000592470 / PSNR: 29.70 / Eps: 00:03:08
# scene_rep_reconstruction (fine): iter  14000 / Loss: 0.000616719 / PSNR: 29.78 / Eps: 00:03:17
#  58%|█████████████████████▍               | 14497/25000 [03:25<03:08, 55.64it/s]VolRepr-fg: sharpness 744.84
# VolRepr-fg: occupancy mask activated ratio 0.0426 => 0.0417
# VolRepr-bg: occupancy mask activated ratio 0.3276 => 0.3276
# scene_rep_reconstruction (fine): iter  14500 / Loss: 0.000645985 / PSNR: 29.84 / Eps: 00:03:26
# scene_rep_reconstruction (fine): iter  15000 / Loss: 0.000611124 / PSNR: 29.90 / Eps: 00:03:35
#  62%|██████████████████████▉              | 15499/25000 [03:43<02:46, 57.10it/s]VolRepr-fg: sharpness 794.83
# VolRepr-fg: occupancy mask activated ratio 0.0417 => 0.0409
# VolRepr-bg: occupancy mask activated ratio 0.3276 => 0.3275
# scene_rep_reconstruction (fine): iter  15500 / Loss: 0.000621125 / PSNR: 29.96 / Eps: 00:03:44
# scene_rep_reconstruction (fine): iter  16000 / Loss: 0.000576823 / PSNR: 30.00 / Eps: 00:03:53
#  66%|████████████████████████▍            | 16495/25000 [04:01<02:26, 58.01it/s]VolRepr-fg: sharpness 844.82
# VolRepr-fg: occupancy mask activated ratio 0.0409 => 0.0402
# VolRepr-bg: occupancy mask activated ratio 0.3275 => 0.3275
# scene_rep_reconstruction (fine): iter  16500 / Loss: 0.000640046 / PSNR: 30.05 / Eps: 00:04:01
# scene_rep_reconstruction (fine): iter  17000 / Loss: 0.000594391 / PSNR: 30.11 / Eps: 00:04:10
#  70%|█████████████████████████▉           | 17497/25000 [04:18<02:09, 57.92it/s]VolRepr-fg: sharpness 894.81
# VolRepr-fg: occupancy mask activated ratio 0.0402 => 0.0396
# VolRepr-bg: occupancy mask activated ratio 0.3275 => 0.3275
# scene_rep_reconstruction (fine): iter  17500 / Loss: 0.000557273 / PSNR: 30.12 / Eps: 00:04:19
# scene_rep_reconstruction (fine): iter  18000 / Loss: 0.000576510 / PSNR: 30.19 / Eps: 00:04:27
#  74%|███████████████████████████▍         | 18499/25000 [04:35<01:50, 58.76it/s]VolRepr-fg: sharpness 944.79
# VolRepr-fg: occupancy mask activated ratio 0.0396 => 0.0391
# VolRepr-bg: occupancy mask activated ratio 0.3275 => 0.3274
# scene_rep_reconstruction (fine): iter  18500 / Loss: 0.000587465 / PSNR: 30.22 / Eps: 00:04:36
# scene_rep_reconstruction (fine): iter  19000 / Loss: 0.000626350 / PSNR: 30.23 / Eps: 00:04:45
#  78%|████████████████████████████▊        | 19495/25000 [04:53<01:34, 58.43it/s]VolRepr-fg: sharpness 994.78
# VolRepr-fg: occupancy mask activated ratio 0.0391 => 0.0386
# VolRepr-bg: occupancy mask activated ratio 0.3274 => 0.3274
# scene_rep_reconstruction (fine): iter  19500 / Loss: 0.000575264 / PSNR: 30.30 / Eps: 00:04:53
# scene_rep_reconstruction (fine): iter  20000 / Loss: 0.000590233 / PSNR: 30.30 / Eps: 00:05:02
#  82%|██████████████████████████████▎      | 20497/25000 [05:10<01:16, 58.65it/s]VolRepr-fg: sharpness 1000.00
# VolRepr-fg: occupancy mask activated ratio 0.0386 => 0.0386
# VolRepr-bg: occupancy mask activated ratio 0.3274 => 0.3274
# scene_rep_reconstruction (fine): iter  20500 / Loss: 0.000600741 / PSNR: 30.36 / Eps: 00:05:10
# scene_rep_reconstruction (fine): iter  21000 / Loss: 0.000576033 / PSNR: 30.36 / Eps: 00:05:19
#  86%|███████████████████████████████▊     | 21499/25000 [05:27<00:59, 59.08it/s]VolRepr-fg: sharpness 1000.00
# VolRepr-fg: occupancy mask activated ratio 0.0386 => 0.0386
# VolRepr-bg: occupancy mask activated ratio 0.3274 => 0.3274
# scene_rep_reconstruction (fine): iter  21500 / Loss: 0.000622670 / PSNR: 30.42 / Eps: 00:05:27
# scene_rep_reconstruction (fine): iter  22000 / Loss: 0.000577673 / PSNR: 30.41 / Eps: 00:05:36
#  90%|█████████████████████████████████▎   | 22495/25000 [05:44<00:42, 59.21it/s]VolRepr-fg: sharpness 1000.00
# VolRepr-fg: occupancy mask activated ratio 0.0386 => 0.0386
# VolRepr-bg: occupancy mask activated ratio 0.3274 => 0.3274
# scene_rep_reconstruction (fine): iter  22500 / Loss: 0.000547783 / PSNR: 30.45 / Eps: 00:05:45
# scene_rep_reconstruction (fine): iter  23000 / Loss: 0.000549228 / PSNR: 30.48 / Eps: 00:05:53
#  94%|██████████████████████████████████▊  | 23497/25000 [06:01<00:25, 59.33it/s]VolRepr-fg: sharpness 1000.00
# VolRepr-fg: occupancy mask activated ratio 0.0386 => 0.0386
# VolRepr-bg: occupancy mask activated ratio 0.3274 => 0.3274
# scene_rep_reconstruction (fine): iter  23500 / Loss: 0.000560236 / PSNR: 30.50 / Eps: 00:06:02
# scene_rep_reconstruction (fine): iter  24000 / Loss: 0.000555373 / PSNR: 30.52 / Eps: 00:06:10
#  98%|████████████████████████████████████▎| 24499/25000 [06:18<00:08, 58.17it/s]VolRepr-fg: sharpness 1000.00
# VolRepr-fg: occupancy mask activated ratio 0.0386 => 0.0386
# VolRepr-bg: occupancy mask activated ratio 0.3274 => 0.3273
# scene_rep_reconstruction (fine): iter  24500 / Loss: 0.000589075 / PSNR: 30.51 / Eps: 00:06:19
# scene_rep_reconstruction (fine): iter  25000 / Loss: 0.000571479 / PSNR: 30.55 / Eps: 00:06:27
# 100%|█████████████████████████████████████| 25000/25000 [06:27<00:00, 64.56it/s]
# scene_rep_reconstruction (fine): saving checkpoints...
# scene_rep_reconstruction (fine): saved checkpoints at results/stanford_orb/teapot_scene001/neural_surface_recon/fine_last.pth
# train: fine detail reconstruction in 00:06:30
# train: finish (eps time 00:06:30 )
# /home/ahc/Documents/metrology_ir/DigitalTwinCatalog/neural_pbir/neural_surface_recon/lib/utils.py:187: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(path, *args, **kwargs)
# VolRepr-fg: voxel_size       tensor(0.0040)
# VolRepr-fg: world_size       tensor([300, 300, 300])
# VolRepr-fg: world_size_k0    tensor([300, 300, 300])
# VolRepr-fg: voxel_size_base  tensor(0.0075)
# VolRepr-fg: voxel_size_ratio tensor(0.5333)
# VolRepr-fg: geometry grid DenseGrid(channels=1, world_size=[300, 300, 300])
# VolRepr-fg: feature voxel grid DenseGrid(channels=12, world_size=[300, 300, 300])
# VolRepr-fg: mlp MLP_torch(
#   (mlp): Sequential(
#     (0): Linear(in_features=39, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Sequential(
#       (0): Linear(in_features=128, out_features=128, bias=True)
#       (1): ReLU(inplace=True)
#     )
#     (3): Linear(in_features=128, out_features=3, bias=True)
#   )
# )
# VolRepr-bg: set density bias shift to tensor([-4.5951], device='cpu')
# VolRepr-bg: voxel_size       tensor(0.1200)
# VolRepr-bg: world_size       tensor([160, 160, 160])
# VolRepr-bg: world_size_k0    tensor([160, 160, 160])
# VolRepr-bg: voxel_size_base  tensor(0.1200)
# VolRepr-bg: voxel_size_ratio tensor(1.)
# VolRepr-bg: geometry grid DenseGrid(channels=1, world_size=[160, 160, 160])
# VolRepr-bg: feature voxel grid DenseGrid(channels=8, world_size=[160, 160, 160])
# VolRepr-bg: mlp MLP_tcnn(
#   (mlp): Network(n_input_dims=35, n_output_dims=3, seed=1337, dtype=torch.float16, hyperparams={'encoding': {'offset': 0.0, 'otype': 'Identity', 'scale': 1.0}, 'network': {'activation': 'ReLU', 'n_hidden_layers': 2, 'n_neurons': 64, 'otype': 'FullyFusedMLP', 'output_activation': 'None'}, 'otype': 'NetworkWithInputEncoding'})
# )
# All results are dumped into results/stanford_orb/teapot_scene001/neural_surface_recon/render_video_fine_last
#   0%|                                                   | 0/120 [00:00<?, ?it/s]Testing (512, 512, 3)
# 100%|█████████████████████████████████████████| 120/120 [00:01<00:00, 89.91it/s]
# ==================================================
# Extracting mesh
# Removed 25 isolated connected components.
# Dumping mesh
# Remeshing...
# The mesh is dumped into results/stanford_orb/teapot_scene001/neural_surface_recon/mesh.obj
# Using blender to uv unwrap for results/stanford_orb/teapot_scene001/neural_surface_recon/mesh.obj
# Blender 3.6.21 (hash e7f18247b228 built 2025-02-18 08:11:48)
# Failed to open dir (No such file or directory): /run/user/1000/gvfs/
# (  0.0000 sec |   0.0000 sec) Importing OBJ 'results/stanford_orb/teapot_scene001/neural_surface_recon/mesh.obj'...
#   (  0.0000 sec |   0.0000 sec) Parsing OBJ file...
#     (  1.7217 sec |   1.7216 sec) Done, loading materials and images...
#     (  1.7244 sec |   1.7243 sec) Done, building geometries (verts:283169 faces:566438 materials: 1 smoothgroups:0) ...
#     (  2.4807 sec |   2.4806 sec) Done.
#   (  2.4807 sec |   2.4807 sec) Finished importing: 'results/stanford_orb/teapot_scene001/neural_surface_recon/mesh.obj'
# Progress: 100.00%
#
# UV mapping using Blender
#     (  0.0410 sec |   0.0000 sec) OBJ Export path: 'results/stanford_orb/teapot_scene001/neural_surface_recon/mesh.obj'
#           (  3.4862 sec |   3.4431 sec) Finished writing geometry of 'mesh'.
#       (  3.5038 sec |   3.4628 sec) Finished exporting geometry, now exporting materials
#       (  3.5039 sec |   3.4628 sec) OBJ Export Finished
# Progress: 100.00%
#
#
# Blender quit
# The uv mesh is dumped into results/stanford_orb/teapot_scene001/neural_surface_recon/mesh.obj
# ==================================================
# The bg 360 image is dumped into results/stanford_orb/teapot_scene001/neural_surface_recon/bg360.png
# /home/ahc/Documents/metrology_ir/DigitalTwinCatalog/neural_pbir/neural_surface_recon/lib/utils.py:187: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(path, *args, **kwargs)
# The cam2world matrices are dumped into results/stanford_orb/teapot_scene001/neural_surface_recon/to_worlds_after.txt
# Done
# /home/ahc/miniconda3/envs/metrology_ir/lib/python3.11/site-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# /home/ahc/miniconda3/envs/metrology_ir/lib/python3.11/site-packages/torch/__init__.py:955: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:432.)
#   _C._set_default_tensor_type(t)
# ==> Load checkpoint
# /home/ahc/Documents/metrology_ir/./DigitalTwinCatalog/neural_pbir/neural_distillation/run.py:92: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(
# VolRepr-fg: voxel_size       tensor(0.0040)
# VolRepr-fg: world_size       tensor([300, 300, 300])
# VolRepr-fg: world_size_k0    tensor([300, 300, 300])
# VolRepr-fg: voxel_size_base  tensor(0.0075)
# VolRepr-fg: voxel_size_ratio tensor(0.5333)
# VolRepr-fg: geometry grid DenseGrid(channels=1, world_size=[300, 300, 300])
# VolRepr-fg: feature voxel grid DenseGrid(channels=12, world_size=[300, 300, 300])
# VolRepr-fg: mlp MLP_torch(
#   (mlp): Sequential(
#     (0): Linear(in_features=39, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Sequential(
#       (0): Linear(in_features=128, out_features=128, bias=True)
#       (1): ReLU(inplace=True)
#     )
#     (3): Linear(in_features=128, out_features=3, bias=True)
#   )
# )
# VolRepr-bg: set density bias shift to tensor([-4.5951], device='cpu')
# VolRepr-bg: voxel_size       tensor(0.1200)
# VolRepr-bg: world_size       tensor([160, 160, 160])
# VolRepr-bg: world_size_k0    tensor([160, 160, 160])
# VolRepr-bg: voxel_size_base  tensor(0.1200)
# VolRepr-bg: voxel_size_ratio tensor(1.)
# VolRepr-bg: geometry grid DenseGrid(channels=1, world_size=[160, 160, 160])
# VolRepr-bg: feature voxel grid DenseGrid(channels=8, world_size=[160, 160, 160])
# VolRepr-bg: mlp MLP_tcnn(
#   (mlp): Network(n_input_dims=35, n_output_dims=3, seed=1337, dtype=torch.float16, hyperparams={'encoding': {'offset': 0.0, 'otype': 'Identity', 'scale': 1.0}, 'network': {'activation': 'ReLU', 'n_hidden_layers': 2, 'n_neurons': 64, 'otype': 'FullyFusedMLP', 'output_activation': 'None'}, 'otype': 'NetworkWithInputEncoding'})
# )
# ==> Compute avg bg observation
# Start loading dataset...
# 100%|██████████████████████████████████████████| 70/70 [00:00<00:00, 281.48it/s]
# Finish loading dataset in 0.8 sec.
# Loaded dataset: (70, 512, 512, 3) /home/ahc/Datasets/Stanford-ORB/blender_HDR/teapot_scene001
# # train: 60
# # test: 10 [60 61 62 63 64 65 66 67 68 69]
# get_training_rays_offline_sampler: start
# get_training_rays_offline_sampler: ratio tensor(1.)
# get_training_rays_offline_sampler: finish (eps time: 0.1500706672668457 sec)
# 100%|████████████████████████████████████████| 241/241 [00:00<00:00, 297.50it/s]
# ==> Load mesh
# ====> # verts:     375468
# ====> # faces:     566438
# ====> # texel to optimize:     471964
# ==> Create material field / envmap sg / optimizer
# 100%|███████████████████████████████████████████| 58/58 [00:00<00:00, 84.09it/s]
# ==> Pre-compute visibility and indirect illumination
# 100%|████████████████████████████████████████| 256/256 [00:00<00:00, 274.75it/s]
# ==> Split texels into 24 chunks to save gpu mem
# ==> Start training
#   0%|                                                  | 0/1000 [00:00<?, ?it/s]==> iter=    0: psnr=13.9
#  10%|████                                    | 100/1000 [00:14<02:13,  6.73it/s]==> iter=  100: psnr=16.7
#  20%|████████                                | 200/1000 [00:29<01:58,  6.73it/s]==> iter=  200: psnr=18.8
#  30%|████████████                            | 300/1000 [00:44<01:44,  6.72it/s]==> iter=  300: psnr=19.0
#  40%|████████████████                        | 400/1000 [00:59<01:29,  6.72it/s]==> iter=  400: psnr=19.2
#  50%|████████████████████                    | 500/1000 [01:14<01:14,  6.72it/s]==> iter=  500: psnr=19.3
#  60%|████████████████████████                | 600/1000 [01:29<00:59,  6.72it/s]==> iter=  600: psnr=19.3
#  70%|████████████████████████████            | 700/1000 [01:44<00:44,  6.72it/s]==> iter=  700: psnr=19.4
#  80%|████████████████████████████████        | 800/1000 [01:58<00:29,  6.72it/s]==> iter=  800: psnr=19.4
#  90%|████████████████████████████████████    | 900/1000 [02:13<00:14,  6.72it/s]==> iter=  900: psnr=19.5
# 100%|███████████████████████████████████████▉| 999/1000 [02:28<00:00,  6.72it/s]==> iter=  999: psnr=19.5
# 100%|███████████████████████████████████████| 1000/1000 [02:28<00:00,  6.72it/s]
# ==> Post-processing
# ==> Save to results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/neural_distillation/
# /home/ahc/miniconda3/envs/metrology_ir/lib/python3.11/site-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# Running stage microfacet_naive-envmap_sg...
# /home/ahc/miniconda3/envs/metrology_ir/lib/python3.11/site-packages/gin/config.py:615: FutureWarning: `NLLLoss2d` has been deprecated. Please use `NLLLoss` instead as a drop-in replacement and see https://pytorch.org/docs/main/nn.html#torch.nn.NLLLoss for more details.
#   decorated_class = decorating_meta(cls.__name__, (cls,), overrides)
# Envmap2SG step: 1, loss: 1.4550851583480835
# Envmap2SG step: 100, loss: 0.002212101360782981
# Starting the optimization...
# 100%|█████████████████████████████████████████| 500/500 [01:37<00:00,  5.12it/s]
# Writing final outputs...
# Done.
# Running stage microfacet_basis-envmap_ls...
# Initializing using NMF...
# Done.
# Starting the optimization...
# 100%|█████████████████████████████████████████| 500/500 [01:49<00:00,  4.59it/s]
# Writing final outputs...
# Done.
# Final results are written to results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir
# /home/ahc/miniconda3/envs/metrology_ir/lib/python3.11/site-packages/pytorch3d/io/obj_io.py:547: UserWarning: No mtl file provided
#   warnings.warn("No mtl file provided")
# 100%|███████████████████████████████████████████| 10/10 [00:00<00:00, 10.45it/s]
# Save to results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/envmap_for_blender.exr
# Blender 3.6.21 (hash e7f18247b228 built 2025-02-18 08:11:48)
# Failed to open dir (No such file or directory): /run/user/1000/gvfs/
# Read blend: "/home/ahc/Documents/metrology_ir/DigitalTwinCatalog/neural_pbir/scripts/relit/relit.blend"
# Results are dumped to /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit
# Set fov: 20.327493328509615 deg
# Loading mesh: /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/mesh.obj
# (  0.0000 sec |   0.0000 sec) Importing OBJ '/home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/mesh.obj'...
#   (  0.0000 sec |   0.0000 sec) Parsing OBJ file...
#     (  2.5002 sec |   2.5001 sec) Done, loading materials and images...
#     (  2.5028 sec |   2.5027 sec) Done, building geometries (verts:283169 faces:566438 materials: 1 smoothgroups:0) ...
#     (  3.4914 sec |   3.4913 sec) Done.
#   (  3.4915 sec |   3.4915 sec) Finished importing: '/home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/mesh.obj'
# Progress: 100.00%
#
# Set albedo: /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/diffuse.exr
# Set roughenss: /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/roughness.exr
# /home/ahc/Documents/metrology_ir/DigitalTwinCatalog/neural_pbir/scripts/relit/blender_script.py:144: DeprecationWarning: Passing in context overrides is deprecated in favor of Context.temp_override(..), calling "object.delete"
#   bpy.ops.object.delete({"selected_objects": objs})
# Set environment map: /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/envmap_for_blender.exr
# Writing: im_0000_image_envmap_for_blender
# Fra:29 Mem:76.38M (Peak 76.40M) | Time:00:00.00 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Synchronizing object | mesh
# Fra:29 Mem:123.38M (Peak 136.34M) | Time:00:00.02 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Initializing
# Fra:29 Mem:123.37M (Peak 136.34M) | Time:00:00.02 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Updating Images | Loading sunrise.exr
# Fra:29 Mem:131.39M (Peak 147.38M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Waiting for render to start
# Fra:29 Mem:131.39M (Peak 147.38M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Loading render kernels (may take a few minutes the first time)
# Fra:29 Mem:131.39M (Peak 147.38M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Scene
# Fra:29 Mem:131.39M (Peak 147.38M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Shaders
# Fra:29 Mem:131.39M (Peak 147.38M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Procedurals
# Fra:29 Mem:131.39M (Peak 147.38M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Background
# Fra:29 Mem:131.39M (Peak 147.38M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Camera
# Fra:29 Mem:131.39M (Peak 147.38M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Meshes Flags
# Fra:29 Mem:131.39M (Peak 147.38M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Objects
# Fra:29 Mem:131.39M (Peak 147.38M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Objects | Copying Transformations to device
# Fra:29 Mem:131.39M (Peak 147.38M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Objects | Applying Static Transformations
# Fra:29 Mem:131.39M (Peak 147.38M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Particle Systems
# Fra:29 Mem:131.39M (Peak 147.38M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Particle Systems | Copying Particles to device
# Fra:29 Mem:131.39M (Peak 147.38M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Meshes
# Fra:29 Mem:140.03M (Peak 147.38M) | Time:00:00.04 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Mesh | Computing attributes
# Fra:29 Mem:156.24M (Peak 156.24M) | Time:00:00.04 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Mesh | Copying Attributes to device
# Fra:29 Mem:156.24M (Peak 156.24M) | Time:00:00.04 | Mem:24.21M, Peak:24.21M | Scene, View Layer | Updating Scene BVH | Building
# Fra:29 Mem:156.24M (Peak 156.24M) | Time:00:00.04 | Mem:24.21M, Peak:24.21M | Scene, View Layer | Updating Scene BVH | Building BVH
# Fra:29 Mem:156.24M (Peak 156.24M) | Time:00:00.04 | Mem:41.49M, Peak:41.49M | Scene, View Layer | Updating Scene BVH | Building BVH 0%
# Fra:29 Mem:156.24M (Peak 156.24M) | Time:00:00.05 | Mem:60.30M, Peak:77.58M | Scene, View Layer | Updating Scene BVH | Copying BVH to device
# Fra:29 Mem:156.24M (Peak 156.24M) | Time:00:00.05 | Mem:60.30M, Peak:77.58M | Scene, View Layer | Updating Mesh | Computing normals
# Fra:29 Mem:175.68M (Peak 175.68M) | Time:00:00.05 | Mem:60.30M, Peak:77.58M | Scene, View Layer | Updating Mesh | Copying Mesh to device
# Fra:29 Mem:175.68M (Peak 175.68M) | Time:00:00.05 | Mem:79.74M, Peak:79.74M | Scene, View Layer | Updating Objects Flags
# Fra:29 Mem:175.68M (Peak 175.68M) | Time:00:00.05 | Mem:79.74M, Peak:79.74M | Scene, View Layer | Updating Primitive Offsets
# Fra:29 Mem:175.68M (Peak 175.68M) | Time:00:00.05 | Mem:79.74M, Peak:79.74M | Scene, View Layer | Updating Images
# Fra:29 Mem:167.68M (Peak 175.68M) | Time:00:00.05 | Mem:71.74M, Peak:79.74M | Scene, View Layer | Updating Images | Loading roughness.exr
# Fra:29 Mem:183.68M (Peak 183.68M) | Time:00:00.05 | Mem:71.74M, Peak:79.74M | Scene, View Layer | Updating Images | Loading diffuse.exr
# Fra:29 Mem:199.68M (Peak 199.68M) | Time:00:00.05 | Mem:71.74M, Peak:79.74M | Scene, View Layer | Updating Images | Loading envmap_for_blender.exr
# Fra:29 Mem:200.18M (Peak 200.18M) | Time:00:00.06 | Mem:104.24M, Peak:104.24M | Scene, View Layer | Updating Camera Volume
# Fra:29 Mem:200.18M (Peak 200.18M) | Time:00:00.06 | Mem:104.24M, Peak:104.24M | Scene, View Layer | Updating Lookup Tables
# Fra:29 Mem:200.18M (Peak 200.18M) | Time:00:00.06 | Mem:104.24M, Peak:104.24M | Scene, View Layer | Updating Lights
# Fra:29 Mem:200.18M (Peak 200.18M) | Time:00:00.06 | Mem:104.24M, Peak:104.24M | Scene, View Layer | Updating Lights | Importance map
# Fra:29 Mem:264.21M (Peak 552.18M) | Time:00:00.16 | Mem:168.28M, Peak:328.25M | Scene, View Layer | Updating Lights | Computing distribution
# Fra:29 Mem:264.21M (Peak 552.18M) | Time:00:00.16 | Mem:168.28M, Peak:328.25M | Scene, View Layer | Updating Integrator
# Fra:29 Mem:265.21M (Peak 552.18M) | Time:00:00.16 | Mem:169.28M, Peak:328.25M | Scene, View Layer | Updating Film
# Fra:29 Mem:265.22M (Peak 552.18M) | Time:00:00.16 | Mem:169.28M, Peak:328.25M | Scene, View Layer | Updating Lookup Tables
# Fra:29 Mem:265.22M (Peak 552.18M) | Time:00:00.16 | Mem:169.29M, Peak:328.25M | Scene, View Layer | Updating Baking
# Fra:29 Mem:265.22M (Peak 552.18M) | Time:00:00.16 | Mem:169.29M, Peak:328.25M | Scene, View Layer | Updating Device | Writing constant memory
# Fra:29 Mem:265.22M (Peak 552.18M) | Time:00:00.16 | Mem:169.29M, Peak:328.25M | Scene, View Layer | Sample 0/128
# Fra:29 Mem:283.21M (Peak 552.18M) | Time:00:00.17 | Remaining:00:00.89 | Mem:187.18M, Peak:328.25M | Scene, View Layer | Sample 1/128
# ...
# Fra:29 Mem:131.39M (Peak 147.38M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Objects | Copying Transformations to device
# Fra:29 Mem:131.39M (Peak 147.38M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Objects | Applying Static Transformations
# Fra:29 Mem:131.39M (Peak 147.38M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Particle Systems
# Fra:29 Mem:131.39M (Peak 147.38M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Particle Systems | Copying Particles to device
# Fra:29 Mem:131.39M (Peak 147.38M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Meshes
# Fra:29 Mem:140.03M (Peak 147.38M) | Time:00:00.03 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Mesh | Computing attributes
# Fra:29 Mem:156.24M (Peak 156.24M) | Time:00:00.04 | Mem:8.00M, Peak:8.00M | Scene, View Layer | Updating Mesh | Copying Attributes to device
# Fra:29 Mem:156.24M (Peak 156.24M) | Time:00:00.04 | Mem:24.21M, Peak:24.21M | Scene, View Layer | Updating Scene BVH | Building
# Fra:29 Mem:156.24M (Peak 156.24M) | Time:00:00.04 | Mem:24.21M, Peak:24.21M | Scene, View Layer | Updating Scene BVH | Building BVH
# Fra:29 Mem:156.24M (Peak 156.24M) | Time:00:00.04 | Mem:41.49M, Peak:41.49M | Scene, View Layer | Updating Scene BVH | Building BVH 0%
# Fra:29 Mem:156.24M (Peak 156.24M) | Time:00:00.05 | Mem:60.30M, Peak:77.58M | Scene, View Layer | Updating Scene BVH | Copying BVH to device
# Fra:29 Mem:156.24M (Peak 156.24M) | Time:00:00.05 | Mem:60.30M, Peak:77.58M | Scene, View Layer | Updating Mesh | Computing normals
# Fra:29 Mem:175.68M (Peak 175.68M) | Time:00:00.05 | Mem:60.30M, Peak:77.58M | Scene, View Layer | Updating Mesh | Copying Mesh to device
# Fra:29 Mem:175.68M (Peak 175.68M) | Time:00:00.05 | Mem:79.74M, Peak:79.74M | Scene, View Layer | Updating Objects Flags
# Fra:29 Mem:175.68M (Peak 175.68M) | Time:00:00.05 | Mem:79.74M, Peak:79.74M | Scene, View Layer | Updating Primitive Offsets
# Fra:29 Mem:175.68M (Peak 175.68M) | Time:00:00.05 | Mem:79.74M, Peak:79.74M | Scene, View Layer | Updating Images
# Fra:29 Mem:167.68M (Peak 175.68M) | Time:00:00.05 | Mem:71.74M, Peak:79.74M | Scene, View Layer | Updating Images | Loading roughness.exr
# Fra:29 Mem:183.68M (Peak 183.68M) | Time:00:00.05 | Mem:71.74M, Peak:79.74M | Scene, View Layer | Updating Images | Loading diffuse.exr
# Fra:29 Mem:199.68M (Peak 199.68M) | Time:00:00.05 | Mem:71.74M, Peak:79.74M | Scene, View Layer | Updating Images | Loading teapot_scene006_0070_for_teapot_scene001.exr
# Fra:29 Mem:207.68M (Peak 207.68M) | Time:00:00.06 | Mem:111.74M, Peak:111.74M | Scene, View Layer | Updating Camera Volume
# Fra:29 Mem:207.68M (Peak 207.68M) | Time:00:00.06 | Mem:111.74M, Peak:111.74M | Scene, View Layer | Updating Lookup Tables
# Fra:29 Mem:207.68M (Peak 207.68M) | Time:00:00.06 | Mem:111.74M, Peak:111.74M | Scene, View Layer | Updating Lights
# Fra:29 Mem:207.68M (Peak 207.68M) | Time:00:00.06 | Mem:111.74M, Peak:111.74M | Scene, View Layer | Updating Lights | Importance map
# Fra:29 Mem:271.71M (Peak 559.68M) | Time:00:00.17 | Mem:175.78M, Peak:335.75M | Scene, View Layer | Updating Lights | Computing distribution
# Fra:29 Mem:271.71M (Peak 559.68M) | Time:00:00.17 | Mem:175.78M, Peak:335.75M | Scene, View Layer | Updating Integrator
# Fra:29 Mem:272.71M (Peak 559.68M) | Time:00:00.17 | Mem:176.78M, Peak:335.75M | Scene, View Layer | Updating Film
# Fra:29 Mem:272.72M (Peak 559.68M) | Time:00:00.17 | Mem:176.78M, Peak:335.75M | Scene, View Layer | Updating Lookup Tables
# Fra:29 Mem:272.72M (Peak 559.68M) | Time:00:00.17 | Mem:176.79M, Peak:335.75M | Scene, View Layer | Updating Baking
# Fra:29 Mem:272.72M (Peak 559.68M) | Time:00:00.17 | Mem:176.79M, Peak:335.75M | Scene, View Layer | Updating Device | Writing constant memory
# Fra:29 Mem:272.72M (Peak 559.68M) | Time:00:00.17 | Mem:176.79M, Peak:335.75M | Scene, View Layer | Sample 0/128
# Fra:29 Mem:290.71M (Peak 559.68M) | Time:00:00.17 | Remaining:00:00.94 | Mem:194.68M, Peak:335.75M | Scene, View Layer | Sample 1/128
# Fra:29 Mem:302.64M (Peak 559.68M) | Time:00:00.71 | Mem:194.68M, Peak:335.75M | Scene, View Layer | Sample 128/128
# Fra:29 Mem:302.64M (Peak 559.68M) | Time:00:00.71 | Mem:194.68M, Peak:335.75M | Scene, View Layer | Finished
# Fra:29 Mem:302.72M (Peak 559.68M) | Time:00:00.71 | Compositing
# Fra:29 Mem:302.72M (Peak 559.68M) | Time:00:00.71 | Compositing | Determining resolution
# Fra:29 Mem:302.72M (Peak 559.68M) | Time:00:00.71 | Compositing | Initializing execution
# Fra:29 Mem:313.78M (Peak 559.68M) | Time:00:00.72 | Compositing | Tile 1-4
# Fra:29 Mem:313.78M (Peak 559.68M) | Time:00:00.72 | Compositing | Tile 2-4
# Fra:29 Mem:313.78M (Peak 559.68M) | Time:00:00.72 | Compositing | Tile 3-4
# Fra:29 Mem:313.78M (Peak 559.68M) | Time:00:00.72 | Compositing | Tile 4-4
# Fra:29 Mem:313.78M (Peak 559.68M) | Time:00:00.72 | Compositing | Tile 1-4
# Fra:29 Mem:313.78M (Peak 559.68M) | Time:00:00.72 | Compositing | Tile 2-4
# Fra:29 Mem:313.78M (Peak 559.68M) | Time:00:00.72 | Compositing | Tile 3-4
# Fra:29 Mem:313.78M (Peak 559.68M) | Time:00:00.72 | Compositing | Tile 4-4
# Fra:29 Mem:313.78M (Peak 559.68M) | Time:00:00.72 | Compositing | Tile 1-4
# Fra:29 Mem:313.78M (Peak 559.68M) | Time:00:00.72 | Compositing | Tile 2-4
# Fra:29 Mem:313.78M (Peak 559.68M) | Time:00:00.72 | Compositing | Tile 3-4
# Fra:29 Mem:313.78M (Peak 559.68M) | Time:00:00.72 | Compositing | Tile 4-4
# Fra:29 Mem:313.78M (Peak 559.68M) | Time:00:00.72 | Compositing | Tile 1-4
# Fra:29 Mem:313.78M (Peak 559.68M) | Time:00:00.72 | Compositing | Tile 2-4
# Fra:29 Mem:313.78M (Peak 559.68M) | Time:00:00.72 | Compositing | Tile 3-4
# Fra:29 Mem:313.78M (Peak 559.68M) | Time:00:00.72 | Compositing | Tile 4-4
# Fra:29 Mem:313.72M (Peak 559.68M) | Time:00:00.72 | Compositing | De-initializing execution
# Saved: Image0029.png
# Saved: Image0029.png
# Saved: /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0070_albedo0029.exr
# Saved: '/home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0070_teapot_scene006_0070_for_teapot_scene001.exr'
#  Time: 00:00.75 (Saving: 00:00.00)
#
#
# Blender quit
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/render_geo/0000_image.zbuf.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/render_geo/0007_image.zbuf.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/render_geo/0014_image.zbuf.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/render_geo/0021_image.zbuf.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/render_geo/0028_image.zbuf.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/render_geo/0035_image.zbuf.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/render_geo/0042_image.zbuf.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/render_geo/0049_image.zbuf.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/render_geo/0056_image.zbuf.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/render_geo/0063_image.zbuf.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0000_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0007_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0014_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0021_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0028_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0035_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0042_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0049_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0056_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0063_image_envmap_for_blender.exr
# teapot_scene001     : nv=10/10 nl=20/20 mat=10/10 geo=10/10 w/ mesh
# Save to results___NPBIR__VGGT_g__EST_l/stanford_orb/eval_inputs_pbir.json
# INFO:__main__:Processing 1 scenes...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0000_image_envmap_for_blender.exr
# /home/ahc/miniconda3/envs/metrology_ir/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/ahc/miniconda3/envs/metrology_ir/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# /home/ahc/miniconda3/envs/metrology_ir/lib/python3.11/site-packages/lpips/lpips.py:107: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.load_state_dict(torch.load(model_path, map_location='cpu'), strict=False)
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0007_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0014_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0021_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0028_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0035_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0042_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0049_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0056_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0063_image_envmap_for_blender.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0060_teapot_scene002_0060_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0061_teapot_scene002_0061_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0062_teapot_scene002_0062_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0063_teapot_scene002_0063_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0064_teapot_scene002_0064_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0065_teapot_scene002_0065_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0066_teapot_scene002_0066_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0067_teapot_scene002_0067_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0068_teapot_scene002_0068_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0069_teapot_scene002_0069_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0061_teapot_scene006_0061_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0062_teapot_scene006_0062_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0063_teapot_scene006_0063_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0064_teapot_scene006_0064_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0065_teapot_scene006_0065_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0066_teapot_scene006_0066_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0067_teapot_scene006_0067_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0068_teapot_scene006_0068_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0069_teapot_scene006_0069_for_teapot_scene001.exr
# /home/ahc/Documents/metrology_ir/results___NPBIR__VGGT_g__EST_l/stanford_orb/teapot_scene001/pbir/blender_relit/im_0070_teapot_scene006_0070_for_teapot_scene001.exr
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.35s/it]
# INFO:__main__:Results saved to .././results___NPBIR__VGGT_g__EST_l/stanford_orb/eval_outputs_pbir.json
